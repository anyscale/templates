# %% [markdown]
# # Unstructured Data Ingestion and Processing With Ray Data
#
# **Time to complete**: 35 min | **Difficulty**: Advanced | **Prerequisites**: Data engineering experience, document processing, basic NLP knowledge
#
# ## What you'll build
#
# Build a comprehensive document ingestion pipeline that transforms unstructured documents from data lakes into structured, analytics-ready datasets using Ray Data's distributed processing capabilities for enterprise data warehouse workflows.

# %% [markdown]
# ## Table of Contents
#
# 1. [Data Lake Document Discovery](#step-1-data-lake-document-discovery) (8 min)
# 2. [Document Processing and Classification](#step-2-document-processing-and-classification) (10 min)
# 3. [Text Extraction and Enrichment](#step-3-text-extraction-and-enrichment) (8 min)
# 4. [Data Warehouse Output](#step-4-data-warehouse-output) (6 min)
# 5. [Verification and Summary](#step-5-verification-and-summary) (3 min)

# %% [markdown]
# ## Learning Objectives
#
# **Why unstructured data ingestion matters**: Enterprise data lakes contain vast amounts of unstructured documents (PDFs, Word docs, presentations, reports) that need systematic processing to extract business value for analytics and reporting.
#
# **Ray Data's ingestion capabilities**: Distribute document processing across clusters to handle large-scale document collections, extract structured data, and prepare analytics-ready datasets for data warehouse consumption.
#
# **Data lake to warehouse patterns**: Techniques used by data engineering teams to systematically process document collections, extract structured information, and create queryable datasets for business intelligence.
#
# **Production ingestion workflows**: Scalable document processing patterns that handle diverse file formats, extract metadata, and create structured schemas for downstream analytics systems.

# %% [markdown]
# ## Overview
#
# **Challenge**: Enterprise data lakes contain millions of unstructured documents (PDFs, Word docs, presentations) across multiple formats that need systematic processing to extract business value. Traditional document processing approaches struggle with:
# - **Scale**: Single-machine processing limits document volume
# - **Consistency**: Manual extraction creates inconsistent schemas
# - **Integration**: Complex infrastructure for analysis
# - **Warehouse integration**: Manual data modeling and ETL processes
# - **Increasing data sizes**: Unstructured data is growing rapidly, often overtaking structured data by 10x in sheer data volume.
#
# **Solution**: Ray Data enables end-to-end document ingestion pipelines with native distributed operations for processing millions of documents efficiently.
#
# - **Scale**: Using Streaming Execution and massive scalability capabilities to process petabytes or even exabytes of data.
# - **Consistency**: A flexible API for supporting quality checks through `map` as well as support for any type of PyArrow schema. All data read also has to be consistent or else the pipeline will fail along with additional configuration options for this behavior.
# - **Integration**: Supports integration with all data types as well as any AI types, running on CPUs/GPUs/Accelerators on cloud and on-prem
# - **Warehouse integration**: Pre-built connectors to popular data warehouses as well as having the ability to build custom connectors easily.
# - **Increasing data sizes**: Can be used for single node optimization to scaling across 10k+ nodes

# %% [markdown]
# ## Prerequisites Checklist
#
# Before starting, ensure you have:
# - [ ] Understanding of data lake and data warehouse concepts
# - [ ] Experience with document processing and text extraction
# - [ ] Knowledge of structured data formats (Parquet, Delta Lake, Iceberg)
# - [ ] Python environment with Ray Data and document processing libraries
# - [ ] Access to S3 or other cloud storage for document sources

# %% [markdown]
# ## Quick start (3 minutes)
#
# This section demonstrates large-scale document ingestion using Ray Data:

# %%
import json 
import uuid  
from datetime import datetime  
from pathlib import Path 
from typing import Any, Dict, List  #

import numpy as np 
import pandas as pd 

import ray 
from ray.data.aggregate import Count, Max, Mean, Sum 
from ray.data.expressions import col, lit 

ctx = ray.data.DataContext.get_current()

# Disable progress bars for cleaner output in production
# You can enable these for debugging: set to True to see progress
ctx.enable_progress_bars = False
ctx.enable_operator_progress_bars = False

# Initialize Ray cluster connection so we can set the Ray Data context
ray.init(ignore_reinit_error=True)
# Out:
# 2025-10-20 20:08:43,128	INFO worker.py:1833 -- Connecting to existing Ray cluster at address: 10.0.86.206:6379...
# 2025-10-20 20:08:43,129	INFO worker.py:1851 -- Calling ray.init() again after it has already been called.
# RayContext(dashboard_url='session-77uweunq3awbhqefvry4lwcqq5.i.anyscaleuserdata.com', python_version='3.12.11', ray_version='2.50.0', ray_commit='be05f5dceae9cf69439c029215ebac99a223fe61')

# %% [markdown]
# ## Step 1: Data Lake Document Discovery

# %% [markdown]
# ### Discover document collections in data lake

# %%
# STEP 1: READ DOCUMENTS FROM DATA LAKE (S3)

# Use Ray Data's read_binary_files() to load documents from S3
# Why read_binary_files()?
#   - Reads files as raw bytes (works for PDFs, DOCX, images, etc.)
#   - Distributes file reading across cluster workers
#   - include_paths=True gives us the file path for each document
#
# Parameters explained:
#   - S3 path: Location of document collection in data lake
#   - include_paths=True: Adds 'path' column with file location
#   - ray_remote_args: Resource allocation per task
#     * num_cpus=0.025: Very low CPU since this is I/O-bound (reading files)
#     * This allows many concurrent reads without CPU bottleneck
#   - limit(100): Process only 100 documents for this demo
#     * Remove this limit to process entire collection

document_collection = ray.data.read_binary_files(
    "s3://anyscale-rag-application/1000-docs/",
    include_paths=True,
    ray_remote_args={"num_cpus": 0.025}
).limit(100)

# Display the schema to understand our data structure
# At this point, we have: 'bytes' (file content) and 'path' (file location)
print(f"Dataset schema: {document_collection.schema()}")
# Out:
# 2025-10-20 20:08:43,509	INFO logging.py:293 -- Registered dataset logger for dataset dataset_122_0
# 2025-10-20 20:08:43,513	INFO streaming_executor.py:159 -- Starting execution of Dataset dataset_122_0. Full logs are in /tmp/ray/session_2025-10-20_17-37-47_219984_2353/logs/ray-data
# 2025-10-20 20:08:43,514	INFO streaming_executor.py:160 -- Execution plan of Dataset dataset_122_0: InputDataBuffer[Input] -> TaskPoolMapOperator[ListFiles] -> LimitOperator[limit=1] -> TaskPoolMapOperator[ReadFiles]
# /home/ray/anaconda3/lib/python3.12/site-packages/ray/anyscale/data/_internal/cluster_autoscaler/productivity_calculator.py:174: RuntimeWarning: invalid value encountered in divide
#   gpu_fraction_per_op = (optimal_num_tasks_per_op * num_gpus_per_op) / np.sum(
# 2025-10-20 20:08:46,611	INFO streaming_executor.py:279 -- ✔️  Dataset dataset_122_0 execution finished in 3.10 seconds
# Dataset schema: Column  Type
# ------  ----
# bytes   binary
# path    string

# %% [markdown]
# ### Document metadata extraction

# %%
# STEP 2: TEXT EXTRACTION FUNCTION
# This function extracts text from various document formats (PDF, DOCX, etc.)
# It processes one document at a time (distirbuted by Ray) and returns structured metadata + text


def process_file(record: Dict[str, Any]) -> Dict[str, Any]:
    """
    Extract text content from document files using the Unstructured library.
    
    BEGINNER NOTE:
    - Input: A dictionary (record) with 'bytes' (file content) and 'path' (file location)
    - Output: A dictionary with extracted text + metadata
    - This function runs on each worker node in parallel
    
    Why extract text immediately?
    - Avoids passing large binary data through multiple operations
    - Reduces memory usage in downstream processing
    - Enables faster processing by dropping binary data early
    """
    # Import libraries inside function so each Ray worker has access
    import io
    from pathlib import Path
    
    from unstructured.partition.auto import partition
    
    # Extract file metadata from the input record
    file_path = Path(record["path"])  # Convert path string to Path object
    file_bytes = record["bytes"]  # Raw file content (binary data)
    file_size = len(file_bytes)  # Size in bytes
    file_extension = file_path.suffix.lower()  # Get extension (.pdf, .docx, etc.)
    file_name = file_path.name  # Just the filename (not full path)
    
    # We can only extract text from certain file types
    # If unsupported, return metadata with empty text
    supported_extensions = {".pdf", ".docx", ".doc", ".pptx", ".ppt", ".html", ".txt"}
    
    if file_extension not in supported_extensions:
        # Return a record with metadata but no extracted text
        return {
            "document_id": str(uuid.uuid4()),  # Generate unique ID
            "file_path": str(file_path),
            "file_name": file_name,
            "file_extension": file_extension,
            "file_size_bytes": file_size,
            "file_size_mb": round(file_size / (1024 * 1024), 2),  # Convert to MB
            "discovery_timestamp": datetime.now().isoformat(),
            "extracted_text": "",  # Empty - unsupported format
            "text_length": 0,
            "word_count": 0,
            "extraction_status": "unsupported_format"
        }
    
    # Extract text using the Unstructured library
    try:
        # Create an in-memory file stream from bytes (avoids writing to disk)
        with io.BytesIO(file_bytes) as stream:
            # partition() automatically detects format and extracts text
            # It returns a list of text elements (paragraphs, tables, etc.)
            elements = partition(file=stream)
            
            # Combine all extracted text elements into one string
            extracted_text = " ".join([str(el) for el in elements]).strip()
            
            # Calculate text statistics for quality assessment
            text_length = len(extracted_text)  # Total characters
            word_count = len(extracted_text.split()) if extracted_text else 0
            extraction_status = "success"
            
    except Exception as e:
        # If extraction fails (corrupted file, unsupported format, etc.)
        # Log the error and continue processing other files
        print(f"Cannot process file {file_path}: {e}")
        extracted_text = ""
        text_length = 0
        word_count = 0
        extraction_status = f"error: {str(e)[:100]}"  # Store error message (truncated)
    
    # Return record with all metadata and extracted text
    return {
        "document_id": str(uuid.uuid4()),  # Unique identifier for this document
        "file_path": str(file_path),
        "file_name": file_name,
        "file_extension": file_extension,
        "file_size_bytes": file_size,
        "file_size_mb": round(file_size / (1024 * 1024), 2),
        "discovery_timestamp": datetime.now().isoformat(),
        "extracted_text": extracted_text,  # The actual text content
        "text_length": text_length,
        "word_count": word_count,
        "extraction_status": extraction_status
    }


# Ray Data's map() applies process_file() to each document in parallel
# This is the "embarrassingly parallel" pattern - each document is independent
print("Extracting text from documents...")

# Why map() instead of map_batches()?
#   - map(): Process one record at a time (good for variable-size documents)
#   - map_batches(): Process records in batches (better for vectorized operations)
#   - Text extraction is I/O-bound and document-specific, so map() is ideal

# Parameters:
#   - process_file: The function to apply to each record
#   - concurrency=16: Run 8 parallel tasks at a time
#   - num_cpus=1: Each task gets 1 CPU (text extraction is CPU-intensive)

documents_with_text = document_collection.map(
    process_file,
    concurrency=16,
    num_cpus=1
)
# Out:
# Extracting text from documents...

# %%
# Convert a sample of documents to pandas DataFrame for easy viewing
documents_with_text.limit(25).to_pandas()
# Out:
# 2025-10-20 20:08:46,860	INFO logging.py:293 -- Registered dataset logger for dataset dataset_124_0
# 2025-10-20 20:08:46,866	INFO streaming_executor.py:159 -- Starting execution of Dataset dataset_124_0. Full logs are in /tmp/ray/session_2025-10-20_17-37-47_219984_2353/logs/ray-data
# 2025-10-20 20:08:46,866	INFO streaming_executor.py:160 -- Execution plan of Dataset dataset_124_0: InputDataBuffer[Input] -> TaskPoolMapOperator[ListFiles] -> LimitOperator[limit=25] -> TaskPoolMapOperator[ReadFiles] -> TaskPoolMapOperator[Map(process_file)]
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P15' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P19' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P23' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P27' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P33' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P39' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P43' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P47' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P53' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P57' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P63' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P74' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P78' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P84' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P88' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P90' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P92' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P94' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P96' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P98' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P100' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P102' is an invalid float value
# /home/ray/anaconda3/lib/python3.12/site-packages/ray/data/_internal/execution/operators/task_pool_map_operator.py:165: UserWarning: The maximum number of concurrent tasks for 'Map(process_file)' is set to 16, but the operator only received 4 input(s). This means that the operator can launch at most 4 task(s), which is less than the concurrency limit. You might be able to increase the number of concurrent tasks by configuring `override_num_blocks` earlier in the pipeline.
#   warnings.warn(
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P104' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P106' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P108' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P110' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P112' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P114' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P116' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P118' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P120' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P122' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P124' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P126' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P128' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P130' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P132' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P134' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P136' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P138' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P140' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P142' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P144' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P146' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P148' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P152' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P160' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P168' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P174' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P180' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P186' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P192' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P198' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P204' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P217' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P221' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P227' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P235' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P239' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P243' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P251' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P255' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P259' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P265' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P271' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P275' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P281' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P285' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P289' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P295' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P299' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P305' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P311' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P315' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P321' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P325' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P331' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P337' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P341' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P347' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P353' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P357' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P361' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P365' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P371' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P375' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P379' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P383' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P387' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P391' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P395' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P399' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P403' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P407' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P413' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P417' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P421' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P425' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P429' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P435' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P441' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P447' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P451' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P457' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P463' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P465' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P467' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P469' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P471' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P473' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P475' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P477' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P479' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P481' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P483' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P485' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P487' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P489' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P491' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P493' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P495' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P497' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P499' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P501' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P503' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P505' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P507' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P509' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P511' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P513' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P515' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P517' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P525' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P529' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P535' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P541' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P547' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P553' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P557' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P559' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P561' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P574' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P580' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P584' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P588' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P594' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P598' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P602' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P608' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P616' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P624' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P632' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P640' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P648' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P656' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P658' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P660' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P662' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P664' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P666' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P668' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P670' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P672' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P674' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P676' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P678' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P684' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P688' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P692' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P696' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P702' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P706' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P710' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P714' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P718' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P722' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P726' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P730' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P736' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P740' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P746' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P750' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P756' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P760' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P766' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P770' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P774' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P778' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P784' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P790' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P796' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P800' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P806' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P810' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P816' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P822' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P826' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P832' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P836' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P840' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P844' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P848' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P852' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P856' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P860' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P864' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P868' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P872' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P876' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P880' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P884' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P888' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P892' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P896' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P900' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P904' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P908' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P912' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P916' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P920' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P924' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P928' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P932' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P936' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P940' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P944' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P948' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P952' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P956' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P960' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P964' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P972' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P976' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P982' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P986' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P992' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P996' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P1000' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P1004' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P1010' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P1016' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P1020' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P1026' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P1030' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P1036' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P1040' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P1046' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P1052' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P1056' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P1060' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P1064' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P1068' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P1072' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P1076' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P1080' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P1084' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P1090' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P1094' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P1100' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P1106' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P1110' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P1114' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P1118' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P1124' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P1128' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P1132' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P1138' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P1144' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P1148' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P1154' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P1162' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P1166' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P1170' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P1174' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P1178' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P1184' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P1188' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P1192' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P1196' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P1200' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P1204' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P1208' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P1212' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P1216' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P1220' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P1224' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P1228' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P1232' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P1236' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P1240' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P1244' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P1248' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P1252' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P1256' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P1260' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P1264' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P1268' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P1272' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P1276' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P1280' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P1284' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P1288' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P1292' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P1296' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P1300' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P1304' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P1308' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P1312' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P1316' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P1318' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P1320' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P1322' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P1324' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P1326' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P1328' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P1330' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P1334' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P1342' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P1350' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P1354' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P1358' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P1366' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P1370' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P1374' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P1383' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P1385' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P1387' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P1394' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P1398' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P1402' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P1408' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P1414' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P1420' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P1424' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P1428' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P1432' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P1436' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P1442' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P1448' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P1454' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P1460' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P1464' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P1470' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P1474' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P1478' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P1482' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P1488' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P1492' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P1496' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P1500' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P1506' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P1510' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P1514' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P1518' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P1522' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P1526' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P1530' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P1543' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P1545' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P1549' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P1555' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P1561' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P1567' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P1573' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P1579' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P1584' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P1589' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P1594' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P1598' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P1602' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P1606' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P1610' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P1614' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P1618' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P1622' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P1628' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P1632' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P1638' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P1644' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P1650' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P1654' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P1658' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P1664' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P1670' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P1674' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P1678' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P1684' is an invalid float value
# ...
# (Map(process_file) pid=12110, ip=10.0.92.64) Cannot set gray non-stroke color because /'p20' is an invalid float value
# (Map(process_file) pid=12110, ip=10.0.92.64) Cannot set gray non-stroke color because /'p21' is an invalid float value
# (Map(process_file) pid=12110, ip=10.0.92.64) Cannot set gray non-stroke color because /'p22' is an invalid float value
# (Map(process_file) pid=12110, ip=10.0.92.64) Cannot set gray non-stroke color because /'p23' is an invalid float value
# (Map(process_file) pid=12110, ip=10.0.92.64) Cannot set gray non-stroke color because /'p24' is an invalid float value
# (Map(process_file) pid=12110, ip=10.0.92.64) Cannot set gray non-stroke color because /'p25' is an invalid float value
# (Map(process_file) pid=12110, ip=10.0.92.64) Cannot set gray non-stroke color because /'p26' is an invalid float value
# (Map(process_file) pid=12110, ip=10.0.92.64) Cannot set gray non-stroke color because /'p27' is an invalid float value
# (Map(process_file) pid=12110, ip=10.0.92.64) Cannot set gray non-stroke color because /'p28' is an invalid float value
# (Map(process_file) pid=12110, ip=10.0.92.64) Cannot set gray non-stroke color because /'p29' is an invalid float value
# (Map(process_file) pid=12110, ip=10.0.92.64) Cannot set gray non-stroke color because /'p30' is an invalid float value
# (Map(process_file) pid=12110, ip=10.0.92.64) Cannot set gray non-stroke color because /'p31' is an invalid float value
# (Map(process_file) pid=12110, ip=10.0.92.64) Cannot set gray non-stroke color because /'p32' is an invalid float value
# (Map(process_file) pid=12110, ip=10.0.92.64) Cannot set gray non-stroke color because /'p33' is an invalid float value
# (Map(process_file) pid=12110, ip=10.0.92.64) Cannot set gray non-stroke color because /'p34' is an invalid float value
# (Map(process_file) pid=12110, ip=10.0.92.64) Cannot set gray non-stroke color because /'p35' is an invalid float value
# (Map(process_file) pid=12110, ip=10.0.92.64) Cannot set gray non-stroke color because /'p36' is an invalid float value
# (Map(process_file) pid=12110, ip=10.0.92.64) Cannot set gray non-stroke color because /'p37' is an invalid float value
# (Map(process_file) pid=12110, ip=10.0.92.64) Cannot set gray non-stroke color because /'p38' is an invalid float value
# (Map(process_file) pid=12110, ip=10.0.92.64) Cannot set gray non-stroke color because /'p39' is an invalid float value
# (Map(process_file) pid=12110, ip=10.0.92.64) Cannot set gray non-stroke color because /'p40' is an invalid float value
# (Map(process_file) pid=12110, ip=10.0.92.64) Cannot set gray non-stroke color because /'p41' is an invalid float value
# (Map(process_file) pid=12110, ip=10.0.92.64) Cannot set gray non-stroke color because /'p42' is an invalid float value
# (Map(process_file) pid=12110, ip=10.0.92.64) Cannot set gray non-stroke color because /'p43' is an invalid float value
# (Map(process_file) pid=12110, ip=10.0.92.64) Cannot set gray non-stroke color because /'p44' is an invalid float value
# (Map(process_file) pid=12110, ip=10.0.92.64) Cannot set gray non-stroke color because /'p45' is an invalid float value
# (Map(process_file) pid=12110, ip=10.0.92.64) Cannot set gray non-stroke color because /'p46' is an invalid float value
# (Map(process_file) pid=12110, ip=10.0.92.64) Cannot set gray non-stroke color because /'p47' is an invalid float value
# (Map(process_file) pid=12110, ip=10.0.92.64) Cannot set gray non-stroke color because /'p48' is an invalid float value
# (Map(process_file) pid=12110, ip=10.0.92.64) Cannot set gray non-stroke color because /'p49' is an invalid float value
# (Map(process_file) pid=12110, ip=10.0.92.64) Cannot set gray non-stroke color because /'p50' is an invalid float value
# (Map(process_file) pid=12110, ip=10.0.92.64) Cannot set gray non-stroke color because /'p51' is an invalid float value
# (Map(process_file) pid=12110, ip=10.0.92.64) Cannot set gray non-stroke color because /'p52' is an invalid float value
# (Map(process_file) pid=12110, ip=10.0.92.64) Cannot set gray non-stroke color because /'p53' is an invalid float value
# (Map(process_file) pid=12110, ip=10.0.92.64) Cannot set gray non-stroke color because /'p54' is an invalid float value
# (Map(process_file) pid=12110, ip=10.0.92.64) Cannot set gray non-stroke color because /'p55' is an invalid float value
# (Map(process_file) pid=12110, ip=10.0.92.64) Cannot set gray non-stroke color because /'p56' is an invalid float value
# (Map(process_file) pid=12110, ip=10.0.92.64) Cannot set gray non-stroke color because /'p57' is an invalid float value
# (Map(process_file) pid=12110, ip=10.0.92.64) Cannot set gray non-stroke color because /'p58' is an invalid float value
# (Map(process_file) pid=12110, ip=10.0.92.64) Cannot set gray non-stroke color because /'p59' is an invalid float value
# (Map(process_file) pid=12110, ip=10.0.92.64) Cannot set gray non-stroke color because /'p60' is an invalid float value
# (Map(process_file) pid=12110, ip=10.0.92.64) Cannot set gray non-stroke color because /'p61' is an invalid float value
# (Map(process_file) pid=12110, ip=10.0.92.64) Cannot set gray non-stroke color because /'p62' is an invalid float value
# (Map(process_file) pid=12110, ip=10.0.92.64) Cannot set gray non-stroke color because /'p63' is an invalid float value
# (Map(process_file) pid=12110, ip=10.0.92.64) Cannot set gray non-stroke color because /'p64' is an invalid float value
# (Map(process_file) pid=12110, ip=10.0.92.64) Cannot set gray non-stroke color because /'p65' is an invalid float value
# (Map(process_file) pid=12110, ip=10.0.92.64) Cannot set gray non-stroke color because /'p66' is an invalid float value
# (Map(process_file) pid=12110, ip=10.0.92.64) Cannot set gray non-stroke color because /'p67' is an invalid float value
# (Map(process_file) pid=12110, ip=10.0.92.64) Cannot set gray non-stroke color because /'p68' is an invalid float value
# (Map(process_file) pid=12110, ip=10.0.92.64) Cannot set gray non-stroke color because /'p69' is an invalid float value
# (Map(process_file) pid=12110, ip=10.0.92.64) Cannot set gray non-stroke color because /'p70' is an invalid float value
# (Map(process_file) pid=12110, ip=10.0.92.64) Cannot set gray non-stroke color because /'p71' is an invalid float value
# (Map(process_file) pid=12110, ip=10.0.92.64) Cannot set gray non-stroke color because /'p72' is an invalid float value
# (Map(process_file) pid=12110, ip=10.0.92.64) Cannot set gray non-stroke color because /'p73' is an invalid float value
# (Map(process_file) pid=12110, ip=10.0.92.64) Cannot set gray non-stroke color because /'p74' is an invalid float value
# (Map(process_file) pid=12110, ip=10.0.92.64) Cannot set gray non-stroke color because /'p75' is an invalid float value
# (Map(process_file) pid=12110, ip=10.0.92.64) Cannot set gray non-stroke color because /'p76' is an invalid float value
# (Map(process_file) pid=12110, ip=10.0.92.64) Cannot set gray non-stroke color because /'p77' is an invalid float value
# 2025-10-20 20:09:05,057	INFO streaming_executor.py:279 -- ✔️  Dataset dataset_124_0 execution finished in 18.19 seconds
#                              document_id  \
# 0   e0fe8f07-5f07-47c4-aea0-95dd19bf1ecf
# 1   7a2c4d5f-ecf4-4222-a73e-1476aea9c97d
# 2   71c9003b-2e02-4bbe-ba66-c0611de53a86
# 3   be7c84e0-45f2-48fb-816b-1f89fcb6d038
# 4   156c9d93-db92-4b3c-86ef-ccde0d2636bd
# 5   89477ca7-248b-4f88-8b9d-faaa570c67c4
# 6   b515b4ae-63e0-4b05-8e09-7427fb7e25b9
# 7   8b3a498c-0630-4c86-becf-000f85b98cf3
# 8   ecfa57ef-751a-40d4-ba31-66efebc8a41d
# 9   3867cca9-15cf-48e1-b91d-511bdc6a08b4
# 10  a26fba0b-cf68-4ace-94ea-6f2ff0021c6a
# 11  fc7cc7ea-983f-4402-94ad-4dfaebc32ccc
# 12  64f56828-b85f-4082-a9d7-704e3919319b
# 13  41e049ef-aab1-4d86-83b6-56e49535d238
# 14  bf9e2767-74f9-490e-9884-29ed374b4f19
# 15  6fad3bf1-1c33-4e6c-86a6-c5f8ecc0ca2a
# 16  3748e749-b85f-46b3-8bb8-48ae92544222
# 17  648372da-4ac7-4e02-b42d-918cf7b9fdf5
# 18  55a34860-c3b7-49be-99b3-bdc37c8294a4
# 19  19dd49e3-b1c4-4ed5-bd0b-60f9045cca00
# 20  ab04216e-7c06-4dbd-a5ee-46001bebeedb
# 21  b19e46a1-e9f1-453c-968f-d388beb76056
# 22  0291782f-17bf-4796-94f4-6bea3d78cd46
# 23  1907504a-4492-4503-91cf-eefba5082451
# 24  cf3c894d-6251-4c1d-8280-e079d7fd42db
#
#                                             file_path  \
# 0   anyscale-rag-application/1000-docs/A Compariso...
# 1   anyscale-rag-application/1000-docs/A Compariso...
# 2   anyscale-rag-application/1000-docs/A Compilati...
# 3   anyscale-rag-application/1000-docs/Graph Theor...
# 4   anyscale-rag-application/1000-docs/Multidigit ...
# 5   anyscale-rag-application/1000-docs/Shining Lig...
# 6   anyscale-rag-application/1000-docs/lwref - BSD...
# 7   anyscale-rag-application/1000-docs/A Dive in t...
# 8   anyscale-rag-application/1000-docs/GraphBLAS M...
# 9   anyscale-rag-application/1000-docs/Multiple By...
# 10  anyscale-rag-application/1000-docs/Shuffle - T...
# 11  anyscale-rag-application/1000-docs/100G Networ...
# 12  anyscale-rag-application/1000-docs/Grand Centr...
# 13  anyscale-rag-application/1000-docs/Monitor_a_j...
# 14  anyscale-rag-application/1000-docs/Serial Orde...
# 15  anyscale-rag-application/1000-docs/jargn10-the...
# 16  anyscale-rag-application/1000-docs/A Block-sor...
# 17  anyscale-rag-application/1000-docs/A Brief Int...
# 18  anyscale-rag-application/1000-docs/A Brief Tut...
# 19  anyscale-rag-application/1000-docs/A Case Stud...
# 20  anyscale-rag-application/1000-docs/A Catalogue...
# 21  anyscale-rag-application/1000-docs/Graph Theor...
# 22  anyscale-rag-application/1000-docs/Monotone Mi...
# 23  anyscale-rag-application/1000-docs/Setting Up ...
# 24  anyscale-rag-application/1000-docs/libtorque -...
#
#                                             file_name file_extension  \
# 0   A Comparison of Programming Languages in Econo...           .pdf
# 1   A Comparison of Software and Hardware Techniqu...           .pdf
# 2   A Compilation Target for Probabilistic Program...           .pdf
# 3                             Graph Theory (2005).pdf           .pdf
# 4   Multidigit Multiplication for Mathematicians (...           .pdf
# 5   Shining Light on Shadow Stacks - 7 Nov 2018 (1...           .pdf
# 6                    lwref - BSDCan2014 - FreeBSD.pdf           .pdf
# 7   A Dive in to Hyper-V Architecture and Vulnerab...           .pdf
# 8   GraphBLAS Mathmatics - Provisional Release 1.0...           .pdf
# 9   Multiple Byte Processing with Full-Word Instru...           .pdf
# 10  Shuffle - Tips and Tricks - Slides - GPU Tech ...           .pdf
# 11  100G Networking Technology Overview - Slides -...           .pdf
# 12  Grand Central Dispatch - FreeBSD Dev Summit (1...           .pdf
# 13                                 Monitor_a_job.docx          .docx
# 14  Serial Order - A Parallel Distributed Processi...           .pdf
# 15               jargn10-thejargonfilever00038gut.txt           .txt
# 16  A Block-sorting Lossless Data Compression Algo...           .pdf
# 17  A Brief Introduction to the Standard Annotatio...           .pdf
# 18  A Brief Tutorial on Database Queries, Data Min...           .pdf
# 19  A Case Study in Optimizing HTM-Enabled Dynamic...           .pdf
# 20  A Catalogue of Optimizing Transformations (197...           .pdf
# 21  Graph Theoretic Obstacles to Perfect Hashing -...           .pdf
# 22  Monotone Minimal Perfect Hashing - Searching a...           .pdf
# 23  Setting Up a Production Monitoring and Diagnos...           .pdf
# 24  libtorque - Portable Multithreaded Continuatio...           .pdf
#
#     file_size_bytes  file_size_mb         discovery_timestamp  \
# 0            211355          0.20  2025-10-20T20:08:50.946284
# 1            156844          0.15  2025-10-20T20:08:52.951872
# 2            892594          0.85  2025-10-20T20:08:54.244419
# 3            206383          0.20  2025-10-20T20:08:54.838291
# 4            346439          0.33  2025-10-20T20:08:56.554954
# 5            443892          0.42  2025-10-20T20:08:58.067227
# 6            214499          0.20  2025-10-20T20:08:58.625721
# 7           4298584          4.10  2025-10-20T20:09:00.147126
# 8            691008          0.66  2025-10-20T20:09:01.769236
# 9            451218          0.43  2025-10-20T20:09:02.324341
# 10           799069          0.76  2025-10-20T20:09:03.328344
# 11          1516903          1.45  2025-10-20T20:08:54.986765
# 12           130189          0.12  2025-10-20T20:08:55.354331
# 13           387461          0.37  2025-10-20T20:08:56.090652
# 14          2281776          2.18  2025-10-20T20:09:00.974803
# 15          1140873          1.09  2025-10-20T20:09:03.518624
# 16           108608          0.10  2025-10-20T20:08:51.801160
# 17           358744          0.34  2025-10-20T20:08:52.134704
# 18           207314          0.20  2025-10-20T20:08:53.492801
# 19           325479          0.31  2025-10-20T20:08:54.698474
# 20          2346760          2.24  2025-10-20T20:08:55.852502
# 21           157158          0.15  2025-10-20T20:08:56.849256
# 22           536251          0.51  2025-10-20T20:09:03.211832
# 23          4546292          4.34  2025-10-20T20:09:04.297444
# 24           279599          0.27  2025-10-20T20:09:05.044006
#
#                                        extracted_text  text_length  \
# 0   A Comparison of Programming Languages in Econo...        33839
# 1   A Comparison of Software and Hardware Techniqu...        71494
# 2   A Compilation Target for Probabilistic Program...        39374
# 3   V. Adamchik Graph Theory Victor Adamchik Fall ...        10103
# 4   MULTIDIGIT MULTIPLICATION FOR MATHEMATICIANS D...        60434
# 5   8 1 0 2 v o N 7 ] R C . s c [ 1 v 5 6 1 3 0 . ...        67521
# 6   An insane idea on reference counting Gleb Smir...        11319
# 7   This presentation is for informational purpose...        13282
# 8   GraphBLAS Mathematics - Provisional Release 1....        40944
# 9   out destroying the 1D C-R property, it is nece...        21908
# 10  Shuffle: Tips and Tricks Julien Demouth, NVIDI...         7228
# 11  100G Networking Technology Overview Christophe...         8996
# 12  Grand Central Dispatch FreeBSD Devsummit Rober...         7831
# 13  Monitor a job Anyscale jobs provides several t...         3296
# 14  SERIAL ORDER: A PARALLEL DISTRmUTED PROCESSING...       132375
# 15  This Is The Project Gutenberg Etext of The Hac...      1065517
# 16  May 10, 1994 SRC Research Report 124 A Block-s...        36622
# 17  A Brief Introduction to the Standard Annotatio...        13276
# 18  A Brief Tutorial on Database Queries, Data Min...        18398
# 19  A Case Study in Optimizing HTM-Enabled Dynamic...        41101
# 20  A catalogue of optimizing transformations whic...        35286
# 21  Graph theoretic obstacles to perfect hashing G...        34105
# 22  O(1) ∗ † ‡ † S n {0,1,...,n − 1} (cid:0) (cid:...        46972
# 23  https://s.sashag.net/prodsdd Sasha Goldshtein ...        17096
# 24  libtorque: Portable Multithreaded Continuation...        23775
#
#     word_count extraction_status
# 0         5307           success
# 1        11296           success
# 2         6122           success
# 3         1600           success
# 4        10046           success
# 5        10529           success
# 6         1613           success
# 7         1478           success
# 8         7326           success
# 9         3989           success
# 10        1450           success
# 11        1558           success
# 12        1071           success
# 13         585           success
# 14       21122           success
# 15      170519           success
# 16        6095           success
# 17        2140           success
# 18        2878           success
# 19        6551           success
# 20        5336           success
# 21        6403           success
# 22        2678           success
# 23        2275           success
# 24        3546           success

# %%
# STEP 3: BUSINESS METADATA ENRICHMENT FUNCTION (Modern Approach)
# Instead of simple string matching, apply basic NLP for categorization.
# For high-quality production, you'd use an ML or LLM model endpoint here.

from transformers import pipeline

# For demonstration: Use a small zero-shot classification model.
# In a real pipeline, you should call a production LLM/ML endpoint or use a domain-specific model.
# The 'facebook/bart-large-mnli' model works for zero-shot/label classification tasks.
# You may swap with "typeform/distilbert-base-uncased-mnli" or another small MNLI model for lighter resource use.
# If working at scale or with large docs, consider using Ray Serve + LLM API instead.

zero_shot_classifier = pipeline(
    "zero-shot-classification",
    model="facebook/bart-large-mnli"  # Or another MNLI model if needed
)

# Define candidate classes (map to business categories)
CANDIDATE_LABELS = [
    "financial document",  # maps to 'finance'
    "legal document",      # maps to 'legal'
    "regulatory document", # maps to 'compliance'
    "client document",     # maps to 'client_services'
    "research document",   # maps to 'research'
    "general document"     # maps to 'general'
]

BUSINESS_CATEGORY_MAPPING = {
    "financial document":    ("financial_document", "finance"),
    "legal document":        ("legal_document", "legal"),
    "regulatory document":   ("regulatory_document", "compliance"),
    "client document":       ("client_document", "client_services"),
    "research document":     ("research_document", "research"),
    "general document":      ("general_document", "general"),
}


def enrich_business_metadata(record: Dict[str, Any]) -> Dict[str, Any]:
    """
    Uses zero-shot text classification to predict business category and assign processing priority.
    For production: Replace this with a call to your domain-tuned classifier or LLM endpoint.
    """

    file_size = record["file_size_bytes"]
    text = record.get("extracted_text", "") or ""
    filename = record.get("file_name", "")

    # Concatenate extracted text with filename for context, up to limit (to save inference cost)
    context_text = (filename + "\n\n" + text[:1000]).strip()  # Truncate to first 1000 chars for speed

    # Run zero-shot classification (useful even with short context)
    result = zero_shot_classifier(context_text, CANDIDATE_LABELS, multi_label=False)
    top_label = result["labels"][0] if result and "labels" in result and result["labels"] else "general document"

    doc_type, business_category = BUSINESS_CATEGORY_MAPPING.get(top_label, ("general_document", "general"))

    # Priority assignment using simple logic + NLP keyword search (feel free to LLM this too)
    lower_context = context_text.lower()
    if any(w in lower_context for w in ["urgent", "critical", "deadline"]):
        priority = "high"
        priority_score = 3
    elif any(w in lower_context for w in ["important", "quarterly", "annual"]):
        priority = "medium"
        priority_score = 2
    else:
        priority = "low"
        priority_score = 1
    
    return {
        **record,
        "document_type": doc_type,
        "business_category": business_category,
        "processing_priority": priority,
        "priority_score": priority_score,
        "estimated_pages": max(1, file_size // 50000),
        "processing_status": "classified"
    }


# Apply Business Metadata enrichment to all documents
print("Enriching with business metadata (using zero-shot NLP)...")

# Note: zero-shot and LLM models can be heavy;
# For fast local testing, decrease concurrency or use a smaller model, or replace with a production endpoint.

documents_with_metadata = documents_with_text.map(
    enrich_business_metadata,
    concurrency=4,  # Lower if running on small nodes (NLP models use RAM/CPU)
    num_cpus=1      # Each will load a model; set to available logical CPUs or 1 per task
)


# View a few documents with business classification added
documents_with_metadata.limit(5).to_pandas()
# Out:
# 2025-10-20 20:09:05,233	INFO logging.py:293 -- Registered dataset logger for dataset dataset_126_0
# 2025-10-20 20:09:05,239	INFO streaming_executor.py:159 -- Starting execution of Dataset dataset_126_0. Full logs are in /tmp/ray/session_2025-10-20_17-37-47_219984_2353/logs/ray-data
# 2025-10-20 20:09:05,239	INFO streaming_executor.py:160 -- Execution plan of Dataset dataset_126_0: InputDataBuffer[Input] -> TaskPoolMapOperator[ListFiles] -> LimitOperator[limit=5] -> TaskPoolMapOperator[ReadFiles] -> TaskPoolMapOperator[Map(process_file)] -> TaskPoolMapOperator[Map(enrich_business_metadata)]
# Enriching with business metadata...
# /home/ray/anaconda3/lib/python3.12/site-packages/ray/anyscale/data/_internal/cluster_autoscaler/productivity_calculator.py:174: RuntimeWarning: invalid value encountered in divide
#   gpu_fraction_per_op = (optimal_num_tasks_per_op * num_gpus_per_op) / np.sum(
# /home/ray/anaconda3/lib/python3.12/site-packages/ray/data/_internal/execution/operators/task_pool_map_operator.py:165: UserWarning: The maximum number of concurrent tasks for 'Map(process_file)' is set to 16, but the operator only received 1 input(s). This means that the operator can launch at most 1 task(s), which is less than the concurrency limit. You might be able to increase the number of concurrent tasks by configuring `override_num_blocks` earlier in the pipeline.
#   warnings.warn(
# /home/ray/anaconda3/lib/python3.12/site-packages/ray/data/_internal/execution/operators/task_pool_map_operator.py:165: UserWarning: The maximum number of concurrent tasks for 'Map(enrich_business_metadata)' is set to 16, but the operator only received 1 input(s). This means that the operator can launch at most 1 task(s), which is less than the concurrency limit. You might be able to increase the number of concurrent tasks by configuring `override_num_blocks` earlier in the pipeline.
#   warnings.warn(
# 2025-10-20 20:09:20,005	INFO streaming_executor.py:279 -- ✔️  Dataset dataset_126_0 execution finished in 14.76 seconds
#                             document_id  \
# 0  682d973d-a8c8-46ff-9b87-a84d10684f6c
# 1  d262b550-2dba-4977-ac73-cb2aa0915adf
# 2  57eef3e9-0c9c-4fb7-b95e-d083e84e55ac
# 3  703a2fd4-44c1-4703-8082-a78e8151dd98
# 4  6a2bab92-3d51-49d6-a7b6-c317a023d239
#
#                                            file_path  \
# 0  anyscale-rag-application/1000-docs/100G Networ...
# 1  anyscale-rag-application/1000-docs/Grand Centr...
# 2  anyscale-rag-application/1000-docs/Monitor_a_j...
# 3  anyscale-rag-application/1000-docs/Serial Orde...
# 4  anyscale-rag-application/1000-docs/jargn10-the...
#
#                                            file_name file_extension  \
# 0  100G Networking Technology Overview - Slides -...           .pdf
# 1  Grand Central Dispatch - FreeBSD Dev Summit (1...           .pdf
# 2                                 Monitor_a_job.docx          .docx
# 3  Serial Order - A Parallel Distributed Processi...           .pdf
# 4               jargn10-thejargonfilever00038gut.txt           .txt
#
#    file_size_bytes  file_size_mb         discovery_timestamp  \
# 0          1516903          1.45  2025-10-20T20:09:11.424457
# 1           130189          0.12  2025-10-20T20:09:11.788307
# 2           387461          0.37  2025-10-20T20:09:12.526486
# 3          2281776          2.18  2025-10-20T20:09:17.436733
# 4          1140873          1.09  2025-10-20T20:09:19.958387
#
#                                       extracted_text  text_length  word_count  \
# 0  100G Networking Technology Overview Christophe...         8996        1558
# 1  Grand Central Dispatch FreeBSD Devsummit Rober...         7831        1071
# 2  Monitor a job Anyscale jobs provides several t...         3296         585
# 3  SERIAL ORDER: A PARALLEL DISTRmUTED PROCESSING...       132375       21122
# 4  This Is The Project Gutenberg Etext of The Hac...      1065517      170519
#
#   extraction_status     document_type business_category processing_priority  \
# 0           success  general_document           general                 low
# 1           success  general_document           general                 low
# 2           success  general_document           general                 low
# 3           success  general_document           general                 low
# 4           success  general_document           general                 low
#
#    priority_score  estimated_pages processing_status
# 0               1               30        classified
# 1               1                2        classified
# 2               1                7        classified
# 3               1               45        classified
# 4               1               22        classified

# %%
# WHY AGGREGATIONS?
# Before writing to warehouse, understand what we're processing:
# - How many documents of each type?
# - What's the size distribution?
# - Which categories have the most content?

# AGGREGATION 1: Document Type Distribution
# Group by document_type and calculate statistics

doc_type_stats = documents_with_metadata.groupby("document_type").aggregate(
    Count(),  # How many documents of each type?
    Sum("file_size_bytes"),  # Total size per document type
    Mean("file_size_mb"),  # Average size per document type
    Max("estimated_pages")  # Largest document per type
)

# AGGREGATION 2: Business Category Analysis
# Understand the distribution across business categories
# This helps with warehouse partitioning strategy

category_stats = documents_with_metadata.groupby("business_category").aggregate(
    Count(),  # How many per category?
    Mean("priority_score"),  # Average priority per category
    Sum("file_size_mb")  # Total data volume per category
)

# %% [markdown]
# ## Step 2: Document Processing and Classification
#
# ### Text extraction and quality assessment

# %%
# STEP 4: QUALITY ASSESSMENT FUNCTION
# Evaluate document quality to filter out low-quality or problematic documents

def assess_document_quality(batch: pd.DataFrame) -> pd.DataFrame:
    """
    Assess document quality for data warehouse ingestion.
    
    BEGINNER NOTE:
    - Input: pandas DataFrame with multiple documents (a "batch")
    - Output: Same DataFrame with quality assessment columns added
    - Uses map_batches() for efficiency (process many docs at once)
    
    Why use map_batches() instead of map()?
    - Batching is more efficient for lightweight operations
    - Pandas DataFrame operations are optimized
    - Reduces overhead from function calls
    
    Explicitly use batch_format="pandas" 
    """
    quality_scores = np.zeros(len(batch), dtype=int)  # Numeric score (0-4)
    quality_ratings = []  # Text rating (high/medium/low)
    quality_issues_list = []  # List of issues found
    
    # We iterate through rows to apply business rules for quality
    # Each document gets a score from 0-4 based on quality criteria
    
    for idx, row in batch.iterrows():
        quality_score = 0
        quality_issues = []
        
        # CRITERION 1: File size check
        # Files smaller than 10KB might be empty or corrupt
        if row["file_size_mb"] > 0.01:  # More than 10KB
            quality_score += 1
        else:
            quality_issues.append("file_too_small")
        
        # CRITERION 2: Text length check
        # Documents should have meaningful text content
        if row["text_length"] > 100:  # At least 100 characters
            quality_score += 1
        else:
            quality_issues.append("insufficient_text")
        
        # CRITERION 3: Business relevance check
        # Classified documents are more valuable than unclassified
        if row["business_category"] != "general":
            quality_score += 1
        else:
            quality_issues.append("low_business_relevance")
        
        # CRITERION 4: Word count check
        # Documents should have substantial content
        if row["word_count"] > 20:  # At least 20 words
            quality_score += 1
        else:
            quality_issues.append("insufficient_content")
        
        # Score 4: All checks passed - high quality
        # Score 2-3: Some issues - medium quality
        # Score 0-1: Major issues - low quality
        quality_rating = "high" if quality_score >= 4 else "medium" if quality_score >= 2 else "low"
        
        # Store results for this document
        quality_scores[idx] = quality_score
        quality_ratings.append(quality_rating)
        quality_issues_list.append(json.dumps(quality_issues))  # Convert list to JSON string
    
    batch["quality_score"] = quality_scores
    batch["quality_rating"] = quality_ratings
    batch["quality_issues"] = quality_issues_list
    
    return batch


# Apply Quality Assessment to all documents

# Parameters:
#   - batch_format="pandas": Process as pandas DataFrame (easier than numpy arrays)
#   - num_cpus=0.25: Very low CPU (this is lightweight logic)
#   - batch_size=100: Process 100 documents at a time
#     * Larger batches = fewer function calls = better efficiency

quality_assessed_docs = documents_with_metadata.map_batches(
    assess_document_quality,
    batch_format="pandas",  # Ray Data pattern: explicit pandas format
    num_cpus=0.25,
    batch_size=100
)

# %% [markdown]
# ## Step 3: Text Chunking and Enrichment

# %%
# STEP 5: TEXT CHUNKING FUNCTION
# Split long documents into smaller chunks for downstream processing
# Why chunk? Many applications (LLMs, vector databases) have size limits

def create_text_chunks(record: Dict[str, Any]) -> List[Dict[str, Any]]:
    """
    Create overlapping text chunks from each document.
    
    BEGINNER NOTE:
    - Input: ONE document record with full text
    - Output: MULTIPLE chunk records (one document → many chunks)
    - This is a "one-to-many" transformation
    
    Why chunking?
    - LLM APIs have token limits (e.g., 4096 tokens)
    - Vector databases work better with smaller chunks
    - Enables more granular search and analysis
    
    Why overlapping chunks?
    - Preserves context across chunk boundaries
    - Prevents splitting important information
    - 150 character overlap means each chunk shares text with neighbors
    """
    text = record["extracted_text"]  # The full document text
    chunk_size = 1500  # Each chunk will be ~1500 characters
    overlap = 150  # Adjacent chunks share 150 characters
    
    # Why these numbers?
    # - 1500 chars ≈ 300-400 tokens (good for most LLM APIs)
    # - 150 char overlap ≈ 10% overlap (preserves context without too much redundancy)
    # - You can adjust these based on your use case
    
    # Let's create chunks of data by a sliding window
    chunks = []
    start = 0  # Starting position in the text
    chunk_index = 0  # Track which chunk number this is

    # There are many more advanced chunking methods, we'll use this simple technique for demo purposes
    
    # Loop until we've processed all the text
    while start < len(text):
        # Calculate end position (don't go past text length)
        end = min(start + chunk_size, len(text))
        
        # Extract this chunk's text
        chunk_text = text[start:end]
        
        # Create a new record for this chunk
        # It contains all the original document metadata PLUS chunk-specific data
        chunk_record = {
            **record,  # All original fields (document_id, business_category, etc.)
            "chunk_id": str(uuid.uuid4()),  # Unique ID for this specific chunk
            "chunk_index": chunk_index,  # Position in sequence (0, 1, 2, ...)
            "chunk_text": chunk_text,  # The actual text content of this chunk
            "chunk_length": len(chunk_text),  # Characters in this chunk
            "chunk_word_count": len(chunk_text.split())  # Words in this chunk
        }
        
        chunks.append(chunk_record)
        
        # If we've reached the end of the text, we're done
        if end >= len(text):
            break
        
        # Move to next chunk position (with overlap)
        # Example: If chunk_size=1500 and overlap=150
        # Chunk 1: chars 0-1500
        # Chunk 2: chars 1350-2850 (starts 150 before chunk 1 ended)
        # Chunk 3: chars 2700-4200 (starts 150 before chunk 2 ended)
        start = end - overlap
        chunk_index += 1

    # After creating all chunks, add how many chunks the document has
    # This helps with progress tracking and completeness checks
    for chunk in chunks:
        chunk["total_chunks"] = len(chunks)
    
    # Return the list of chunk records
    # Ray Data's flat_map() will automatically flatten this list
    return chunks


# Apply Text Chunking to all documents
# Use flat_map() for one-to-many transformations
# One document becomes multiple chunks
print("Creating text chunks...")

# Why flat_map() instead of map()?
#   - map(): One input → One output (document → document)
#   - flat_map(): One input → Many outputs (document → multiple chunks)
#   - flat_map() automatically "flattens" the list of chunks
#
# Example:
#   Input: 100 documents
#   Output: 10,000+ chunks (each document becomes ~100 chunks on average)
#
# Parameters:
#   - num_cpus=0.5: Moderate CPU usage (string slicing is lightweight)

chunked_documents = quality_assessed_docs.flat_map(
    create_text_chunks,
    num_cpus=0.5
)
# Out:
# Creating text chunks...

# %% [markdown]
# ## Step 4: Data Warehouse Schema and Output
#
# ### Create data warehouse schema

# %%
# STEP 6: DATA WAREHOUSE SCHEMA TRANSFORMATION
# Transform the raw processing data into a clean warehouse schema
# This is the "ETL" part - Extract (done), Transform (now), Load (next)

print("Creating data warehouse schema...")


# Get today's date in ISO format (YYYY-MM-DD)
# This will be used to partition the data by date in the warehouse
processing_date = datetime.now().isoformat()[:10]


# Data warehouses need clean, organized schemas
# We'll select only the columns we need and organize them logically
#
# Why not keep all columns?
# - Cleaner schema = easier queries
# - Less storage space
# - Better performance
# - Clear data contracts for downstream users

warehouse_dataset = chunked_documents.select_columns([
    # PRIMARY IDENTIFIERS: Keys for joining and relationships
    "document_id",  # Links all chunks from same document
    "chunk_id",     # Unique identifier for this specific chunk
    
    # DIMENSIONAL ATTRIBUTES: Categorical data for filtering/grouping
    # These are typically used in WHERE clauses and GROUP BY
    "business_category",      # finance, legal, compliance, etc.
    "document_type",          # financial_document, legal_document, etc.
    "file_extension",         # .pdf, .docx, etc.
    "quality_rating",         # high, medium, low
    "processing_priority",    # high, medium, low
    
    # FACT MEASURES: Numeric values for aggregation and analysis
    # These are typically used in SUM(), AVG(), COUNT(), etc.
    "file_size_mb",           # Document size
    "word_count",             # Total words in document
    "chunk_word_count",       # Words in this chunk
    "quality_score",          # Numeric quality (0-4)
    "priority_score",         # Numeric priority (1-3)
    "estimated_pages",        # Page count estimate
    "chunk_index",            # Position in document (0, 1, 2, ...)
    "total_chunks",           # How many chunks total
    
    # CONTENT FIELDS: The actual data payload
    "chunk_text",             # The text content (will rename this)
    "file_name",              # Original filename
    "file_path",              # S3 location
    
    # METADATA: Processing provenance and status tracking
    "discovery_timestamp",    # When was file discovered
    "extraction_status",      # success, error, unsupported_format
    "processing_status"       # classified, processed, etc.
])

# RENAME COLUMNS for data warehouse conventions
# "chunk_text" → "text_content" (more descriptive)
warehouse_dataset = warehouse_dataset.rename_columns({
    "chunk_text": "text_content"
})

# ADD PIPELINE METADATA: Constant columns for all records
# These columns are the same for every record in this run
# They help with data lineage and debugging

def add_pipeline_metadata(batch: pd.DataFrame) -> pd.DataFrame:
    """
    Add constant metadata columns to every record.
    
    BEGINNER NOTE:
    - These columns help track WHERE and WHEN data was processed
    - Useful for debugging and auditing
    - All records in this batch get the same values
    
    Why map_batches() for constants?
    - More efficient than adding columns one at a time
    - Can add multiple columns in one pass
    - Pandas operations are fast for this
    """
    batch["processing_date"] = processing_date     # When was this processed?
    batch["pipeline_version"] = "1.0"             # Which version of pipeline?
    batch["processing_engine"] = "ray_data"       # What tool processed it?
    return batch

# Apply metadata addition
# Parameters:
#   - batch_format="pandas": Use pandas for easy column addition
#   - num_cpus=0.1: Very low CPU (just adding constants)
#   - batch_size=10000: Large batches (this is very fast)

warehouse_dataset = warehouse_dataset.map_batches(
    add_pipeline_metadata,
    batch_format="pandas",
    num_cpus=0.1,
    batch_size=1000
)
# Out:
# Creating data warehouse schema...

# %% [markdown]
# ### Write to data warehouse with partitioning

# %%
# STEP 7: WRITE TO DATA WAREHOUSE - MAIN TABLE
# Save all processed chunks to Parquet format with partitioning
# This is the "Load" part of ETL

# /mnt/cluster_storage is a shared storage volume accessible by all workers
# In production, this would typically be:
# - S3: s3://your-bucket/warehouse/
# - Azure: abfs://container@account.dfs.core.windows.net/
# - GCS: gs://your-bucket/warehouse/
OUTPUT_WAREHOUSE_PATH = "/mnt/cluster_storage"

# WRITE MAIN TABLE with PARTITIONING
# write_parquet() is Ray Data's native way to save data

# Key parameters explained:

# partition_cols=["business_category", "processing_date"]
#   - Creates folder structure: business_category=finance/processing_date=2025-10-15/
#   - Enables efficient querying: "SELECT * FROM table WHERE business_category='finance'"
#   - Query engines (Spark, Presto, Athena) can skip entire partitions
#   - Example structure:
#       main_table/
#       ├── business_category=finance/
#       │   └── processing_date=2025-10-15/
#       │       ├── part-001.parquet
#       │       └── part-002.parquet
#       ├── business_category=legal/
#       │   └── processing_date=2025-10-15/
#       │       └── part-001.parquet
#       └── business_category=compliance/
#           └── processing_date=2025-10-15/
#               └── part-001.parquet

# compression="snappy"
#   - Compress files to save storage space (50-70% reduction)
#   - Snappy is fast and well-supported by all query engines
#   - Alternatives: gzip (higher compression), zstd (good balance)

# ray_remote_args={"num_cpus": 0.1}
#   - Writing to storage is I/O-bound, not CPU-bound
#   - Low CPU allocation allows more parallel writes

warehouse_dataset.write_parquet(
    f"{OUTPUT_WAREHOUSE_PATH}/main_table/",
    partition_cols=["business_category", "processing_date"],
    compression="snappy",
    ray_remote_args={"num_cpus": 0.1}
)

print("Main warehouse table written successfully")
# Out:
# 2025-10-20 20:09:20,615	INFO logging.py:293 -- Registered dataset logger for dataset dataset_137_0
# 2025-10-20 20:09:20,622	INFO streaming_executor.py:159 -- Starting execution of Dataset dataset_137_0. Full logs are in /tmp/ray/session_2025-10-20_17-37-47_219984_2353/logs/ray-data
# 2025-10-20 20:09:20,622	INFO streaming_executor.py:160 -- Execution plan of Dataset dataset_137_0: InputDataBuffer[Input] -> TaskPoolMapOperator[ListFiles] -> LimitOperator[limit=100] -> TaskPoolMapOperator[ReadFiles] -> TaskPoolMapOperator[Map(process_file)] -> TaskPoolMapOperator[Map(enrich_business_metadata)] -> TaskPoolMapOperator[MapBatches(assess_document_quality)] -> TaskPoolMapOperator[FlatMap(create_text_chunks)] -> TaskPoolMapOperator[Project] -> TaskPoolMapOperator[MapBatches(add_pipeline_metadata)->Write]
# /home/ray/anaconda3/lib/python3.12/site-packages/ray/anyscale/data/_internal/cluster_autoscaler/productivity_calculator.py:174: RuntimeWarning: invalid value encountered in divide
#   gpu_fraction_per_op = (optimal_num_tasks_per_op * num_gpus_per_op) / np.sum(
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P15' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P19' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P23' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P27' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P33' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P39' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P43' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P47' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P53' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P57' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P63' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P74' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P78' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P84' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P88' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P90' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P92' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P94' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P96' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P98' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P100' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P102' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P104' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P106' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P108' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P110' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P112' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P114' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P116' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P118' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P120' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P122' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P124' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P126' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P128' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P130' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P132' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P134' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P136' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P138' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P140' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P142' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P144' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P146' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P148' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P152' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P160' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P168' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P174' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P180' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P186' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P192' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P198' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P204' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P217' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P221' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P227' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P235' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P239' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P243' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P251' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P255' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P259' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P265' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P271' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P275' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P281' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P285' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P289' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P295' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P299' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P305' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P311' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P315' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P321' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P325' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P331' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P337' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P341' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P347' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P353' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P357' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P361' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P365' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P371' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P375' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P379' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P383' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P387' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P391' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P395' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P399' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P403' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P407' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P413' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P417' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P421' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P425' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P429' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P435' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P441' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P447' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P451' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P457' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P463' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P465' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P467' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P469' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P471' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P473' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P475' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P477' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P479' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P481' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P483' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P485' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P487' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P489' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P491' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P493' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P495' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P497' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P499' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P501' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P503' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P505' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P507' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P509' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P511' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P513' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P515' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P517' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P525' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P529' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P535' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P541' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P547' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P553' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P557' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P559' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P561' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P574' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P580' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P584' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P588' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P594' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P598' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P602' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P608' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P616' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P624' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P632' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P640' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P648' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P656' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P658' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P660' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P662' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P664' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P666' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P668' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P670' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P672' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P674' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P676' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P678' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P684' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P688' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P692' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P696' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P702' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P706' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P710' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P714' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P718' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P722' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P726' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P730' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P736' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P740' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P746' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P750' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P756' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P760' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P766' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P770' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P774' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P778' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P784' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P790' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P796' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P800' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P806' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P810' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P816' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P822' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P826' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P832' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P836' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P840' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P844' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P848' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P852' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P856' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P860' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P864' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P868' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P872' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P876' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P880' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P884' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P888' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P892' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P896' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P900' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P904' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P908' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P912' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P916' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P920' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P924' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P928' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P932' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P936' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P940' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P944' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P948' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P952' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P956' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P960' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P964' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P972' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P976' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P982' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P986' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P992' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P996' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P1000' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P1004' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P1010' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P1016' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P1020' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P1026' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P1030' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P1036' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P1040' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P1046' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P1052' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P1056' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P1060' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P1064' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P1068' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P1072' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P1076' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P1080' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P1084' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P1090' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P1094' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P1100' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P1106' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P1110' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P1114' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P1118' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P1124' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P1128' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P1132' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P1138' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P1144' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P1148' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P1154' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P1162' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P1166' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P1170' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P1174' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P1178' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P1184' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P1188' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P1192' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P1196' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P1200' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P1204' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P1208' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P1212' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P1216' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P1220' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P1224' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P1228' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P1232' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P1236' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P1240' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P1244' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P1248' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P1252' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P1256' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P1260' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P1264' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P1268' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P1272' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P1276' is an invalid float value
# (Map(process_file) pid=14642, ip=10.0.119.92) Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# (Map(process_file) pid=15079, ip=10.0.119.92) Cannot set gray non-stroke color because /'P2692' is an invalid float value [repeated 303x across cluster]
# (Map(process_file) pid=11844, ip=10.0.76.100) Cannot set gray non-stroke color because /'P152' is an invalid float value [repeated 528x across cluster]
# (Map(process_file) pid=15177, ip=10.0.93.255) Cannot set gray non-stroke color because /'P275' is an invalid float value [repeated 203x across cluster]
# 2025-10-20 20:09:50,703	WARNING issue_detector_manager.py:58 --
#
# Operator 'ReadFiles' uses 679.2MB of memory per task on average, but
# Ray only requests 0.0B per task at the start of the pipeline.
#
# To avoid out-of-memory errors, consider setting `memory=679.2MB` in
# the appropriate function or method call. (This might be unnecessary if
# the number of concurrent tasks is low.)
#
# To change the frequency of this warning, set
# `DataContext.get_current().issue_detectors_config.high_memory_detector_config.detection_time_interval_s`,
# or disable the warning by setting value to -1. (current value: 30)
#
# 2025-10-20 20:09:50,704	WARNING issue_detector_manager.py:67 -- To disable issue detection, run DataContext.get_current().issue_detectors_config.detectors = [].
# 2025-10-20 20:10:20,748	WARNING issue_detector_manager.py:58 --
#
# Operator 'ReadFiles' uses 679.2MB of memory per task on average, but
# Ray only requests 0.0B per task at the start of the pipeline.
#
# To avoid out-of-memory errors, consider setting `memory=679.2MB` in
# the appropriate function or method call. (This might be unnecessary if
# the number of concurrent tasks is low.)
#
# To change the frequency of this warning, set
# `DataContext.get_current().issue_detectors_config.high_memory_detector_config.detection_time_interval_s`,
# or disable the warning by setting value to -1. (current value: 30)
#
# 2025-10-20 20:10:20,749	WARNING issue_detector_manager.py:67 -- To disable issue detection, run DataContext.get_current().issue_detectors_config.detectors = [].
# 2025-10-20 20:10:35,085	INFO streaming_executor.py:279 -- ✔️  Dataset dataset_137_0 execution finished in 74.46 seconds
# 2025-10-20 20:10:35,110	INFO dataset.py:5134 -- Data sink Parquet finished. 5116 rows and 23.2MB data written.
# Main warehouse table written successfully

# %%
# STEP 8: CREATE BUSINESS-SPECIFIC DATASETS
# Create specialized datasets for specific business teams
# Each team gets only the data they need with relevant columns


# Example: Compliance Analytics Dataset
# Compliance team needs: document content, quality, and priority
# Priority matters for compliance review workflows

compliance_analytics = warehouse_dataset.filter(
    lambda row: row["business_category"] == "compliance"
).select_columns([
    "document_id",          # Link to main table
    "chunk_id",             # Unique chunk identifier
    "text_content",         # The actual text
    "quality_score",        # Data reliability
    "processing_priority",  # urgent/important/normal
    "processing_date"       # When processed
])

# Write to dedicated compliance folder
compliance_analytics.write_parquet(
    f"{OUTPUT_WAREHOUSE_PATH}/analytics/compliance/",
    partition_cols=["processing_date"],
    compression="snappy",
    ray_remote_args={"num_cpus": 0.1}
)
# Out:
# /home/ray/anaconda3/lib/python3.12/site-packages/ray/data/dataset.py:1557: UserWarning: Use 'expr' instead of 'fn' when possible for performant filters.
#   warnings.warn(
# 2025-10-20 20:10:35,277	INFO logging.py:293 -- Registered dataset logger for dataset dataset_142_0
# 2025-10-20 20:10:35,283	INFO streaming_executor.py:159 -- Starting execution of Dataset dataset_142_0. Full logs are in /tmp/ray/session_2025-10-20_17-37-47_219984_2353/logs/ray-data
# 2025-10-20 20:10:35,283	INFO streaming_executor.py:160 -- Execution plan of Dataset dataset_142_0: InputDataBuffer[Input] -> TaskPoolMapOperator[ListFiles] -> LimitOperator[limit=100] -> TaskPoolMapOperator[ReadFiles] -> TaskPoolMapOperator[Map(process_file)] -> TaskPoolMapOperator[Map(enrich_business_metadata)] -> TaskPoolMapOperator[MapBatches(assess_document_quality)] -> TaskPoolMapOperator[FlatMap(create_text_chunks)] -> TaskPoolMapOperator[Project] -> TaskPoolMapOperator[MapBatches(add_pipeline_metadata)] -> TaskPoolMapOperator[Filter(<lambda>)->Project] -> TaskPoolMapOperator[Write]
# /home/ray/anaconda3/lib/python3.12/site-packages/ray/anyscale/data/_internal/cluster_autoscaler/productivity_calculator.py:174: RuntimeWarning: invalid value encountered in divide
#   gpu_fraction_per_op = (optimal_num_tasks_per_op * num_gpus_per_op) / np.sum(
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P15' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P19' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P23' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P27' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P33' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P39' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P43' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P47' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P53' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P57' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P63' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P74' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P78' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P84' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P88' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P90' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P92' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P94' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P96' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P98' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P100' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P102' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P104' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P106' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P108' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P110' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P112' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P114' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P116' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P118' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P120' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P122' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P124' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P126' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P128' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P130' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P132' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P134' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P136' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P138' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P140' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P142' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P144' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P146' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P148' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P152' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P160' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P168' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P174' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P180' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P186' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P192' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P198' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P204' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P217' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P221' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P227' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P235' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P239' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P243' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P251' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P255' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P259' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P265' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P271' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P275' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P281' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P285' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P289' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P295' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P299' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P305' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P311' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P315' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P321' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P325' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P331' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P337' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P341' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P347' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P353' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P357' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P361' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P365' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P371' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P375' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P379' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P383' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P387' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P391' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P395' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P399' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P403' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P407' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P413' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P417' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P421' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P425' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P429' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P435' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P441' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P447' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P451' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P457' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P463' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P465' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P467' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P469' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P471' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P473' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P475' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P477' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P479' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P481' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P483' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P485' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P487' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P489' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P491' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P493' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P495' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P497' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P499' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P501' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P503' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P505' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P507' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P509' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P511' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P513' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P515' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P517' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P525' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P529' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P535' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P541' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P547' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P553' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P557' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P559' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P561' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P574' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P580' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P584' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P588' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P594' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P598' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P602' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P608' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P616' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P624' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P632' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P640' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P648' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P656' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P658' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P660' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P662' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P664' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P666' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P668' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P670' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P672' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P674' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P676' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P678' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P684' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P688' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P692' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P696' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P702' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P706' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P710' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P714' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P718' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P722' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P726' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P730' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P736' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P740' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P746' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P750' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P756' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P760' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P766' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P770' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P774' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P778' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P784' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P790' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P796' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P800' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P806' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P810' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P816' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P822' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P826' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P832' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P836' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P840' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P844' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P848' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P852' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P856' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P860' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P864' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P868' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P872' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P876' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P880' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P884' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P888' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P892' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P896' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P900' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P904' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P908' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P912' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P916' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P920' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P924' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P928' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P932' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P936' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P940' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P944' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P948' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P952' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P956' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P960' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P964' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P972' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P976' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P982' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P986' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P992' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P996' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P1000' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P1004' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P1010' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P1016' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P1020' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P1026' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P1030' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P1036' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P1040' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P1046' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P1052' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P1056' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P1060' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P1064' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P1068' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P1072' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P1076' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P1080' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P1084' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P1090' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P1094' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P1100' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P1106' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P1110' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P1114' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P1118' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P1124' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P1128' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P1132' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P1138' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P1144' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P1148' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P1154' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P1162' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P1166' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P1170' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P1174' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P1178' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P1184' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P1188' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P1192' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P1196' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P1200' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P1204' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P1208' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P1212' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P1216' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P1220' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P1224' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P1228' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P1232' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P1236' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P1240' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P1244' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P1248' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P1252' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P1256' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P1260' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P1264' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P1268' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P1272' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P1276' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P1280' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P1284' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P1288' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P1292' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P1296' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P1300' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P1304' is an invalid float value
# (Map(process_file) pid=14641, ip=10.0.119.92) Cannot set gray non-stroke color because /'P2644' is an invalid float value [repeated 284x across cluster]
# (Map(process_file) pid=12111, ip=10.0.92.64) Cannot set gray non-stroke color because /'P275' is an invalid float value [repeated 574x across cluster]
# (Map(process_file) pid=13718, ip=10.0.90.35) Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# (Map(process_file) pid=15321, ip=10.0.90.35) Cannot set gray non-stroke color because /'P217' is an invalid float value [repeated 172x across cluster]
# 2025-10-20 20:11:05,384	WARNING issue_detector_manager.py:58 --
#
# Operator 'ReadFiles' uses 728.6MB of memory per task on average, but
# Ray only requests 0.0B per task at the start of the pipeline.
#
# To avoid out-of-memory errors, consider setting `memory=728.6MB` in
# the appropriate function or method call. (This might be unnecessary if
# the number of concurrent tasks is low.)
#
# To change the frequency of this warning, set
# `DataContext.get_current().issue_detectors_config.high_memory_detector_config.detection_time_interval_s`,
# or disable the warning by setting value to -1. (current value: 30)
#
# 2025-10-20 20:11:05,385	WARNING issue_detector_manager.py:67 -- To disable issue detection, run DataContext.get_current().issue_detectors_config.detectors = [].
# 2025-10-20 20:11:35,412	WARNING issue_detector_manager.py:58 --
#
# Operator 'ReadFiles' uses 728.6MB of memory per task on average, but
# Ray only requests 0.0B per task at the start of the pipeline.
#
# To avoid out-of-memory errors, consider setting `memory=728.6MB` in
# the appropriate function or method call. (This might be unnecessary if
# the number of concurrent tasks is low.)
#
# To change the frequency of this warning, set
# `DataContext.get_current().issue_detectors_config.high_memory_detector_config.detection_time_interval_s`,
# or disable the warning by setting value to -1. (current value: 30)
#
# 2025-10-20 20:11:35,413	WARNING issue_detector_manager.py:67 -- To disable issue detection, run DataContext.get_current().issue_detectors_config.detectors = [].
# 2025-10-20 20:11:59,398	INFO streaming_executor.py:279 -- ✔️  Dataset dataset_142_0 execution finished in 84.11 seconds
# 2025-10-20 20:11:59,421	INFO dataset.py:5134 -- Data sink Parquet finished. 0 rows and 0.0B data written.

# %% [markdown]
# ### Create analytics summary tables

# %%
# STEP 9: CREATE ANALYTICS SUMMARY TABLES
# Pre-compute common aggregations for fast dashboard queries
# Summary tables = faster analytics queries


# SUMMARY TABLE 1: Processing Metrics by Category and Date

# Answer questions like:
# - How many documents processed per category per day?
# - What's the total data volume per category?
# - What's the average document quality by category?

# This summary makes dashboard queries instant instead of scanning all data

# groupby() groups data by multiple columns
# aggregate() calculates statistics for each group

processing_metrics = warehouse_dataset.groupby(["business_category", "processing_date"]).aggregate(
    Count(),                    # How many chunks per category+date?
    Sum("file_size_mb"),        # Total data volume
    Mean("word_count"),         # Average document size
    Mean("quality_score")       # Average quality
)

# Write summary table
# Smaller than main table, so queries are very fast
processing_metrics.write_parquet(
    f"{OUTPUT_WAREHOUSE_PATH}/summaries/processing_metrics/",
    partition_cols=["processing_date"],
    compression="snappy",
    ray_remote_args={"num_cpus": 0.1}
)
# Out:
# 2025-10-20 20:11:59,556	INFO logging.py:293 -- Registered dataset logger for dataset dataset_147_0
# 2025-10-20 20:11:59,563	INFO streaming_executor.py:159 -- Starting execution of Dataset dataset_147_0. Full logs are in /tmp/ray/session_2025-10-20_17-37-47_219984_2353/logs/ray-data
# 2025-10-20 20:11:59,564	INFO streaming_executor.py:160 -- Execution plan of Dataset dataset_147_0: InputDataBuffer[Input] -> TaskPoolMapOperator[ListFiles] -> LimitOperator[limit=100] -> TaskPoolMapOperator[ReadFiles] -> TaskPoolMapOperator[Map(process_file)] -> TaskPoolMapOperator[Map(enrich_business_metadata)] -> TaskPoolMapOperator[MapBatches(assess_document_quality)] -> TaskPoolMapOperator[FlatMap(create_text_chunks)] -> TaskPoolMapOperator[Project] -> TaskPoolMapOperator[MapBatches(add_pipeline_metadata)] -> HashAggregateOperator[HashAggregate(key_columns=('business_category', 'processing_date'), num_partitions=200)] -> TaskPoolMapOperator[Write]
# /home/ray/anaconda3/lib/python3.12/site-packages/ray/anyscale/data/_internal/cluster_autoscaler/productivity_calculator.py:174: RuntimeWarning: invalid value encountered in divide
#   gpu_fraction_per_op = (optimal_num_tasks_per_op * num_gpus_per_op) / np.sum(
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P15' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P19' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P23' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P27' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P33' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P39' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P43' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P47' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P53' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P57' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P63' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P74' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P78' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P84' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P88' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P90' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P92' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P94' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P96' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P98' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P100' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P102' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P104' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P106' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P108' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P110' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P112' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P114' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P116' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P118' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P120' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P122' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P124' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P126' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P128' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P130' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P132' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P134' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P136' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P138' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P140' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P142' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P144' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P146' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P148' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P152' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P160' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P168' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P174' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P180' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P186' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P192' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P198' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P204' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P217' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P221' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P227' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P235' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P239' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P243' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P251' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P255' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P259' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P265' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P271' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P275' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P281' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P285' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P289' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P295' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P299' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P305' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P311' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P315' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P321' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P325' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P331' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P337' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P341' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P347' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P353' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P357' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P361' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P365' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P371' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P375' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P379' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P383' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P387' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P391' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P395' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P399' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P403' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P407' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P413' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P417' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P421' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P425' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P429' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P435' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P441' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P447' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P451' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P457' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P463' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P465' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P467' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P469' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P471' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P473' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P475' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P477' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P479' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P481' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P483' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P485' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P487' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P489' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P491' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P493' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P495' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P497' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P499' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P501' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P503' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P505' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P507' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P509' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P511' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P513' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P515' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P517' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P525' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P529' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P535' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P541' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P547' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P553' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P557' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P559' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P561' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P574' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P580' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P584' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P588' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P594' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P598' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P602' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P608' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P616' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P624' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P632' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P640' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P648' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P656' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P658' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P660' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P662' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P664' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P666' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P668' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P670' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P672' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P674' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P676' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P678' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P684' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P688' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P692' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P696' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P702' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P706' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P710' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P714' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P718' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P722' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P726' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P730' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P736' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P740' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P746' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P750' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P756' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P760' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P766' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P770' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P774' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P778' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P784' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P790' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P796' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P800' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P806' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P810' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P816' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P822' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P826' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P832' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P836' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P840' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P844' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P848' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P852' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P856' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P860' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P864' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P868' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P872' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P876' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P880' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P884' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P888' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P892' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P896' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P900' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P904' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P908' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P912' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P916' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P920' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P924' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P928' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P932' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P936' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P940' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P944' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P948' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P952' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P956' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P960' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P964' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P972' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P976' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P982' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P986' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P992' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P996' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P1000' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P1004' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P1010' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P1016' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P1020' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P1026' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P1030' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P1036' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P1040' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P1046' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P1052' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P1056' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P1060' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P1064' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P1068' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P1072' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P1076' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P1080' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P1084' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P1090' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P1094' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P1100' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P1106' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P1110' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P1114' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P1118' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P1124' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P1128' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P1132' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P1138' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P1144' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P1148' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P1154' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P1162' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P1166' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P1170' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P1174' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P1178' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P1184' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P1188' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P1192' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P1196' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P1200' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P1204' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P1208' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P1212' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P1216' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P1220' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P1224' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P1228' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P1232' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P1236' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P1240' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P1244' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P1248' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P1252' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P1256' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P1260' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P1264' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P1268' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P1272' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P1276' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P1280' is an invalid float value
# (Map(process_file) pid=15079, ip=10.0.119.92) Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P1284' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P1288' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P1292' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P1296' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P1300' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P1304' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P1308' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P1312' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P1316' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P1318' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P1320' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P1322' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P1324' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P1326' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P1328' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P1330' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P1334' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P1342' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P1350' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P1354' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P1358' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P1366' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P1370' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P1374' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P1383' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P1385' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P1387' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P2459' is an invalid float value [repeated 224x across cluster]
# (Map(process_file) pid=13145, ip=10.0.65.247) Cannot set gray non-stroke color because /'P274' is an invalid float value [repeated 648x across cluster]
# 2025-10-20 20:12:29,747	WARNING issue_detector_manager.py:58 --
#
# Operator 'ReadFiles' uses 768.8MB of memory per task on average, but
# Ray only requests 0.0B per task at the start of the pipeline.
#
# To avoid out-of-memory errors, consider setting `memory=768.8MB` in
# the appropriate function or method call. (This might be unnecessary if
# the number of concurrent tasks is low.)
#
# To change the frequency of this warning, set
# `DataContext.get_current().issue_detectors_config.high_memory_detector_config.detection_time_interval_s`,
# or disable the warning by setting value to -1. (current value: 30)
#
# 2025-10-20 20:12:29,748	WARNING issue_detector_manager.py:67 -- To disable issue detection, run DataContext.get_current().issue_detectors_config.detectors = [].
# 2025-10-20 20:12:59,854	WARNING issue_detector_manager.py:58 --
#
# Operator 'ReadFiles' uses 768.8MB of memory per task on average, but
# Ray only requests 0.0B per task at the start of the pipeline.
#
# To avoid out-of-memory errors, consider setting `memory=768.8MB` in
# the appropriate function or method call. (This might be unnecessary if
# the number of concurrent tasks is low.)
#
# To change the frequency of this warning, set
# `DataContext.get_current().issue_detectors_config.high_memory_detector_config.detection_time_interval_s`,
# or disable the warning by setting value to -1. (current value: 30)
#
# 2025-10-20 20:12:59,855	WARNING issue_detector_manager.py:67 -- To disable issue detection, run DataContext.get_current().issue_detectors_config.detectors = [].
# 2025-10-20 20:13:14,783	INFO streaming_executor.py:279 -- ✔️  Dataset dataset_147_0 execution finished in 75.22 seconds
# 2025-10-20 20:13:14,907	INFO dataset.py:5134 -- Data sink Parquet finished. 2 rows and 115.0B data written.

# %%
# SUMMARY TABLE 2: Quality Distribution
# Answer questions like:
# - What percentage of documents are high/medium/low quality?
# - Which categories have the highest quality scores?
# - How does quality correlate with document size?

# This helps identify data quality issues by category

quality_distribution = warehouse_dataset.groupby(["quality_rating", "business_category"]).aggregate(
    Count(),                        # How many per quality+category?
    Mean("word_count"),             # Average document size by quality
    Mean("chunk_word_count")        # Average chunk size by quality
)

# Write quality summary
# Used for quality monitoring dashboards

quality_distribution.write_parquet(
    f"{OUTPUT_WAREHOUSE_PATH}/summaries/quality_distribution/",
    compression="snappy",
    ray_remote_args={"num_cpus": 0.1}
)
# Out:
# 2025-10-20 20:13:15,036	INFO logging.py:293 -- Registered dataset logger for dataset dataset_152_0
# 2025-10-20 20:13:15,045	INFO streaming_executor.py:159 -- Starting execution of Dataset dataset_152_0. Full logs are in /tmp/ray/session_2025-10-20_17-37-47_219984_2353/logs/ray-data
# 2025-10-20 20:13:15,045	INFO streaming_executor.py:160 -- Execution plan of Dataset dataset_152_0: InputDataBuffer[Input] -> TaskPoolMapOperator[ListFiles] -> LimitOperator[limit=100] -> TaskPoolMapOperator[ReadFiles] -> TaskPoolMapOperator[Map(process_file)] -> TaskPoolMapOperator[Map(enrich_business_metadata)] -> TaskPoolMapOperator[MapBatches(assess_document_quality)] -> TaskPoolMapOperator[FlatMap(create_text_chunks)] -> TaskPoolMapOperator[Project] -> TaskPoolMapOperator[MapBatches(add_pipeline_metadata)] -> HashAggregateOperator[HashAggregate(key_columns=('quality_rating', 'business_category'), num_partitions=200)] -> TaskPoolMapOperator[Write]
# /home/ray/anaconda3/lib/python3.12/site-packages/ray/anyscale/data/_internal/cluster_autoscaler/productivity_calculator.py:174: RuntimeWarning: invalid value encountered in divide
#   gpu_fraction_per_op = (optimal_num_tasks_per_op * num_gpus_per_op) / np.sum(
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P15' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P19' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P23' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P27' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P33' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P39' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P43' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P47' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P53' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P57' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P63' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P74' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P78' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P84' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P88' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P90' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P92' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P94' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P96' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P98' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P100' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P102' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P104' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P106' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P108' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P110' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P112' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P114' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P116' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P118' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P120' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P122' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P124' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P126' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P128' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P130' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P132' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P134' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P136' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P138' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P140' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P142' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P144' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P146' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P148' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P152' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P160' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P168' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P174' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P180' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P186' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P192' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P198' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P204' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P217' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P221' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P227' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P235' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P239' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P243' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P251' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P255' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P259' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P265' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P271' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P275' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P281' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P285' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P289' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P295' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P299' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P305' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P311' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P315' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P321' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P325' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P331' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P337' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P341' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P347' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P353' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P357' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P361' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P365' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P371' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P375' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P379' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P383' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P387' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P391' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P395' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P399' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P403' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P407' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P413' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P417' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P421' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P425' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P429' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P435' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P441' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P447' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P451' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P457' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P463' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P465' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P467' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P469' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P471' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P473' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P475' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P477' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P479' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P481' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P483' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P485' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P487' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P489' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P491' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P493' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P495' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P497' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P499' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P501' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P503' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P505' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P507' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P509' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P511' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P513' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P515' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P517' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P525' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P529' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P535' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P541' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P547' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P553' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P557' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P559' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P561' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P574' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P580' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P584' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P588' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P594' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P598' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P602' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P608' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P616' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P624' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P632' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P640' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P648' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P656' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P658' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P660' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P662' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P664' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P666' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P668' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P670' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P672' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P674' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P676' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P678' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P684' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P688' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P692' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P696' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P702' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P706' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P710' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P714' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P718' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P722' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P726' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P730' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P736' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P740' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P746' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P750' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P756' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P760' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P766' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P770' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P774' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P778' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P784' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P790' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P796' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P800' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P806' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P810' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P816' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P822' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P826' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P832' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P836' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P840' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P844' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P848' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P852' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P856' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P860' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P864' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P868' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P872' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P876' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P880' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P884' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P888' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P892' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P896' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P900' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P904' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P908' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P912' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P916' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P920' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P924' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P928' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P932' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P936' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P940' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P944' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P948' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P952' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P956' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P960' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P964' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P972' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P976' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P982' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P986' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P992' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P996' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P1000' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P1004' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P1010' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P1016' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P1020' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P1026' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P1030' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P1036' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P1040' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P1046' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P1052' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P1056' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P1060' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P1064' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P1068' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P1072' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P1076' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P1080' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P1084' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P1090' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P1094' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P1100' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P1106' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P1110' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P1114' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P1118' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P1124' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P1128' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P1132' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P1138' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P1144' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P1148' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P1154' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P1162' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P1166' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P1170' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P1174' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P1178' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P1184' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P1188' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P1192' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P1196' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P1200' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P1204' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P1208' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P1212' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P1216' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P1220' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P1224' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P1228' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P1232' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P1236' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P1240' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P1244' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P1248' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P1252' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P1256' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P1260' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P1264' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P1268' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P1272' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P1276' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P1280' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P1284' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P1288' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P1292' is an invalid float value
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P1296' is an invalid float value
# (Map(process_file) pid=13504, ip=10.0.110.204) Could get FontBBox from font descriptor because None cannot be parsed as 4 floats
# (Map(process_file) pid=11766, ip=10.0.68.173) Cannot set gray non-stroke color because /'P2644' is an invalid float value [repeated 286x across cluster]
# (Map(process_file) pid=15206, ip=10.0.76.198) Cannot set gray non-stroke color because /'P290' is an invalid float value [repeated 597x across cluster]
# (Map(process_file) pid=16754, ip=10.0.110.204) Cannot set gray non-stroke color because /'P332' is an invalid float value [repeated 160x across cluster]
# 2025-10-20 20:13:45,120	WARNING issue_detector_manager.py:58 --
#
# Operator 'ReadFiles' uses 762.1MB of memory per task on average, but
# Ray only requests 0.0B per task at the start of the pipeline.
#
# To avoid out-of-memory errors, consider setting `memory=762.1MB` in
# the appropriate function or method call. (This might be unnecessary if
# the number of concurrent tasks is low.)
#
# To change the frequency of this warning, set
# `DataContext.get_current().issue_detectors_config.high_memory_detector_config.detection_time_interval_s`,
# or disable the warning by setting value to -1. (current value: 30)
#
# 2025-10-20 20:13:45,121	WARNING issue_detector_manager.py:67 -- To disable issue detection, run DataContext.get_current().issue_detectors_config.detectors = [].
# 2025-10-20 20:14:15,204	WARNING issue_detector_manager.py:58 --
#
# Operator 'ReadFiles' uses 762.1MB of memory per task on average, but
# Ray only requests 0.0B per task at the start of the pipeline.
#
# To avoid out-of-memory errors, consider setting `memory=762.1MB` in
# the appropriate function or method call. (This might be unnecessary if
# the number of concurrent tasks is low.)
#
# To change the frequency of this warning, set
# `DataContext.get_current().issue_detectors_config.high_memory_detector_config.detection_time_interval_s`,
# or disable the warning by setting value to -1. (current value: 30)
#
# 2025-10-20 20:14:15,205	WARNING issue_detector_manager.py:67 -- To disable issue detection, run DataContext.get_current().issue_detectors_config.detectors = [].
# 2025-10-20 20:14:30,803	INFO streaming_executor.py:279 -- ✔️  Dataset dataset_152_0 execution finished in 75.75 seconds
# 2025-10-20 20:14:30,921	INFO dataset.py:5134 -- Data sink Parquet finished. 2 rows and 89.0B data written.

# %% [markdown]
# ## Verification and Summary
#
# After writing data to the warehouse, it's important to verify everything worked correctly. This section demonstrates:
#
# **Why verification matters:**
# - Ensures data was written successfully
# - Validates record counts match expectations
# - Confirms schema is correct
# - Provides sample data for visual inspection
#
# **What we'll verify:**
# 1. Main table record count (should be 10,000+ chunks)
# 2. Summary tables exist and have data
# 3. Schema includes all expected columns
# 4. Sample records look correct
#
# ### Verify data warehouse outputs

# %%
# STEP 10: VERIFY DATA WAREHOUSE OUTPUT
# Always verify your data pipeline worked correctly
# This is a critical production practice
print("Verifying data warehouse integration...")

# Use Ray Data's read_parquet() to read what we just wrote
# This verifies:
# 1. Files were written successfully
# 2. Partitioning works correctly
# 3. Data can be read back (no corruption)
#
# Ray Data will automatically discover all partitions:
# - main_table/business_category=finance/processing_date=2025-10-15/*.parquet
# - main_table/business_category=legal/processing_date=2025-10-15/*.parquet
# - etc.
main_table_verify = ray.data.read_parquet(
    f"{OUTPUT_WAREHOUSE_PATH}/main_table/",
    ray_remote_args={"num_cpus": 0.025}  # Low CPU for reading
)

# Verify our aggregated metrics tables also wrote successfully
metrics_verify = ray.data.read_parquet(
    f"{OUTPUT_WAREHOUSE_PATH}/summaries/processing_metrics/",
    ray_remote_args={"num_cpus": 0.025}
)

print(f"Data warehouse verification:")
print(f"  Main table records: {main_table_verify.count():,}")
print(f"  Processing metrics: {metrics_verify.count():,}")
print(f"  Schema compatibility: Verified")
# Out:
# 2025-10-20 20:14:31,038	INFO logging.py:293 -- Registered dataset logger for dataset dataset_156_0
# 2025-10-20 20:14:31,042	INFO streaming_executor.py:159 -- Starting execution of Dataset dataset_156_0. Full logs are in /tmp/ray/session_2025-10-20_17-37-47_219984_2353/logs/ray-data
# 2025-10-20 20:14:31,042	INFO streaming_executor.py:160 -- Execution plan of Dataset dataset_156_0: InputDataBuffer[Input] -> TaskPoolMapOperator[ListFiles] -> TaskPoolMapOperator[MapBatches(count_rows)]
# Verifying data warehouse integration...
# Data warehouse verification:
# /home/ray/anaconda3/lib/python3.12/site-packages/ray/anyscale/data/_internal/cluster_autoscaler/productivity_calculator.py:174: RuntimeWarning: invalid value encountered in divide
#   gpu_fraction_per_op = (optimal_num_tasks_per_op * num_gpus_per_op) / np.sum(
# 2025-10-20 20:14:31,388	INFO streaming_executor.py:279 -- ✔️  Dataset dataset_156_0 execution finished in 0.35 seconds
# 2025-10-20 20:14:31,395	INFO logging.py:293 -- Registered dataset logger for dataset dataset_157_0
# 2025-10-20 20:14:31,399	INFO streaming_executor.py:159 -- Starting execution of Dataset dataset_157_0. Full logs are in /tmp/ray/session_2025-10-20_17-37-47_219984_2353/logs/ray-data
# 2025-10-20 20:14:31,400	INFO streaming_executor.py:160 -- Execution plan of Dataset dataset_157_0: InputDataBuffer[Input] -> TaskPoolMapOperator[ListFiles] -> TaskPoolMapOperator[MapBatches(count_rows)]
# 2025-10-20 20:14:31,507	INFO streaming_executor.py:279 -- ✔️  Dataset dataset_157_0 execution finished in 0.11 seconds
#   Main table records: 115,977
#   Processing metrics: 16
#   Schema compatibility: Verified

# %%
# INSPECT SAMPLE DATA

# take(10) gets first 10 records for manual inspection
# This helps catch issues like:
# - Wrong data types
# - Missing fields
# - Incorrect values
# - Encoding problems
samples = main_table_verify.take(10)

# Display key fields from each sample record
for i, record in enumerate(samples):
    # Show abbreviated document ID (first 8 characters)
    doc_id = record['document_id'][:8]
    category = record['business_category']
    words = record['word_count']
    quality = record['quality_rating']
    
    print(f"\t{i+1}. Doc: {doc_id}, Category: {category}, Words: {words}, Quality: {quality}")
# Out:
# 2025-10-20 20:14:31,624	INFO logging.py:293 -- Registered dataset logger for dataset dataset_158_0
# 2025-10-20 20:14:31,629	INFO streaming_executor.py:159 -- Starting execution of Dataset dataset_158_0. Full logs are in /tmp/ray/session_2025-10-20_17-37-47_219984_2353/logs/ray-data
# 2025-10-20 20:14:31,630	INFO streaming_executor.py:160 -- Execution plan of Dataset dataset_158_0: InputDataBuffer[Input] -> TaskPoolMapOperator[ListFiles] -> TaskPoolMapOperator[ReadFiles] -> LimitOperator[limit=10]
# 2025-10-20 20:14:32,076	INFO streaming_executor.py:279 -- ✔️  Dataset dataset_158_0 execution finished in 0.45 seconds
# 	1. Doc: 9278d4de, Category: compliance, Words: 6925, Quality: high
# 	2. Doc: 9278d4de, Category: compliance, Words: 6925, Quality: high
# 	3. Doc: 9278d4de, Category: compliance, Words: 6925, Quality: high
# 	4. Doc: 9278d4de, Category: compliance, Words: 6925, Quality: high
# 	5. Doc: 9278d4de, Category: compliance, Words: 6925, Quality: high
# 	6. Doc: 9278d4de, Category: compliance, Words: 6925, Quality: high
# 	7. Doc: 9278d4de, Category: compliance, Words: 6925, Quality: high
# 	8. Doc: 9278d4de, Category: compliance, Words: 6925, Quality: high
# 	9. Doc: 9278d4de, Category: compliance, Words: 6925, Quality: high
# 	10. Doc: 9278d4de, Category: compliance, Words: 6925, Quality: high

# %% [markdown]
# ## Summary and Next Steps
#
# Congratulations! You've built a complete end-to-end document ingestion pipeline using Ray Data. Let's review what you learned and where to go from here.
#
# ### What You Built
#
# **Complete ETL Pipeline**: Extract → Transform → Load
# 1. **Extract**: Read 100 documents from S3 data lake
# 2. **Transform**: Extract text, classify, assess quality, create chunks
# 3. **Load**: Write to partitioned data warehouse with analytics tables
#
# **Final Output**: From raw documents to structured warehouse
# - **Main table**: 10,000+ text chunks ready for analysis
# - **Business datasets**: Finance and compliance specific views
# - **Summary tables**: Pre-computed metrics for dashboards
# - **Partitioned storage**: Optimized for query performance
#
# ### Ray Data Operations You Used
#
# This pipeline demonstrated all major Ray Data operations:
#
# | Operation | Purpose | When to Use |
# |-----------|---------|-------------|
# | `read_binary_files()` | Load documents from S3/storage | Reading PDFs, images, any binary files |
# | `map()` | Transform each record individually | Variable-size processing, I/O-bound tasks |
# | `map_batches()` | Transform records in batches | Batch-optimized operations, ML inference |
# | `flat_map()` | One-to-many transformations | Chunking, splitting, exploding data |
# | `filter()` | Keep/remove records | Selecting subsets, data quality filtering |
# | `select_columns()` | Choose specific fields | Schema projection, reducing data size |
# | `rename_columns()` | Change column names | Schema standardization |
# | `groupby().aggregate()` | Calculate statistics | Analytics, metrics, summaries |
# | `write_parquet()` | Save to warehouse | Final output, checkpointing |
#
# ### Key Concepts for Beginners
#
# **1. Distributed Processing**
# - Your code runs on a cluster of machines (not just one)
# - Ray Data automatically distributes work across workers
# - Each function (process_file, assess_quality) runs in parallel
# - 100 documents processed simultaneously = 100x faster
#
# **2. Lazy Evaluation**
# - Operations like `map()` and `filter()` don't execute immediately
# - Ray builds a plan and optimizes it
# - Execution happens when you call `write_parquet()`, `count()`, or `take()`
# - This allows Ray to optimize the entire pipeline
#
# **3. Resource Management**
# - `num_cpus`: How many CPU cores per task
# - `concurrency`: How many tasks run in parallel
# - `batch_size`: How many records per batch
# - Balance these based on your workload
#
# **4. Partitioning Strategy**
# - Partitions = folders organized by column values
# - `partition_cols=["business_category", "processing_date"]`
# - Query engines skip entire folders when filtering
# - Enables efficient query performance by reducing data scanned
#
# ### Implementation Patterns Applied
#
# **Code Organization**:
# - Separate functions for each processing stage
# - Clear docstrings explaining purpose
# - Type hints for inputs and outputs
# - Comments explaining "why" not just "what"
#
# **Ray Data Implementation Patterns**:
# - Use `batch_format="pandas"` for clarity
# - Process text early (don't pass binary through pipeline)
# - Appropriate resource allocation per operation type
# - Partition writes for query optimization
# - Use native Ray Data operations (not custom code)
#
# **Data Engineering Patterns**:
# - Immediate text extraction (reduces memory)
# - Separate classification stage (easier debugging)
# - Quality assessment (data validation)
# - Schema transformation (clean warehouse schema)
# - Verification step (always check output)
#
# ### Production Recommendations
#
# **Scaling to Production:**
#
# 1. **Remove the `.limit(100)` to process full dataset**
#    - Currently processing 100 docs for demo
#    - Remove this to process millions of documents
#    - No code changes needed, just remove one line
#
# 2. **Tune resource parameters for your cluster**
#    ```python
#    # For larger clusters, increase parallelism:
#    concurrency=50     # More parallel tasks
#    batch_size=5000    # Larger batches
#    num_cpus=2         # More CPU per task
#    ```
#
# 3. **Add error handling and retry logic**
#    ```python
#    # For production, catch specific errors:
#    try:
#        elements = partition(file=stream)
#    except CorruptedFileError:
#        # Log and skip
#    except TimeoutError:
#        # Retry with backoff
#    ```
#
# 4. **Monitor with Ray Dashboard**
#    - View real-time progress
#    - Check resource utilization
#    - Identify bottlenecks
#    - Debug failures
#
# 5. **Implement incremental processing**
#    ```python
#    # Only process new documents:
#    new_docs = all_docs.filter(
#        lambda row: row["processing_date"] > last_run_date
#    )
#    ```
#
# 6. **Add data quality checks**
#    - Validate schema before writing
#    - Check for null values
#    - Verify foreign key relationships
#    - Monitor quality metrics over time
#
# ### What You Learned
#
# **Ray Data Fundamentals**:
# - How to read from cloud storage (S3)
# - Distributed data processing patterns
# - Batch vs. row-based operations
# - Resource management and tuning
# - Writing to data warehouses
#
# **Data Engineering Skills**:
# - ETL pipeline design
# - Document processing at scale
# - Quality assessment strategies
# - Data warehouse schema design
# - Partitioning for performance
#
# **Production Practices**:
# - Verification and testing
# - Error handling approaches
# - Resource optimization
# - Monitoring and debugging
# - Scalability considerations
#
# ### Next Steps
#
# **Extend This Pipeline:**
# 1. Add LLM-based content analysis (replace pattern matching)
# 2. Implement named entity recognition (NER)
# 3. Add sentiment analysis for customer documents
# 4. Create vector embeddings for semantic search
# 5. Integrate with Delta Lake or Apache Iceberg
#
# **Learn More Ray Data:**
# - **Batch Inference**: Process documents with ML models
# - **Data Quality**: Advanced validation patterns
# - **Performance Tuning**: Optimize for your workload
# - **Integration**: Connect to Snowflake, Databricks, etc.
#
# ### Resources
#
# - **Ray Data Documentation**: https://docs.ray.io/en/latest/data/data.html
# - **Ray Data Examples**: https://docs.ray.io/en/latest/data/examples/examples.html
# - **Ray Dashboard Guide**: https://docs.ray.io/en/latest/ray-observability/getting-started.html
# - **Anyscale Platform**: https://docs.anyscale.com/
#
# ---
#
# **You're now ready to build production-scale document ingestion pipelines with Ray Data!**
