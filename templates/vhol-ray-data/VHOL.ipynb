# %% [markdown]
# <div style="
#     background: linear-gradient(90deg, #0f2027 0%, #2c5364 100%);
#     padding: 32px 0 32px 0;
#     border-radius: 15px;
#     text-align: center;
#     margin-bottom: 30px;
# ">
#   <h1 style="color: #fff; letter-spacing: 2px; font-size: 2.7rem; margin: 0; font-weight: 800;">
#     Building Scalable AI with Ray
#   </h1>
# </div>

# %% [markdown]
# <h2 style="color: #0f2027; background: linear-gradient(90deg, #43cea2 0%, #185a9d 100%); padding: 12px 0; border-radius: 8px; text-align:center; font-size: 2rem; letter-spacing: 1px;">
#    <span style="color: #fff;">Introduction</span>
# </h2>

# %% [markdown]
# ## What is Ray ?

# %% [markdown]
# - **Open-source project** under PyTorch Foundation
# - **Open-source distributed scheduler** for stateless tasks & stateful actors
# - **Key features:** task graphs, resource-aware, fast data transfer, GPU/custom resources
# - **Infra:** in-memory object store, fault-tolerant design
# - **Ecosystem:** Data, Train, Tune, Serve, RLlib
# - **User-friendly Python APIs**

# %% [markdown]
# <div align="center"><img src="assets/img01.png" alt="Intro to Ray" width="70%"></div>

# %% [markdown]
# | Concept | What It Is | Why It Matters (The Problem It Solves) |
# | :--- | :--- | :--- |
# | **`@ray.remote`** | A decorator to mark Python code for parallel execution. | The magic switch to turn a normal function or class into a distributed building block. |
# | **Task** | A remote, stateless function call. | **Problem:** My code is slow because it only uses one core. A Task lets you run a function on any available core. |
# | **Actor** | A remote, stateful class instance. | **Problem:** My parallel tasks need to share and update a common state (like a counter or a model). |
# | **`.remote()`** | The syntax used to execute a Task or an Actor method. | The command to "send this work to the Ray cluster" instead of running it here. |
# | **`ObjectRef`** | A "future" or a "receipt" for a result being computed. | The placeholder you get back instantly after calling `.remote()`, allowing your code to continue without waiting. |
# | **`ray.get()`** | The command to retrieve the actual result from an `ObjectRef`. | **Problem:** My parallel work has been sent out; now I need the final answers back. |
# | **`ray.put()`** | A command to place a large object into shared memory. | **Problem:** Sending the same large dataset (e.g., a big model) to every task is slow and wasteful. |

# %% [markdown]
# ## Ray `Task`

# %% [markdown]
# <div align="center"><img src="assets/img02.png" alt="Ray Task" width="70%"></div>

# %% [markdown]
# #### Example of a sequential process (`without Ray`)

# %% [markdown]
# Let's `run` it!

# %%
# !python code/sequential_process.py
# Out:
# Processed 8 images in 8.00 seconds.

# %% [markdown]
# #### Example of the same process but using `Ray Task`

# %% [markdown]
# Let's `run` it!

# %%
# !python code/parallel_process.py
# Out:
# 2025-12-09 23:25:34,888	INFO worker.py:1837 -- Connecting to existing Ray cluster at address: 10.0.135.206:6379...
# 2025-12-09 23:25:34,900	INFO worker.py:2014 -- Connected to Ray cluster. View the dashboard at https://session-byhavyr5h7v1ahhdvgc2eivb5j.i.anyscaleuserdata.com
# 2025-12-09 23:25:34,923	INFO packaging.py:380 -- Pushing file package 'gcs://_ray_pkg_7e9da2d5e75dad7ee773bd27ed5085aa38ea1a9e.zip' (7.55MiB) to Ray cluster...
# 2025-12-09 23:25:34,950	INFO packaging.py:393 -- Successfully pushed file package 'gcs://_ray_pkg_7e9da2d5e75dad7ee773bd27ed5085aa38ea1a9e.zip'.
# /home/ray/anaconda3/lib/python3.12/site-packages/ray/_private/worker.py:2062: FutureWarning: Tip: In future versions of Ray, Ray will no longer override accelerator visible devices env var if num_gpus=0 or num_gpus=None (default). To enable this behavior and turn off this error message, set RAY_ACCEL_ENV_VAR_OVERRIDE_ON_ZERO=0
#   warnings.warn(
# Processed 8 images in 3.13 seconds.

# %% [markdown]
# ## Ray `Actors`

# %%
from IPython.display import Code

Code("code/ray_actor.py")
# Out:
# import ray
#
# # 1. Initialize Ray
# if not ray.is_initialized():
#     ray.init()
#
# # 2. Define the Actor (Stateful Worker)
# @ray.remote
# class Counter:
#     def __init__(self):
#         self.count = 0  # <--- This is the "State"
#
#     def increment(self):
#         self.count += 1
#         return self.count
#
#     def get_count(self):
#         return self.count
#
# # Step 1:Create four Counter actors and increment each Counter once and get the results. These tasks all happen in parallel.
# counters = [Counter.remote() for _ in range(4)]
# results1 = ray.get([c.increment.remote() for c in counters])
# print("Initial counts: ", results1)
#
# # Step 2: Increment the first Counter five times. These tasks are executed sequentially and share state.
# results2 = ray.get([counters[0].increment.remote() for _ in range(5)])
# print("Incremented first counter five times: ", results2)
#
# # Step 3: Increment each Counter once and get the results. These tasks all happen in parallel.
# results3 = ray.get([c.increment.remote() for c in counters])
# print("Look at the final counts after incrementing each counter once: ", results3)

# %% [markdown]
# <div align="center"><img src="assets/ray_actors.jpg" alt="actors" width="80%"></div>

# %% [markdown]
# Let's `run` it!

# %%
# !python code/ray_actor.py
# Out:
# 2025-12-09 23:25:39,425	INFO worker.py:1837 -- Connecting to existing Ray cluster at address: 10.0.135.206:6379...
# 2025-12-09 23:25:39,436	INFO worker.py:2014 -- Connected to Ray cluster. View the dashboard at https://session-byhavyr5h7v1ahhdvgc2eivb5j.i.anyscaleuserdata.com
# 2025-12-09 23:25:39,459	INFO packaging.py:380 -- Pushing file package 'gcs://_ray_pkg_5a4527be9900b99960767896e1d3c1f54ca378a1.zip' (7.55MiB) to Ray cluster...
# 2025-12-09 23:25:39,486	INFO packaging.py:393 -- Successfully pushed file package 'gcs://_ray_pkg_5a4527be9900b99960767896e1d3c1f54ca378a1.zip'.
# /home/ray/anaconda3/lib/python3.12/site-packages/ray/_private/worker.py:2062: FutureWarning: Tip: In future versions of Ray, Ray will no longer override accelerator visible devices env var if num_gpus=0 or num_gpus=None (default). To enable this behavior and turn off this error message, set RAY_ACCEL_ENV_VAR_OVERRIDE_ON_ZERO=0
#   warnings.warn(
# Initial counts:  [1, 1, 1, 1]
# Incremented first counter five times:  [2, 3, 4, 5, 6]
# Look at the final counts after incrementing each counter once:  [7, 2, 2, 2]

# %% [markdown]
# <h2 style="color: #0f2027; background: linear-gradient(90deg, #43cea2 0%, #185a9d 100%); padding: 12px 0; border-radius: 8px; text-align:center; font-size: 2rem; letter-spacing: 1px;">
#    <span style="color: #fff;">Introduction to Ray Data</span>
# </h2>

# %% [markdown]
# ## Streaming execution
#
# Ray Data processes large datasets efficiently using a streaming model, which works with **blocks** as the basic units of data.
#
# This approach replaces traditional bulk processing, where the entire dataset and intermediate results had to fit in the cluster's memory.
#
# For example:
#
# Here is a batch inference pipeline with a bulk processing approach.
#
# <div align="center"><img src="assets/img04.png" alt="DP" width="80%"></div>
#
# Note how:
# - Execution is performed in stages
# - The entire dataset can be repartitioned across stage boundaries
#
# In contrast, here is the same batch inference pipeline with Ray Data's streaming model.
#
# <div align="center"><img src="assets/img05.png" alt="DP with Ray" width="80%"></div>
#
# Note how:
# - Execution across stages of the pipeline is performed in parallel (i.e pipeline parallelism)
# - Data is passed incrementally without blocking the pipeline

# %% [markdown]
# ### Dataset and blocks
#
# A Ray Dataset defines a data loading and processing pipeline.
#
# When either "materialized" or "consumed", a Ray Dataset manifests as a distributed collection of blocks stored in the Ray Object Store.
#
# Let's start by creating a materialized Ray Dataset to inspect its underlying blocks.

# %% [markdown]
# ### Dataset and blocks
#
# A Ray Dataset defines a data loading and processing pipeline.
#
# When either "materialized" or "consumed", a Ray Dataset manifests as a distributed collection of blocks stored in the Ray Object Store.
#
# Let's start by creating a materialized Ray Dataset to inspect its underlying blocks.

# %% [markdown]
# ### `Step 1`: List the existing objects before executing the code

# %% [markdown]
# <div align="center"><img src="assets/img07.png" alt="DP" width="70%"></div>

# %%
# !ray list objects
# Out:
# /home/ray/anaconda3/lib/python3.12/site-packages/ray/util/state/api.py:413: UserWarning: Callsite is not being recorded. To record callsite information for each ObjectRef created, set env variable RAY_record_ref_creation_sites=1 during `ray start` and `ray.init`.
#   warnings.warn(warning_to_print)
# No resource in the cluster

# %% [markdown]
# As expected, there are no objects created yet.

# %% [markdown]
# ### `Step 2`: Prepare some data
#
# Let's build a parquet dataset given a target in-memory size.

# %%
import gc
import ray
import numpy as np
import pandas as pd

# %%
size_mb = 64

df = pd.DataFrame(
    {
        "a": np.random.rand(size_mb * 1024**2 // 8).astype(np.float64),
    }
)

memory_usage = (df.memory_usage(deep=True) / 1024**2).sum() # in MiB
print(f"Memory usage: {memory_usage} MiB")

# Write the dataframe to a parquet file 
df.to_parquet("/mnt/cluster_storage/data.parquet")
# Out:
# Memory usage: 64.00012588500977 MiB

# %% [markdown]
# Let's inspect the parquet file.

# %%
# !ls -lh /mnt/cluster_storage/data.parquet
# Out:
# -rw-r--r-- 1 ray users 67M Dec  9 23:25 /mnt/cluster_storage/data.parquet

# %% [markdown]
# ### `Step 3`: Create a materialized dataset
#
# Let's create a `Dataset` from the parquet file using `read_parquet`

# %%
ds = ray.data.read_parquet("/mnt/cluster_storage/data.parquet")
ds
# Out:
# 2025-12-09 23:25:46,748	INFO worker.py:1837 -- Connecting to existing Ray cluster at address: 10.0.135.206:6379...
# 2025-12-09 23:25:46,761	INFO worker.py:2014 -- Connected to Ray cluster. View the dashboard at https://session-byhavyr5h7v1ahhdvgc2eivb5j.i.anyscaleuserdata.com
# 2025-12-09 23:25:46,783	INFO packaging.py:380 -- Pushing file package 'gcs://_ray_pkg_235b27b45b6c53da941cfae009808b149dd78f42.zip' (7.57MiB) to Ray cluster...
# 2025-12-09 23:25:46,812	INFO packaging.py:393 -- Successfully pushed file package 'gcs://_ray_pkg_235b27b45b6c53da941cfae009808b149dd78f42.zip'.
# /home/ray/anaconda3/lib/python3.12/site-packages/ray/_private/worker.py:2062: FutureWarning: Tip: In future versions of Ray, Ray will no longer override accelerator visible devices env var if num_gpus=0 or num_gpus=None (default). To enable this behavior and turn off this error message, set RAY_ACCEL_ENV_VAR_OVERRIDE_ON_ZERO=0
#   warnings.warn(
# Dataset(num_rows=?, schema={a: double})

# %% [markdown]
# Let's materialize the `Dataset` using `materialize`

# %%
ds_materialized = ds.materialize() 
ds_materialized
# Out:
# 2025-12-09 23:25:47,190	INFO logging.py:397 -- Registered dataset logger for dataset dataset_41_0
# 2025-12-09 23:25:47,208	INFO streaming_executor.py:174 -- Starting execution of Dataset dataset_41_0. Full logs are in /tmp/ray/session_2025-12-09_20-33-19_425846_2349/logs/ray-data
# 2025-12-09 23:25:47,208	INFO streaming_executor.py:175 -- Execution plan of Dataset dataset_41_0: InputDataBuffer[Input] -> TaskPoolMapOperator[ListFiles] -> TaskPoolMapOperator[ReadFiles]
# 2025-12-09 23:25:47,212	INFO streaming_executor.py:682 -- [dataset]: A new progress UI is available. To enable, set `ray.data.DataContext.get_current().enable_rich_progress_bars = True` and `ray.data.DataContext.get_current().use_ray_tqdm = False`.
# Running 0: 0.00 row [00:00, ? row/s]
# - ListFiles 1: 0.00 row [00:00, ? row/s]
# - ReadFiles 2: 0.00 row [00:00, ? row/s]
# 2025-12-09 23:25:47,238	WARNING resource_manager.py:136 -- ⚠️  Ray's object store is configured to use only 27.0% of available memory (17.3GiB out of 64.0GiB total). For optimal Ray Data performance, we recommend setting the object store to at least 50% of available memory. You can do this by setting the 'object_store_memory' parameter when calling ray.init() or by setting the RAY_DEFAULT_OBJECT_STORE_MEMORY_PROPORTION environment variable.
# 2025-12-09 23:25:50,572	INFO streaming_executor.py:300 -- ✔️  Dataset dataset_41_0 execution finished in 3.36 seconds
# MaterializedDataset(num_blocks=1, num_rows=8388608, schema={a: double})

# %% [markdown]
# <div align="center"><img src="assets/img09.png" alt="DP" width="70%"></div>

# %% [markdown]
# ### `Step 4`: List the objects again
#
# We can see an object with a size of ~64 MiB has been created.

# %%
# !ray list objects
# Out:
# /home/ray/anaconda3/lib/python3.12/site-packages/ray/util/state/api.py:413: UserWarning: Callsite is not being recorded. To record callsite information for each ObjectRef created, set env variable RAY_record_ref_creation_sites=1 during `ray start` and `ray.init`.
#   warnings.warn(warning_to_print)
#
# ======== List: 2025-12-09 23:25:52.693219 ========
# Stats:
# ------------------------------
# Total: 4
#
# Table:
# ------------------------------
#     OBJECT_ID                                                 OBJECT_SIZE    TASK_STATUS      ATTEMPT_NUMBER  REFERENCE_TYPE    CALL_SITE    TYPE      PID  IP
#  0  00ffffffffffffffffffffffffffffffffffffff0b00000001e1f505  530.000 B      FINISHED                      1  LOCAL_REFERENCE   disabled     DRIVER  54654  10.0.135.206
#  1  00ffffffffffffffffffffffffffffffffffffff0b00000002e1f505  9.604 KiB      FINISHED                      1  LOCAL_REFERENCE   disabled     DRIVER  54654  10.0.135.206
#  2  00ffffffffffffffffffffffffffffffffffffff0b00000003e1f505  4.193 KiB      FINISHED                      1  LOCAL_REFERENCE   disabled     DRIVER  54654  10.0.135.206
#  3  3a9a9733b405d8caffffffffffffffffffffffff0b00000002000000  64.001 MiB     FINISHED                      1  LOCAL_REFERENCE   disabled     DRIVER  54654  10.0.135.206

# %% [markdown]
# Note that we can verify the object was indeed generated by a Ray Data task by following the `CALL_SITE` of the object.

# %% [markdown]
# ### `Step 5`: Inspect the blocks
#
# Instead of browsing through all the objects in the object store, we can directly fetch the blocks of a materialized dataset using Ray Data.
#
# It turns out that we can iterate over the blocks of a dataset using `iter_internal_ref_bundles`.

# %%
for ref_bundle in ds_materialized.iter_internal_ref_bundles():
    print(ref_bundle)
# Out:
# RefBundle(1 blocks,
#   8388608 rows,
#   schema=a: double
# -- schema metadata --
# pandas: '{"index_columns": [{"kind": "range", "name": null, "start": 0, "' + 368,
#   owns_blocks=False,
#   blocks=(
#     0: 8388608 rows, 68157440 bytes, slice=None (full block)
#   )
# )

# %% [markdown]
# A reference bundle `RefBundle` is simply a bundle of:
# - a reference to the block
# - metadata about the block

# %%
block_ref, block_metadata = ref_bundle.blocks[0]
block_ref
# Out:
# ObjectRef(3a9a9733b405d8caffffffffffffffffffffffff0b00000002000000)

# %% [markdown]
# We can check the `Block size` as well.
#
# Ray Data bounds block sizes to avoid excessive communication overhead and prevent out-of-memory errors.
#
# - Small blocks are good for latency and more streamed execution
# - Large blocks reduce scheduler and communication overhead.
# - The default range attempts to make a good tradeoff for most jobs.
#
# Here are the default values that Ray Data uses:

# %%
max_block_size = ray.data.DatasetContext.get_current().target_max_block_size / 1024**2 # in MiB
min_block_size = ray.data.DatasetContext.get_current().target_min_block_size / 1024**2 # in MiB

print(f"Max block size: {max_block_size} MiB")
print(f"Min block size: {min_block_size} MiB")
# Out:
# Max block size: 128.0 MiB
# Min block size: 1.0 MiB

# %% [markdown]
# A block is the basic unit of data that Ray Data stores in the object store and transfers over the network.
#
# Each block contains a disjoint subset of rows, and Ray Data loads and transforms these blocks in a distributed manner.

# %% [markdown]
# <div align="center"><img src="assets/img03.png" alt="Ray Data" width="80%"></div>

# %% [markdown]
# To fetch the block, we can use `ray.get`.

# %%
block = ray.get(block_ref)
block
# Out:
# pyarrow.Table
# a: double
# ----
# a: [[0.46423730264810603,0.6618340545272251,0.8685421262908706,0.4009627462503653,0.5123287668368313,...,0.1719548139379119,0.07007355572123608,0.8706470082329615,0.6565158321132386,0.43037883164657975],[0.8360050957539717,0.773094125157797,0.44020329167068695,0.15160418272129328,0.6245329915574217,...,0.7827023304075951,0.3854056351037879,0.5116759707736523,0.4445087058972632,0.6169162859188839],...,[0.9989978727512656,0.6912298864267064,0.6686200873323693,0.023257736107916704,0.20940418555026852,...,0.6035976026611929,0.6658905367710712,0.2157620394614086,0.6074117720950212,0.09139236704661646],[0.716889373611765,0.4825261807821015,0.08513951818970955,0.6024826888718517,0.7037238822803671,...,0.9439085156192201,0.34418339567521694,0.42029625365912626,0.3569940492027577,0.9527684850271069]]

# %% [markdown]
# Ray Data stores blocks as either pandas Dataframes or pyarrow Tables. In this case, when materializing from a `read_parquet`, the block is a pyarrow Table.
#
# <!-- TODO - figure out adding info below: -->
# <!-- Note, that regardless of the data type that Ray Data uses to store the block, Ray Data will convert the block to the required batch format when batching the data and transforming it. -->

# %%
type(block)
# Out:
# pyarrow.lib.Table

# %% [markdown]
# In this case, the block contains the same data as the original dataframe.

# %%
block.shape, df.shape
# Out:
# ((8388608, 1), (8388608, 1))

# %% [markdown]
# let's clean up references to the objects we created so Ray can garbage collect them.

# %%
# %xdel block
# %xdel block_ref
# %xdel ds
# %xdel ds_materialized
# %xdel ref_bundle
gc.collect()
# Out:
# 43

# %% [markdown]
# We can see that the object has been garbage collected.

# %%
# !ray list objects
# Out:
# /home/ray/anaconda3/lib/python3.12/site-packages/ray/util/state/api.py:413: UserWarning: Callsite is not being recorded. To record callsite information for each ObjectRef created, set env variable RAY_record_ref_creation_sites=1 during `ray start` and `ray.init`.
#   warnings.warn(warning_to_print)
#
# ======== List: 2025-12-09 23:25:56.156652 ========
# Stats:
# ------------------------------
# Total: 3
#
# Table:
# ------------------------------
#     OBJECT_ID                                                 OBJECT_SIZE    TASK_STATUS      ATTEMPT_NUMBER  REFERENCE_TYPE    CALL_SITE    TYPE      PID  IP
#  0  00ffffffffffffffffffffffffffffffffffffff0b00000001e1f505  530.000 B      FINISHED                      1  LOCAL_REFERENCE   disabled     DRIVER  54654  10.0.135.206
#  1  00ffffffffffffffffffffffffffffffffffffff0b00000002e1f505  9.604 KiB      FINISHED                      1  LOCAL_REFERENCE   disabled     DRIVER  54654  10.0.135.206
#  2  00ffffffffffffffffffffffffffffffffffffff0b00000003e1f505  4.193 KiB      FINISHED                      1  LOCAL_REFERENCE   disabled     DRIVER  54654  10.0.135.206

# %% [markdown]
# <h2 style="color: #0f2027; background: linear-gradient(90deg, #43cea2 0%, #185a9d 100%); padding: 12px 0; border-radius: 8px; text-align:center; font-size: 2rem; letter-spacing: 1px;">
#    <span style="color: #fff;">What are we going to build today ?</span>
# </h2>

# %% [markdown]
# * Scalable data ingestion (`Batch image generation`)
# * Transforming data using Ray Data pipelines and operators
# * Scalable batch inference processing with accelerators
# * Joining Ray Datasets and apply data transformation to joined columns
# * Integrating scalable LLM inference and fractional resource scheduling

# %% [markdown]
# ## Scenario
#
# We have a dataset of image prompts (in our example, animals) and another dataset with enhanced detail information for each record (in the demo, clothing the animal will wear).
#
# Our end goal is to combine the prompts and details, then use a LLM to enhance to prompts further, employ an image gen model to create corresponding images, and produce batch output to storage.
#
# ### Ray Data motivation
#
# It's pretty easy to write a Python script to manipulate strings and use models directly from Huggingface with code like the following:
#
# ```python
# # Load some model
# pipe = AutoPipelineForText2Image.from_pretrained("stabilityai/sdxl-turbo", torch_dtype=torch.float16, variant="fp16").to("cuda")
# # Perform the inference
# image = pipe("A cinematic shot of a racoon wearing an italian priest robe.", num_inference_steps=1, guidance_scale=0.0).images[0]
# ```

# %% [markdown]
# <div align="center"><img src="assets/img06.png" alt="RD" width="80%"></div>

# %% [markdown]
# But we want to build a scalable data+AI processing pipeline. To do that, we want to ...
#
# * leverage a scale-out cluster with multiple GPUs
# * read data using as much of our cluster as is useful (parallel read)
# * work with the data in chunks large enough to get benefits of scale (i.e., not suffer from excessive overhead relative to the number of records)
#     * but also small enough to allow for flexible scheduling as it flows through our pipeline -- we don't want an enormous chunk to hold up processing, require excessive disk or network I/O, etc.
# * assign work to, e.g., CPU nodes where GPU is not required; or to smaller, cheaper GPUs where large ones are not required
# * adjust batching to optimize GPU use even when ideal batch size may be different for different operations
# * handle arbitrarily large datasets by leveraging a streaming execution model
# * minimize I/O costs by, e.g., fusing operations where possible
# * produce predictable flow by managing backpressure (i.e., ensuring data doesn't "pile up" in between pipeline stages)
# * optimize via lazy execution and flexible logical + physical planners
#
# Ray Data is designed to address these requirements, allowing us to orchestrate at scale while still straightforward Python / Huggingface code we're used to.
#
# ### Agenda and steps for incremental implementation
#
# 1. Locate our datasets in shared storage
# 2. Read records using Ray Data and learn how to perform basic transformations
# 3. Generate images across multiple GPU nodes
# 4. Lab activity: generate images and store all of our prompts and outputs as parquet data
# 5. Join animal records against clothing outfit details to build a bigger prompt and generate enhanced images
# 6. Lab activity: generate and export just the images as PNG files
# 7. Leverage a LLM to further enhance the prompts, adding seasonal content and generate images from the full pipeline
# 8. Lab activity: parameterize the LLM-based component so see how Ray Data supports separation of concerns
# 9. Wrapup

# %% [markdown]
# <h2 style="color: #0f2027; background: linear-gradient(90deg, #43cea2 0%, #185a9d 100%); padding: 12px 0; border-radius: 8px; text-align:center; font-size: 2rem; letter-spacing: 1px;">
#    <span style="color: #fff;">Let's get started! </span>
# </h2>

# %%
from diffusers import AutoPipelineForText2Image
from transformers import pipeline
from transformers.utils import logging
import numpy as np
import random
import ray
import torch
logging.set_verbosity_info()

# %% [markdown]
# ## `Step 0`: Defining the dataset

# %% [markdown]
# First, we need to get all of our data in some common location where the whole cluster can see it. This might be a blob store, NFS, database, etc.
#
# Anyscale offers `/mnt/cluster_storage` as a NFS path.

# %%
# !head data/animals.csv
# Out:
# id,animal
# 100,A watercolor painting of a cat
# 101,A digital illustration of a dog
# 102,A charcoal sketch of a rabbit
# 103,A clay sculpture of an owl
# 104,An oil painting of a fox
# 105,A pencil drawing of a horse
# 106,A digital painting of a penguin
# 107,A watercolor of a bear
# 108,An ink sketch of a raccoon

# %%
# !cp data/animals.csv /mnt/cluster_storage/

# %% [markdown]
# <div align="center"><img src="assets/img09.png" alt="DP" width="70%"></div>

# %% [markdown]
# ## `Step 1`: Read the data using `Ray Data`

# %% [markdown]
# Ray Data's `read_xxxx` methods (see I/O in Ray Docs for all the available formats and data sources) get us scalable, parallel reads.

# %%
animals = ray.data.read_csv('/mnt/cluster_storage/animals.csv')
animals.take_batch(3)
# Out:
# 2025-12-09 23:26:02,722	INFO logging.py:397 -- Registered dataset logger for dataset dataset_44_0
# 2025-12-09 23:26:02,727	INFO streaming_executor.py:174 -- Starting execution of Dataset dataset_44_0. Full logs are in /tmp/ray/session_2025-12-09_20-33-19_425846_2349/logs/ray-data
# 2025-12-09 23:26:02,728	INFO streaming_executor.py:175 -- Execution plan of Dataset dataset_44_0: InputDataBuffer[Input] -> TaskPoolMapOperator[ListFiles] -> TaskPoolMapOperator[ReadFiles] -> LimitOperator[limit=3]
# Running 0: 0.00 row [00:00, ? row/s]
# - ListFiles 1: 0.00 row [00:00, ? row/s]
# - ReadFiles 2: 0.00 row [00:00, ? row/s]
# - limit=3 3: 0.00 row [00:00, ? row/s]
# 2025-12-09 23:26:04,445	INFO streaming_executor.py:300 -- ✔️  Dataset dataset_44_0 execution finished in 1.72 seconds
# {'id': array([100, 101, 102]),
#  'animal': array(['A watercolor painting of a cat',
#         'A digital illustration of a dog', 'A charcoal sketch of a rabbit'],
#        dtype=object)}

# %% [markdown]
# We can rename column, like this:

# %%
animals.rename_columns({'animal' : 'prompt'}) \
       .take_batch(3)
# Out:
# 2025-12-09 23:26:04,577	INFO logging.py:397 -- Registered dataset logger for dataset dataset_46_0
# 2025-12-09 23:26:04,582	INFO streaming_executor.py:174 -- Starting execution of Dataset dataset_46_0. Full logs are in /tmp/ray/session_2025-12-09_20-33-19_425846_2349/logs/ray-data
# 2025-12-09 23:26:04,583	INFO streaming_executor.py:175 -- Execution plan of Dataset dataset_46_0: InputDataBuffer[Input] -> TaskPoolMapOperator[ListFiles] -> TaskPoolMapOperator[ReadFiles] -> LimitOperator[limit=3] -> TaskPoolMapOperator[Project]
# Running 0: 0.00 row [00:00, ? row/s]
# - ListFiles 1: 0.00 row [00:00, ? row/s]
# - ReadFiles 2: 0.00 row [00:00, ? row/s]
# - limit=3 3: 0.00 row [00:00, ? row/s]
# - Project 4: 0.00 row [00:00, ? row/s]
# 2025-12-09 23:26:04,713	INFO streaming_executor.py:300 -- ✔️  Dataset dataset_46_0 execution finished in 0.13 seconds
# {'id': array([100, 101, 102]),
#  'prompt': array(['A watercolor painting of a cat',
#         'A digital illustration of a dog', 'A charcoal sketch of a rabbit'],
#        dtype=object)}

# %% [markdown]
# <div align="center"><img src="assets/step2.png" alt="Step2" width="70%"></div>

# %% [markdown]
# ## `Step 2` : Generate Image

# %% [markdown]
# We dont want to simply do this and process sequentially
#
# ```python
# # Load some model
# pipe = AutoPipelineForText2Image.from_pretrained("stabilityai/sdxl-turbo", torch_dtype=torch.float16, variant="fp16").to("cuda")
# # Perform the inference
# image = pipe("A cinematic shot of a racoon wearing an italian priest robe.", num_inference_steps=1, guidance_scale=0.0).images[0]
# ```

# %% [markdown]
# Stateful tranformation of datasets -- in this example, `AI inference where the state` is the image gen model (`ImageGen`) -- is done with the following pattern.
#
# 1. Define a Python class (which Ray will later instantiate across the cluster as one more actor instances to do the processing)
# 2. Use Dataset's `map_batches` API to tell Ray to send batches of data to the `__call__` method in the actors instances
#     - `map_batches` allows us to specify resource requirements, actor pool size, batch size, and more

# %%
class ImageGen():
    def __init__(self):
        self.pipe = AutoPipelineForText2Image.from_pretrained("stabilityai/sdxl-turbo", torch_dtype=torch.float16, variant="fp16").to("cuda")
        
    def gen_image(self, prompts):
        return self.pipe(prompt=list(prompts), num_inference_steps=1, guidance_scale=0.0).images
    
    def __call__(self, batch):
        batch['image'] = self.gen_image(batch['prompt'])
        return batch

# %%
animals_images = animals.repartition(2) \
                        .rename_columns({'animal' : 'prompt'}) \
                        .map_batches(ImageGen, 
                                     num_gpus=1, 
                                     compute=ray.data.ActorPoolStrategy(size=2), 
                                     batch_size=8)

# %% [markdown]
# <div align="center"><img src="assets/step3.png" alt="Step3" width="70%"></div>

# %% [markdown]
# Ray Datasets employ *lazy evaluation* for improved performance, so we can use APIs like `take_batch`, `take`, or `show` to trigger execution for development and testing purposes.

# %%
examples = animals_images.take_batch(3)
# Out:
# 2025-12-09 23:26:05,098	INFO logging.py:397 -- Registered dataset logger for dataset dataset_50_0
# 2025-12-09 23:26:05,100	INFO limit_pushdown.py:140 -- Skipping push down of limit 3 through map MapBatches[MapBatches(ImageGen)] because it requires 8 rows to produce stable outputs
# 2025-12-09 23:26:05,105	INFO streaming_executor.py:174 -- Starting execution of Dataset dataset_50_0. Full logs are in /tmp/ray/session_2025-12-09_20-33-19_425846_2349/logs/ray-data
# 2025-12-09 23:26:05,106	INFO streaming_executor.py:175 -- Execution plan of Dataset dataset_50_0: InputDataBuffer[Input] -> TaskPoolMapOperator[ListFiles] -> TaskPoolMapOperator[ReadFiles] -> AllToAllOperator[Repartition] -> TaskPoolMapOperator[Project] -> ActorPoolMapOperator[MapBatches(ImageGen)] -> LimitOperator[limit=3]
# Running 0: 0.00 row [00:00, ? row/s]
# - ListFiles 1: 0.00 row [00:00, ? row/s]
# - ReadFiles 2: 0.00 row [00:00, ? row/s]
# - Repartition 3: 0.00 row [00:00, ? row/s]
# Split Repartition 4:   0%|          | 0.00/1.00 [00:00<?, ? row/s]
# - Project 5: 0.00 row [00:00, ? row/s]
# - MapBatches(ImageGen) 6: 0.00 row [00:00, ? row/s]
# - limit=3 7: 0.00 row [00:00, ? row/s]
# Loading pipeline components...:   0%|          | 0/7 [00:00<?, ?it/s]
# Loading pipeline components...:  29%|██▊       | 2/7 [00:00<00:00, 19.12it/s]
# Loading pipeline components...:  71%|███████▏  | 5/7 [00:00<00:00, 23.61it/s]
# Loading pipeline components...: 100%|██████████| 7/7 [00:00<00:00,  8.81it/s]
# Loading pipeline components...: 100%|██████████| 7/7 [00:00<00:00,  8.52it/s]
#   0%|          | 0/1 [00:00<?, ?it/s] pid=20690, ip=10.0.180.82)
# 100%|██████████| 1/1 [00:00<00:00,  1.80it/s]90, ip=10.0.180.82)
# 100%|██████████| 1/1 [00:00<00:00,  1.78it/s]76, ip=10.0.142.30)
# (MapWorker(MapBatches(ImageGen)) pid=19776, ip=10.0.142.30) Failed to convert column 'image' into pyarrow array due to: Error converting data to Arrow: [<PIL.Image.Image image mode=RGB size=512x512 at 0x7CCD49CD9010>, <PIL.Image.Image image mode=RGB size=512x512 at 0x7CCD49CD8800>, <PIL.Image.Image image mode=RGB size=512x512 at 0x7CCD49CD8080>, <PIL...; falling back to serialize as pickled python objects
# (MapWorker(MapBatches(ImageGen)) pid=19776, ip=10.0.142.30) Traceback (most recent call last):
# (MapWorker(MapBatches(ImageGen)) pid=19776, ip=10.0.142.30)   File "/home/ray/anaconda3/lib/python3.12/site-packages/ray/air/util/tensor_extensions/arrow.py", line 318, in _convert_to_pyarrow_native_array
# (MapWorker(MapBatches(ImageGen)) pid=19776, ip=10.0.142.30)     pa_type = _infer_pyarrow_type(column_values)
# (MapWorker(MapBatches(ImageGen)) pid=19776, ip=10.0.142.30)               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (MapWorker(MapBatches(ImageGen)) pid=19776, ip=10.0.142.30)   File "/home/ray/anaconda3/lib/python3.12/site-packages/ray/air/util/tensor_extensions/arrow.py", line 431, in _infer_pyarrow_type
# (MapWorker(MapBatches(ImageGen)) pid=19776, ip=10.0.142.30)     inferred_pa_dtype = pa.infer_type(column_values)
# (MapWorker(MapBatches(ImageGen)) pid=19776, ip=10.0.142.30)                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (MapWorker(MapBatches(ImageGen)) pid=19776, ip=10.0.142.30)   File "pyarrow/array.pxi", line 568, in pyarrow.lib.infer_type
# (MapWorker(MapBatches(ImageGen)) pid=19776, ip=10.0.142.30)   File "pyarrow/error.pxi", line 155, in pyarrow.lib.pyarrow_internal_check_status
# (MapWorker(MapBatches(ImageGen)) pid=19776, ip=10.0.142.30)   File "pyarrow/error.pxi", line 92, in pyarrow.lib.check_status
# (MapWorker(MapBatches(ImageGen)) pid=19776, ip=10.0.142.30) pyarrow.lib.ArrowInvalid: Could not convert <PIL.Image.Image image mode=RGB size=512x512 at 0x7CCD49CD9010> with type Image: did not recognize Python value type when inferring an Arrow data type
# (MapWorker(MapBatches(ImageGen)) pid=19776, ip=10.0.142.30)
# (MapWorker(MapBatches(ImageGen)) pid=19776, ip=10.0.142.30) The above exception was the direct cause of the following exception:
# (MapWorker(MapBatches(ImageGen)) pid=19776, ip=10.0.142.30)
# (MapWorker(MapBatches(ImageGen)) pid=19776, ip=10.0.142.30) Traceback (most recent call last):
# (MapWorker(MapBatches(ImageGen)) pid=19776, ip=10.0.142.30)   File "/home/ray/anaconda3/lib/python3.12/site-packages/ray/air/util/tensor_extensions/arrow.py", line 235, in convert_to_pyarrow_array
# (MapWorker(MapBatches(ImageGen)) pid=19776, ip=10.0.142.30)     return _convert_to_pyarrow_native_array(column_values, column_name)
# (MapWorker(MapBatches(ImageGen)) pid=19776, ip=10.0.142.30)            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (MapWorker(MapBatches(ImageGen)) pid=19776, ip=10.0.142.30)   File "/home/ray/anaconda3/lib/python3.12/site-packages/ray/air/util/tensor_extensions/arrow.py", line 345, in _convert_to_pyarrow_native_array
# (MapWorker(MapBatches(ImageGen)) pid=19776, ip=10.0.142.30)     raise ArrowConversionError(str(column_values)) from e
# (MapWorker(MapBatches(ImageGen)) pid=19776, ip=10.0.142.30) ray.air.util.tensor_extensions.arrow.ArrowConversionError: Error converting data to Arrow: [<PIL.Image.Image image mode=RGB size=512x512 at 0x7CCD49CD9010>, <PIL.Image.Image image mode=RGB size=512x512 at 0x7CCD49CD8800>, <PIL.Image.Image image mode=RGB size=512x512 at 0x7CCD49CD8080>, <PIL...
# (MapWorker(MapBatches(ImageGen)) pid=20690, ip=10.0.180.82)
# (MapWorker(MapBatches(ImageGen)) pid=20690, ip=10.0.180.82)
# Loading pipeline components...:   0%|          | 0/7 [00:00<?, ?it/s]
# 100%|██████████| 1/1 [00:00<00:00,  7.15it/s]90, ip=10.0.180.82)
# Loading pipeline components...:  57%|█████▋    | 4/7 [00:00<00:00,  7.45it/s] [repeated 3x across cluster] (Ray deduplicates logs by default. Set RAY_DEDUP_LOGS=0 to disable log deduplication, or see https://docs.ray.io/en/master/ray-observability/user-guides/configure-logging.html#log-deduplication for more options.)
# 100%|██████████| 1/1 [00:00<00:00,  7.14it/s]76, ip=10.0.142.30)
# 100%|██████████| 1/1 [00:00<00:00,  7.13it/s]76, ip=10.0.142.30)
# 100%|██████████| 1/1 [00:00<00:00,  7.13it/s]90, ip=10.0.180.82)
#   0%|          | 0/1 [00:00<?, ?it/s] [repeated 6x across cluster]
# 100%|██████████| 1/1 [00:00<00:00,  7.15it/s]90, ip=10.0.180.82)
# 100%|██████████| 1/1 [00:00<00:00,  7.13it/s]76, ip=10.0.142.30)
# (MapWorker(MapBatches(ImageGen)) pid=20690, ip=10.0.180.82) Failed to convert column 'image' into pyarrow array due to: Error converting data to Arrow: [<PIL.Image.Image image mode=RGB size=512x512 at 0x71FAB46820C0>, <PIL.Image.Image image mode=RGB size=512x512 at 0x71FAB3D270B0>, <PIL.Image.Image image mode=RGB size=512x512 at 0x71FAB3D26030>, <PIL...; falling back to serialize as pickled python objects
# (MapWorker(MapBatches(ImageGen)) pid=20690, ip=10.0.180.82) Traceback (most recent call last): [repeated 2x across cluster]
# (MapWorker(MapBatches(ImageGen)) pid=20690, ip=10.0.180.82)   File "/home/ray/anaconda3/lib/python3.12/site-packages/ray/air/util/tensor_extensions/arrow.py", line 345, in _convert_to_pyarrow_native_array [repeated 2x across cluster]
# (MapWorker(MapBatches(ImageGen)) pid=20690, ip=10.0.180.82)     pa_type = _infer_pyarrow_type(column_values)
# (MapWorker(MapBatches(ImageGen)) pid=20690, ip=10.0.180.82)               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (MapWorker(MapBatches(ImageGen)) pid=20690, ip=10.0.180.82)   File "/home/ray/anaconda3/lib/python3.12/site-packages/ray/air/util/tensor_extensions/arrow.py", line 431, in _infer_pyarrow_type
# (MapWorker(MapBatches(ImageGen)) pid=20690, ip=10.0.180.82)     inferred_pa_dtype = pa.infer_type(column_values)
# (MapWorker(MapBatches(ImageGen)) pid=20690, ip=10.0.180.82)                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (MapWorker(MapBatches(ImageGen)) pid=20690, ip=10.0.180.82)   File "pyarrow/array.pxi", line 568, in pyarrow.lib.infer_type
# (MapWorker(MapBatches(ImageGen)) pid=20690, ip=10.0.180.82)   File "pyarrow/error.pxi", line 155, in pyarrow.lib.pyarrow_internal_check_status
# (MapWorker(MapBatches(ImageGen)) pid=20690, ip=10.0.180.82)   File "pyarrow/error.pxi", line 92, in pyarrow.lib.check_status
# (MapWorker(MapBatches(ImageGen)) pid=20690, ip=10.0.180.82) pyarrow.lib.ArrowInvalid: Could not convert <PIL.Image.Image image mode=RGB size=512x512 at 0x71FAB46820C0> with type Image: did not recognize Python value type when inferring an Arrow data type
# (MapWorker(MapBatches(ImageGen)) pid=20690, ip=10.0.180.82) The above exception was the direct cause of the following exception:
# (MapWorker(MapBatches(ImageGen)) pid=20690, ip=10.0.180.82)   File "/home/ray/anaconda3/lib/python3.12/site-packages/ray/air/util/tensor_extensions/arrow.py", line 235, in convert_to_pyarrow_array
# (MapWorker(MapBatches(ImageGen)) pid=20690, ip=10.0.180.82)     return _convert_to_pyarrow_native_array(column_values, column_name)
# (MapWorker(MapBatches(ImageGen)) pid=20690, ip=10.0.180.82)            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (MapWorker(MapBatches(ImageGen)) pid=20690, ip=10.0.180.82)     raise ArrowConversionError(str(column_values)) from e
# (MapWorker(MapBatches(ImageGen)) pid=20690, ip=10.0.180.82) ray.air.util.tensor_extensions.arrow.ArrowConversionError: Error converting data to Arrow: [<PIL.Image.Image image mode=RGB size=512x512 at 0x71FAB46820C0>, <PIL.Image.Image image mode=RGB size=512x512 at 0x71FAB3D270B0>, <PIL.Image.Image image mode=RGB size=512x512 at 0x71FAB3D26030>, <PIL...
# 100%|██████████| 1/1 [00:00<00:00,  7.14it/s]90, ip=10.0.180.82)
# 100%|██████████| 1/1 [00:00<00:00,  7.14it/s]76, ip=10.0.142.30)
# 100%|██████████| 1/1 [00:00<00:00,  7.15it/s]90, ip=10.0.180.82)
# 100%|██████████| 1/1 [00:00<00:00,  7.14it/s]76, ip=10.0.142.30)
#   0%|          | 0/1 [00:00<?, ?it/s] [repeated 7x across cluster]
# 100%|██████████| 1/1 [00:00<00:00,  6.35it/s]90, ip=10.0.180.82)
# 100%|██████████| 1/1 [00:00<00:00,  6.49it/s]76, ip=10.0.142.30)
# 2025-12-09 23:26:23,773	INFO streaming_executor.py:300 -- ✔️  Dataset dataset_50_0 execution finished in 18.66 seconds

# %%
examples
# Out:
# {'id': array([100, 101, 102]),
#  'prompt': array(['A watercolor painting of a cat',
#         'A digital illustration of a dog', 'A charcoal sketch of a rabbit'],
#        dtype=object),
#  'image': array([<PIL.Image.Image image mode=RGB size=512x512 at 0x73B04B60AAB0>,
#         <PIL.Image.Image image mode=RGB size=512x512 at 0x73B04B6590A0>,
#         <PIL.Image.Image image mode=RGB size=512x512 at 0x73B04B60A7E0>],
#        dtype=object)}

# %% [markdown]
# <div align="center"><img src="assets/img10.png" alt="Step3" width="70%"></div>

# %%
print(examples['prompt'][0])
examples['image'][0]
# Out:
# A watercolor painting of a cat
# <PIL.Image.Image image mode=RGB size=512x512>

# %% [markdown]
# <div align="center"><img src="assets/step4.png" alt="Step4" width="70%"></div>

# %% [markdown]
# <div style="border: 2px solid #4F8EF7; background: #F3F8FF; border-radius: 10px; padding: 18px; margin: 18px 0;">
# <h2 style="color: #25396f; margin-top: 0;">📝 <span style="color:#3971CC;">Lab:</span> Generate and Write All Output to Storage as <span style="color: #C678DD;">Parquet</span> Data</h2>
#
# <ul style="font-size: 1.1em;">
#   <li><b>Start</b> with the <span style="color: #A9A9A9;">Ray Dataset</span> you'd like to write.</li>
#   <li><b>Check</b> the <a href="https://docs.ray.io/en/latest/data/api/input_output.html" target="_blank" style="color: #3971CC;">Ray Data Write API docs</a> to find a suitable <code>write</code> API.</li>
#   <li><b>Remember</b> to write to a <span style="color: #228B22;">shared file location</span>, such as <code style="color: #228B22;">/mnt/cluster_storage</code>.</li>
# </ul>
# </div>

# %%
# try your code here

# %% [markdown]
# <details>
#     <summary style="font-size: 1.5em; color: ;"><b> Solution</b></summary>
#
#  ```python
#  animals_images.write_parquet('/mnt/cluster_storage/animals_images.parquet/')
#  ```
#
# <div align="center"><img src="assets/step5.png" alt="Step5" width="70%"></div>
#
# </details>

# %% [markdown]
# <div align="center"><img src="assets/Part1_done.png" alt="Intro to Ray" width="70%"></div>

# %% [markdown]
# ## `Step 3`: Improving the `prompt` using `JOIN`

# %% [markdown]
# <div align="center"><img src="assets/Part2.png" alt="Part2" width="70%"></div>

# %% [markdown]
# Ray Data supports a number of high-performance JOIN APIs.
# You can learn more here:  [Ray Data Join API Documentation](https://docs.ray.io/en/latest/data/joining-data.html)
#
# We can use a `JOIN` to connect our `animal` records with a detailed prompt refinement unique to that record.

# %%
# !head /mnt/cluster_storage/outfits.csv
# Out:
# id,outfit
# 100,red scarf
# 101,blue jacket
# 102,green hat
# 103,purple cloak
# 104,yellow sweater
# 105,pink blanket
# 106,orange bowtie
# 107,teal hoodie
# 108,violet vest

# %%
outfits = ray.data.read_csv('/mnt/cluster_storage/outfits.csv')
outfits.take_batch(3)
# Out:
# 2025-12-09 23:26:25,515	INFO logging.py:397 -- Registered dataset logger for dataset dataset_52_0
# 2025-12-09 23:26:25,519	INFO streaming_executor.py:174 -- Starting execution of Dataset dataset_52_0. Full logs are in /tmp/ray/session_2025-12-09_20-33-19_425846_2349/logs/ray-data
# 2025-12-09 23:26:25,520	INFO streaming_executor.py:175 -- Execution plan of Dataset dataset_52_0: InputDataBuffer[Input] -> TaskPoolMapOperator[ListFiles] -> TaskPoolMapOperator[ReadFiles] -> LimitOperator[limit=3]
# Running 0: 0.00 row [00:00, ? row/s]
# - ListFiles 1: 0.00 row [00:00, ? row/s]
# - ReadFiles 2: 0.00 row [00:00, ? row/s]
# - limit=3 3: 0.00 row [00:00, ? row/s]
# 2025-12-09 23:26:27,138	INFO streaming_executor.py:300 -- ✔️  Dataset dataset_52_0 execution finished in 1.62 seconds
# {'id': array([100, 101, 102]),
#  'outfit': array(['red scarf', 'blue jacket', 'green hat'], dtype=object)}

# %%
animals_outfits = animals.join(outfits, 'inner', 1) \
                         .repartition(8)

animals_outfits.take_batch(3)
# Out:
# 2025-12-09 23:26:27,290	INFO logging.py:397 -- Registered dataset logger for dataset dataset_55_0
# /home/ray/anaconda3/lib/python3.12/site-packages/ray/anyscale/data/_internal/util/dependencies.py:42: UserWarning: Numba isn't available. Install numba>=0.61>=0.61 to get better performance for hash partitioning operations. Falling back to slower Python implementation for RayTurbo optimizations.
#   warnings.warn(
# 2025-12-09 23:26:27,298	INFO streaming_executor.py:174 -- Starting execution of Dataset dataset_55_0. Full logs are in /tmp/ray/session_2025-12-09_20-33-19_425846_2349/logs/ray-data
# 2025-12-09 23:26:27,298	INFO streaming_executor.py:175 -- Execution plan of Dataset dataset_55_0: InputDataBuffer[Input] -> TaskPoolMapOperator[ListFiles] -> TaskPoolMapOperator[ReadFiles], InputDataBuffer[Input] -> TaskPoolMapOperator[ListFiles] -> TaskPoolMapOperator[ReadFiles] -> JoinOperatorWithPolars[Join(num_partitions=1)] -> AllToAllOperator[Repartition] -> LimitOperator[limit=3]
# Running 0: 0.00 row [00:00, ? row/s]
# - ListFiles 1: 0.00 row [00:00, ? row/s]
# - ReadFiles 2: 0.00 row [00:00, ? row/s]
# - ListFiles 3: 0.00 row [00:00, ? row/s]
# - ReadFiles 4: 0.00 row [00:00, ? row/s]
# - Join(num_partitions=1) 5: 0.00 row [00:00, ? row/s]
# Shuffle 6:   0%|          | 0.00/1.00 [00:00<?, ? row/s]
# Join 7:   0%|          | 0.00/1.00 [00:00<?, ? row/s]
# - Repartition 8: 0.00 row [00:00, ? row/s]
# Split Repartition 9:   0%|          | 0.00/1.00 [00:00<?, ? row/s]
# - limit=3 10: 0.00 row [00:00, ? row/s]
# 2025-12-09 23:26:30,647	INFO streaming_executor.py:300 -- ✔️  Dataset dataset_55_0 execution finished in 3.35 seconds
# {'id': array([100, 101, 102]),
#  'animal': array(['A watercolor painting of a cat',
#         'A digital illustration of a dog', 'A charcoal sketch of a rabbit'],
#        dtype=object),
#  'outfit': array(['red scarf', 'blue jacket', 'green hat'], dtype=object)}

# %%
# Expand the prompt to include the outfit
def expand_prompt(batch):
    batch['prompt'] = batch['animal'] + ' wearing a ' + batch['outfit']
    return batch

# Generate images for the dressed animals
dressed_animals = animals_outfits.map_batches(expand_prompt) \
                                 .map_batches(ImageGen, 
                                              batch_size=16, 
                                              compute=ray.data.ActorPoolStrategy(size=2), 
                                              num_gpus=1)

# %%
# Take a look at the first 3 records
examples = dressed_animals.take_batch(3)
# Out:
# 2025-12-09 23:26:31,041	INFO logging.py:397 -- Registered dataset logger for dataset dataset_58_0
# 2025-12-09 23:26:31,044	INFO limit_pushdown.py:140 -- Skipping push down of limit 3 through map MapBatches[MapBatches(ImageGen)] because it requires 16 rows to produce stable outputs
# 2025-12-09 23:26:31,306	INFO streaming_executor.py:174 -- Starting execution of Dataset dataset_58_0. Full logs are in /tmp/ray/session_2025-12-09_20-33-19_425846_2349/logs/ray-data
# 2025-12-09 23:26:31,307	INFO streaming_executor.py:175 -- Execution plan of Dataset dataset_58_0: InputDataBuffer[Input] -> TaskPoolMapOperator[ListFiles] -> TaskPoolMapOperator[ReadFiles], InputDataBuffer[Input] -> TaskPoolMapOperator[ListFiles] -> TaskPoolMapOperator[ReadFiles] -> JoinOperatorWithPolars[Join(num_partitions=1)] -> AllToAllOperator[Repartition] -> TaskPoolMapOperator[MapBatches(expand_prompt)] -> ActorPoolMapOperator[MapBatches(ImageGen)] -> LimitOperator[limit=3]
# Running 0: 0.00 row [00:00, ? row/s]
# - ListFiles 1: 0.00 row [00:00, ? row/s]
# - ReadFiles 2: 0.00 row [00:00, ? row/s]
# - ListFiles 3: 0.00 row [00:00, ? row/s]
# - ReadFiles 4: 0.00 row [00:00, ? row/s]
# - Join(num_partitions=1) 5: 0.00 row [00:00, ? row/s]
# Shuffle 6:   0%|          | 0.00/1.00 [00:00<?, ? row/s]
# Join 7:   0%|          | 0.00/1.00 [00:00<?, ? row/s]
# - Repartition 8: 0.00 row [00:00, ? row/s]
# Split Repartition 9:   0%|          | 0.00/1.00 [00:00<?, ? row/s]
# - MapBatches(expand_prompt) 10: 0.00 row [00:00, ? row/s]
# - MapBatches(ImageGen) 11: 0.00 row [00:00, ? row/s]
# - limit=3 12: 0.00 row [00:00, ? row/s]
# Loading pipeline components...:   0%|          | 0/7 [00:00<?, ?it/s]
# Loading pipeline components...:  29%|██▊       | 2/7 [00:00<00:01,  3.78it/s]
# Loading pipeline components...:  71%|███████▏  | 5/7 [00:00<00:00,  9.11it/s]
# Loading pipeline components...: 100%|██████████| 7/7 [00:00<00:00,  8.62it/s]
# Loading pipeline components...: 100%|██████████| 7/7 [00:00<00:00,  8.69it/s]
#   0%|          | 0/1 [00:00<?, ?it/s] pid=20098, ip=10.0.142.30)
# 100%|██████████| 1/1 [00:00<00:00,  1.27it/s]98, ip=10.0.142.30)
# 100%|██████████| 1/1 [00:00<00:00,  1.28it/s]73, ip=10.0.180.82)
# (MapWorker(MapBatches(ImageGen)) pid=20098, ip=10.0.142.30) Failed to convert column 'image' into pyarrow array due to: Error converting data to Arrow: [<PIL.Image.Image image mode=RGB size=512x512 at 0x7AB464A84410>, <PIL.Image.Image image mode=RGB size=512x512 at 0x7AB474F9A090>, <PIL.Image.Image image mode=RGB size=512x512 at 0x7AB4644952B0>, <PIL...; falling back to serialize as pickled python objects
# (MapWorker(MapBatches(ImageGen)) pid=20098, ip=10.0.142.30) Traceback (most recent call last):
# (MapWorker(MapBatches(ImageGen)) pid=20098, ip=10.0.142.30)   File "/home/ray/anaconda3/lib/python3.12/site-packages/ray/air/util/tensor_extensions/arrow.py", line 318, in _convert_to_pyarrow_native_array
# (MapWorker(MapBatches(ImageGen)) pid=20098, ip=10.0.142.30)     pa_type = _infer_pyarrow_type(column_values)
# (MapWorker(MapBatches(ImageGen)) pid=20098, ip=10.0.142.30)               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (MapWorker(MapBatches(ImageGen)) pid=20098, ip=10.0.142.30)   File "/home/ray/anaconda3/lib/python3.12/site-packages/ray/air/util/tensor_extensions/arrow.py", line 431, in _infer_pyarrow_type
# (MapWorker(MapBatches(ImageGen)) pid=20098, ip=10.0.142.30)     inferred_pa_dtype = pa.infer_type(column_values)
# (MapWorker(MapBatches(ImageGen)) pid=20098, ip=10.0.142.30)                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (MapWorker(MapBatches(ImageGen)) pid=20098, ip=10.0.142.30)   File "pyarrow/array.pxi", line 568, in pyarrow.lib.infer_type
# (MapWorker(MapBatches(ImageGen)) pid=20098, ip=10.0.142.30)   File "pyarrow/error.pxi", line 155, in pyarrow.lib.pyarrow_internal_check_status
# (MapWorker(MapBatches(ImageGen)) pid=20098, ip=10.0.142.30)   File "pyarrow/error.pxi", line 92, in pyarrow.lib.check_status
# (MapWorker(MapBatches(ImageGen)) pid=20098, ip=10.0.142.30) pyarrow.lib.ArrowInvalid: Could not convert <PIL.Image.Image image mode=RGB size=512x512 at 0x7AB464A84410> with type Image: did not recognize Python value type when inferring an Arrow data type
# (MapWorker(MapBatches(ImageGen)) pid=20098, ip=10.0.142.30)
# (MapWorker(MapBatches(ImageGen)) pid=20098, ip=10.0.142.30) The above exception was the direct cause of the following exception:
# (MapWorker(MapBatches(ImageGen)) pid=20098, ip=10.0.142.30)
# (MapWorker(MapBatches(ImageGen)) pid=20098, ip=10.0.142.30) Traceback (most recent call last):
# (MapWorker(MapBatches(ImageGen)) pid=20098, ip=10.0.142.30)   File "/home/ray/anaconda3/lib/python3.12/site-packages/ray/air/util/tensor_extensions/arrow.py", line 235, in convert_to_pyarrow_array
# (MapWorker(MapBatches(ImageGen)) pid=20098, ip=10.0.142.30)     return _convert_to_pyarrow_native_array(column_values, column_name)
# (MapWorker(MapBatches(ImageGen)) pid=20098, ip=10.0.142.30)            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (MapWorker(MapBatches(ImageGen)) pid=20098, ip=10.0.142.30)   File "/home/ray/anaconda3/lib/python3.12/site-packages/ray/air/util/tensor_extensions/arrow.py", line 345, in _convert_to_pyarrow_native_array
# (MapWorker(MapBatches(ImageGen)) pid=20098, ip=10.0.142.30)     raise ArrowConversionError(str(column_values)) from e
# (MapWorker(MapBatches(ImageGen)) pid=20098, ip=10.0.142.30) ray.air.util.tensor_extensions.arrow.ArrowConversionError: Error converting data to Arrow: [<PIL.Image.Image image mode=RGB size=512x512 at 0x7AB464A84410>, <PIL.Image.Image image mode=RGB size=512x512 at 0x7AB474F9A090>, <PIL.Image.Image image mode=RGB size=512x512 at 0x7AB4644952B0>, <PIL...
# Loading pipeline components...:   0%|          | 0/7 [00:00<?, ?it/s]
# Loading pipeline components...:  86%|████████▌ | 6/7 [00:00<00:00,  9.09it/s] [repeated 3x across cluster]
# 100%|██████████| 1/1 [00:00<00:00,  3.15it/s]98, ip=10.0.142.30)
# (MapWorker(MapBatches(ImageGen)) pid=20973, ip=10.0.180.82)
# (MapWorker(MapBatches(ImageGen)) pid=20973, ip=10.0.180.82)
# 100%|██████████| 1/1 [00:00<00:00,  3.15it/s]73, ip=10.0.180.82)
#   0%|          | 0/1 [00:00<?, ?it/s] [repeated 4x across cluster]
# 2025-12-09 23:26:45,484	INFO streaming_executor.py:300 -- ✔️  Dataset dataset_58_0 execution finished in 14.17 seconds

# %%
examples
# Out:
# {'id': array([100, 101, 102]),
#  'animal': array(['A watercolor painting of a cat',
#         'A digital illustration of a dog', 'A charcoal sketch of a rabbit'],
#        dtype=object),
#  'outfit': array(['red scarf', 'blue jacket', 'green hat'], dtype=object),
#  'prompt': array(['A watercolor painting of a cat wearing a red scarf',
#         'A digital illustration of a dog wearing a blue jacket',
#         'A charcoal sketch of a rabbit wearing a green hat'], dtype=object),
#  'image': array([<PIL.Image.Image image mode=RGB size=512x512 at 0x73B04B5D5130>,
#         <PIL.Image.Image image mode=RGB size=512x512 at 0x73B04B5B56D0>,
#         <PIL.Image.Image image mode=RGB size=512x512 at 0x73B04B5D4740>],
#        dtype=object)}

# %% [markdown]
# <div align="center"><img src="assets/img11.png" alt="Ray Task" width="70%"></div>

# %%
print(examples['prompt'][0])
examples['image'][0]
# Out:
# A watercolor painting of a cat wearing a red scarf
# 100%|██████████| 1/1 [00:00<00:00,  3.89it/s]98, ip=10.0.142.30)
# <PIL.Image.Image image mode=RGB size=512x512>

# %% [markdown]
# <div align="center"><img src="assets/step4_task.png" alt="Ray Task" width="70%"></div>

# %% [markdown]
# <div style="border: 2px solid #4F8EF7; background: #F3F8FF; border-radius: 10px; padding: 18px; margin: 18px 0;">
# <h2 style="color: #25396f; margin-top: 0;">📝 <span style="color:#3971CC;">Lab:</span> Generate Images for Input Prompts &amp; Write Them to a Folder</h2>
#
# <ul style="font-size: 1.1em;">
#   <li><b>Convert</b> the image column to NumPy arrays using <code>np.array(my_pil_image)</code> together with <code>map_batches</code>.</li>
#   <li><b>Use</b> <code>dataset.write_images(...)</code> to write the NumPy image arrays to a folder of your choice (e.g., <code>/mnt/cluster_storage/generated_images/</code>).</li>
#   <li><b>Check</b> the <a href="https://docs.ray.io/en/latest/data/api/input_output.html#ray.data.Dataset.write_images" target="_blank" style="color: #3971CC;">Ray Data Write Images API Docs</a> for details.</li>
# </ul>
# </div>

# %%
# try your code here
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s] pid=20973, ip=10.0.180.82)

# %% [markdown]
# <details>
#     <summary style="font-size: 1.5em; color: ;"><b> Solution</b></summary>
#
#  ```python
#     def image_to_array(batch):
#         batch['image'] = [np.array(i) for i in batch['image']]
#         return batch
#
#     dressed_animals.map_batches(image_to_array) \
#                    .write_images('/mnt/cluster_storage/animals_images/', 'image')
#  ```
# </details>

# %% [markdown]
# <div align="center"><img src="assets/Part2_done.png" alt="Intro to Ray" width="70%"></div>

# %% [markdown]
# ## `Step 4` :  Enhance pipeline with `LLM` generated prompt

# %% [markdown]
# We can leverage a LLM to create more varied and detailed image prompts -- as well as add dynamism like a seasonal element -- by adding a LLM batch inference step to the pipeline.
#
# To implement this operation, we'll
# 1. Create a Python class to encasulate the logic and data transformtion
# 1. Use `map_batches` to route batches of data from our Ray Dataset through this transformation operation
# 1. Demonstrate Ray's support for fractional resource allocation, so that we can schedule 4 GPU-dependent operator instances with only 2 GPUs
# 1. Demonstrate the decoupling of operator batch sizes from each other (as well as from Dataset block size) to optimally use our models and GPUs

# %% [markdown]
# <div align="center"><img src="assets/Part3.png" alt="Intro to Ray" width="70%"></div>

# %%
class Enhancer():
    def __init__(self):
        self.pipe = pipeline("text-generation", model="Qwen/Qwen2.5-0.5B-Instruct", device='cuda')
        
    def chat(self, prompts):
        messages = []
        for p in prompts:
            season = random.choice(['winter', 'spring', 'summer', 'fall'])
                                   
            message = [{"role": "system", "content": "You are a helpful assistant." +
                        "Enhance the image description with two short elements corresponding to the " + season + 
                        "season. Keep animal wearing clothing and retain image medium information (like photo or painting). Return new description only, no intro."},
                        {"role": "user", "content": p }]
            messages.append(message)
        return [out[0]['generated_text'][-1]['content'] for out in self.pipe(messages, max_new_tokens=200, batch_size=2)]
    
    def __call__(self, batch):
        batch['prompt'] = self.chat(batch['prompt'])
        return batch
# Out:
# 100%|██████████| 1/1 [00:00<00:00,  3.89it/s]73, ip=10.0.180.82)

# %%
seasonal_images = animals_outfits.map_batches(expand_prompt) \
                                 .map_batches(Enhancer, batch_size=4, compute=ray.data.ActorPoolStrategy(size=2), num_gpus=0.6) \
                                 .map_batches(ImageGen, batch_size=8, compute=ray.data.ActorPoolStrategy(size=2), num_gpus=0.4)

# %%
examples = seasonal_images.take_batch(3)
# Out:
# 2025-12-09 23:26:47,296	INFO logging.py:397 -- Registered dataset logger for dataset dataset_62_0
# 2025-12-09 23:26:47,298	INFO limit_pushdown.py:140 -- Skipping push down of limit 3 through map MapBatches[MapBatches(ImageGen)] because it requires 8 rows to produce stable outputs
# 2025-12-09 23:26:47,304	INFO streaming_executor.py:174 -- Starting execution of Dataset dataset_62_0. Full logs are in /tmp/ray/session_2025-12-09_20-33-19_425846_2349/logs/ray-data
# 2025-12-09 23:26:47,305	INFO streaming_executor.py:175 -- Execution plan of Dataset dataset_62_0: InputDataBuffer[Input] -> TaskPoolMapOperator[ListFiles] -> TaskPoolMapOperator[ReadFiles], InputDataBuffer[Input] -> TaskPoolMapOperator[ListFiles] -> TaskPoolMapOperator[ReadFiles] -> JoinOperatorWithPolars[Join(num_partitions=1)] -> AllToAllOperator[Repartition] -> TaskPoolMapOperator[MapBatches(expand_prompt)] -> ActorPoolMapOperator[MapBatches(Enhancer)] -> ActorPoolMapOperator[MapBatches(ImageGen)] -> LimitOperator[limit=3]
# Running 0: 0.00 row [00:00, ? row/s]
# - ListFiles 1: 0.00 row [00:00, ? row/s]
# - ReadFiles 2: 0.00 row [00:00, ? row/s]
# - ListFiles 3: 0.00 row [00:00, ? row/s]
# - ReadFiles 4: 0.00 row [00:00, ? row/s]
# - Join(num_partitions=1) 5: 0.00 row [00:00, ? row/s]
# Shuffle 6:   0%|          | 0.00/1.00 [00:00<?, ? row/s]
# Join 7:   0%|          | 0.00/1.00 [00:00<?, ? row/s]
# - Repartition 8: 0.00 row [00:00, ? row/s]
# Split Repartition 9:   0%|          | 0.00/1.00 [00:00<?, ? row/s]
# - MapBatches(expand_prompt) 10: 0.00 row [00:00, ? row/s]
# - MapBatches(Enhancer) 11: 0.00 row [00:00, ? row/s]
# - MapBatches(ImageGen) 12: 0.00 row [00:00, ? row/s]
# - limit=3 13: 0.00 row [00:00, ? row/s]
#   0%|          | 0/1 [00:00<?, ?it/s] pid=20098, ip=10.0.142.30)
# 100%|██████████| 1/1 [00:00<00:00,  6.22it/s]98, ip=10.0.142.30)
# Loading pipeline components...:   0%|          | 0/7 [00:00<?, ?it/s]
# Loading pipeline components...:  29%|██▊       | 2/7 [00:00<00:00, 16.04it/s]
# (MapWorker(MapBatches(Enhancer)) pid=21401, ip=10.0.180.82) Sliding Window Attention is enabled but not implemented for `sdpa`; unexpected results may be encountered.
# Loading pipeline components...:  57%|█████▋    | 4/7 [00:00<00:00, 17.26it/s]
# Loading pipeline components...:  86%|████████▌ | 6/7 [00:00<00:00,  6.28it/s]
# Loading pipeline components...: 100%|██████████| 7/7 [00:00<00:00,  8.33it/s]
# (MapWorker(MapBatches(Enhancer)) pid=21401, ip=10.0.180.82) Device set to use cuda
# (MapWorker(MapBatches(Enhancer)) pid=21401, ip=10.0.180.82) A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# (MapWorker(MapBatches(Enhancer)) pid=21401, ip=10.0.180.82) A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Loading pipeline components...:   0%|          | 0/7 [00:00<?, ?it/s]
# Loading pipeline components...:  86%|████████▌ | 6/7 [00:00<00:00,  7.55it/s] [repeated 2x across cluster]
# (MapWorker(MapBatches(Enhancer)) pid=20426, ip=10.0.142.30) Sliding Window Attention is enabled but not implemented for `sdpa`; unexpected results may be encountered.
# Loading pipeline components...: 100%|██████████| 7/7 [00:00<00:00,  8.44it/s]
# (MapWorker(MapBatches(Enhancer)) pid=20426, ip=10.0.142.30) Device set to use cuda
# (MapWorker(MapBatches(Enhancer)) pid=20426, ip=10.0.142.30) A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# (MapWorker(MapBatches(Enhancer)) pid=20426, ip=10.0.142.30) A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# (MapWorker(MapBatches(Enhancer)) pid=21401, ip=10.0.180.82) A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer. [repeated 3x across cluster]
# (MapWorker(MapBatches(ImageGen)) pid=20428, ip=10.0.142.30) Token indices sequence length is longer than the specified maximum sequence length for this model (91 > 77). Running this sequence through the model will result in indexing errors
# (MapWorker(MapBatches(ImageGen)) pid=20428, ip=10.0.142.30) The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['beauty is intertwined with the whimsical spirit of a beloved pet. <|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|>', '<|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|>', '<|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|>', '<|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|>', 'captures the essence of summer, with the sun casting long, warm shadows across the canvas, creating a sense of warmth and serenity.', 'capturing the moment when horses come out of their hibernation season and return to the world outside. <|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|>', 'all their pristine glory. <|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|>', '<|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|>']
# (MapWorker(MapBatches(ImageGen)) pid=20428, ip=10.0.142.30) Token indices sequence length is longer than the specified maximum sequence length for this model (91 > 77). Running this sequence through the model will result in indexing errors
# (MapWorker(MapBatches(ImageGen)) pid=20428, ip=10.0.142.30) The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['beauty is intertwined with the whimsical spirit of a beloved pet. <|endoftext|>!!!!!!!!!!!', '!!!!!!!!!!!!!!!!!!!!!!!!!!', '!!!!!!!!!!!!!!!!!!!!!!!!!!', '!!!!!!!!!!!!!!!!!!!!!!!!!!', 'captures the essence of summer, with the sun casting long, warm shadows across the canvas, creating a sense of warmth and serenity.', 'capturing the moment when horses come out of their hibernation season and return to the world outside. <|endoftext|>!!!!!!', 'all their pristine glory. <|endoftext|>!!!!!!!!!!!!!!!!!!!!', '<|endoftext|>!!!!!!!!!!!!!!!!!!!!!!!!!']
#   0%|          | 0/1 [00:00<?, ?it/s] pid=20428, ip=10.0.142.30)
# 100%|██████████| 1/1 [00:00<00:00,  1.39it/s]28, ip=10.0.142.30)
# (MapWorker(MapBatches(ImageGen)) pid=20428, ip=10.0.142.30) Failed to convert column 'image' into pyarrow array due to: Error converting data to Arrow: [<PIL.Image.Image image mode=RGB size=512x512 at 0x7159F4BB5610>, <PIL.Image.Image image mode=RGB size=512x512 at 0x7159F16F23F0>, <PIL.Image.Image image mode=RGB size=512x512 at 0x7159F16F2180>, <PIL...; falling back to serialize as pickled python objects
# (MapWorker(MapBatches(ImageGen)) pid=20428, ip=10.0.142.30) Traceback (most recent call last):
# (MapWorker(MapBatches(ImageGen)) pid=20428, ip=10.0.142.30)   File "/home/ray/anaconda3/lib/python3.12/site-packages/ray/air/util/tensor_extensions/arrow.py", line 318, in _convert_to_pyarrow_native_array
# (MapWorker(MapBatches(ImageGen)) pid=20428, ip=10.0.142.30)     pa_type = _infer_pyarrow_type(column_values)
# (MapWorker(MapBatches(ImageGen)) pid=20428, ip=10.0.142.30)               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (MapWorker(MapBatches(ImageGen)) pid=20428, ip=10.0.142.30)   File "/home/ray/anaconda3/lib/python3.12/site-packages/ray/air/util/tensor_extensions/arrow.py", line 431, in _infer_pyarrow_type
# (MapWorker(MapBatches(ImageGen)) pid=20428, ip=10.0.142.30)     inferred_pa_dtype = pa.infer_type(column_values)
# (MapWorker(MapBatches(ImageGen)) pid=20428, ip=10.0.142.30)                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (MapWorker(MapBatches(ImageGen)) pid=20428, ip=10.0.142.30)   File "pyarrow/array.pxi", line 568, in pyarrow.lib.infer_type
# (MapWorker(MapBatches(ImageGen)) pid=20428, ip=10.0.142.30)   File "pyarrow/error.pxi", line 155, in pyarrow.lib.pyarrow_internal_check_status
# (MapWorker(MapBatches(ImageGen)) pid=20428, ip=10.0.142.30)   File "pyarrow/error.pxi", line 92, in pyarrow.lib.check_status
# (MapWorker(MapBatches(ImageGen)) pid=20428, ip=10.0.142.30) pyarrow.lib.ArrowInvalid: Could not convert <PIL.Image.Image image mode=RGB size=512x512 at 0x7159F4BB5610> with type Image: did not recognize Python value type when inferring an Arrow data type
# (MapWorker(MapBatches(ImageGen)) pid=20428, ip=10.0.142.30)
# (MapWorker(MapBatches(ImageGen)) pid=20428, ip=10.0.142.30) The above exception was the direct cause of the following exception:
# (MapWorker(MapBatches(ImageGen)) pid=20428, ip=10.0.142.30)
# (MapWorker(MapBatches(ImageGen)) pid=20428, ip=10.0.142.30) Traceback (most recent call last):
# (MapWorker(MapBatches(ImageGen)) pid=20428, ip=10.0.142.30)   File "/home/ray/anaconda3/lib/python3.12/site-packages/ray/air/util/tensor_extensions/arrow.py", line 235, in convert_to_pyarrow_array
# (MapWorker(MapBatches(ImageGen)) pid=20428, ip=10.0.142.30)     return _convert_to_pyarrow_native_array(column_values, column_name)
# (MapWorker(MapBatches(ImageGen)) pid=20428, ip=10.0.142.30)            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (MapWorker(MapBatches(ImageGen)) pid=20428, ip=10.0.142.30)   File "/home/ray/anaconda3/lib/python3.12/site-packages/ray/air/util/tensor_extensions/arrow.py", line 345, in _convert_to_pyarrow_native_array
# (MapWorker(MapBatches(ImageGen)) pid=20428, ip=10.0.142.30)     raise ArrowConversionError(str(column_values)) from e
# (MapWorker(MapBatches(ImageGen)) pid=20428, ip=10.0.142.30) ray.air.util.tensor_extensions.arrow.ArrowConversionError: Error converting data to Arrow: [<PIL.Image.Image image mode=RGB size=512x512 at 0x7159F4BB5610>, <PIL.Image.Image image mode=RGB size=512x512 at 0x7159F16F23F0>, <PIL.Image.Image image mode=RGB size=512x512 at 0x7159F16F2180>, <PIL...
# (MapWorker(MapBatches(ImageGen)) pid=20428, ip=10.0.142.30) The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['<|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|>', '<|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|>', '<|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|>', "birds flitting through the branches, the gentle breeze caressing the surface of the canvas. the overall composition emphasizes the delicate interplay between nature's beauty and its fleeting season, creating an immersive experience for viewers who step into this whimsical tableau."]
# (MapWorker(MapBatches(ImageGen)) pid=20428, ip=10.0.142.30) The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!', '!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!', '!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!', "birds flitting through the branches, the gentle breeze caressing the surface of the canvas. the overall composition emphasizes the delicate interplay between nature's beauty and its fleeting season, creating an immersive experience for viewers who step into this whimsical tableau."]
#   0%|          | 0/1 [00:00<?, ?it/s] pid=20428, ip=10.0.142.30)
# 100%|██████████| 1/1 [00:00<00:00,  4.15it/s]28, ip=10.0.142.30)
# (MapWorker(MapBatches(ImageGen)) pid=21174, ip=10.0.180.82) The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['<|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|>', '<|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|>', 'elegance and tranquility to the scene. this piece, a stunning representation of nature ’ s beauty in the midst of the changing seasons, captures the essence of autumn as it unfolds.', 'visual experience. <|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|>', '<|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|>', '<|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|>', 'bird. <|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|>', 'it is a moment frozen in time, reflecting the beauty and wonder of this natural world. <|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|>']
# (MapWorker(MapBatches(ImageGen)) pid=21174, ip=10.0.180.82) The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!', '!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!', 'elegance and tranquility to the scene. this piece, a stunning representation of nature ’ s beauty in the midst of the changing seasons, captures the essence of autumn as it unfolds.', 'visual experience. <|endoftext|>!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!', '!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!', '!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!', 'bird. <|endoftext|>!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!', 'it is a moment frozen in time, reflecting the beauty and wonder of this natural world. <|endoftext|>!!!!!!!!!!!!!!!!!!']
# 2025-12-09 23:27:14,394	INFO streaming_executor.py:300 -- ✔️  Dataset dataset_62_0 execution finished in 27.08 seconds

# %%
print(examples['prompt'][1])
examples['image'][1]
# Out:
# Dog in a blue jacket, summer season, outdoors
# 100%|██████████| 1/1 [00:00<00:00,  1.48it/s]74, ip=10.0.180.82)
# <PIL.Image.Image image mode=RGB size=512x512>

# %% [markdown]
# <div align="center"><img src="assets/Part3_done.png" alt="Intro to Ray" width="70%"></div>

# %% [markdown]
# <div style="border: 2px solid #4F8EF7; background: #F3F8FF; border-radius: 10px; padding: 18px; margin: 18px 0;">
# <h2 style="color: #25396f; margin-top: 0;">📝 <span style="color:#3971CC;">Modify the <code>Enhancer</code> class and <code>seasonal_images</code> pipeline for parametrization</span></h2>
#
# <ul style="font-size: 1.1em;">
#   <li>Use variables contaioning the model name and the name of the dataset column containing the prompt as below</li>
# </ul>
# </div>

# %%
enhancer_model = "Qwen/Qwen2.5-0.5B-Instruct"
prompt_column = "prompt"
# Out:
# (MapWorker(MapBatches(Enhancer)) pid=20426, ip=10.0.142.30) A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.

# %%
# try your code here: updated Enhancer class

# %%
# try your code here: updated pipelineto generate seasonal_images Ray dataset

# %% [markdown]
# <details>
#     <summary style="font-size: 1.5em; color: ;"><b> Solution</b></summary>
#
#  ```python
#     # try your code here: updated Enhancer class
#     class Enhancer():
#         def __init__(self, model_name, prompt_column_name):
#             self.pipe = pipeline("text-generation", model=model_name, device='cuda')
#             self.prompt_column_name = prompt_column_name
#
#         def chat(self, prompts):
#             messages = []
#             for p in prompts:
#                 season = random.choice(['winter', 'spring', 'summer', 'fall'])
#
#                 message = [{"role": "system", "content": "You are a helpful assistant." +
#                             "Enhance the image description with two short elements corresponding to the " + season +
#                             "season. Keep animal wearing clothing and retain image medium information (like photo or painting). Return new description only, no intro."},
#                             {"role": "user", "content": p }]
#                 messages.append(message)
#             return [out[0]['generated_text'][-1]['content'] for out in self.pipe(messages, max_new_tokens=200, batch_size=2)]
#
#         def __call__(self, batch):
#             batch[self.prompt_column_name] = self.chat(batch[self.prompt_column_name])
#             return batch
#
#
#     # try your code here: updated pipelineto generate seasonal_images Ray dataset
#     seasonal_images = animals_outfits.map_batches(expand_prompt) \
#                         .map_batches(Enhancer, batch_size=4, compute=ray.data.ActorPoolStrategy(size=2), num_gpus=0.6, fn_constructor_args=[enhancer_model, prompt_column]) \
#                         .map_batches(ImageGen, batch_size=8, compute=ray.data.ActorPoolStrategy(size=2), num_gpus=0.4)
#  ```
# </details>

# %%
# try your code here: updated Enhancer class
class Enhancer():
    def __init__(self, model_name, prompt_column_name):
        self.pipe = pipeline("text-generation", model=model_name, device='cuda')
        self.prompt_column_name = prompt_column_name
        
    def chat(self, prompts):
        messages = []
        for p in prompts:
            season = random.choice(['winter', 'spring', 'summer', 'fall'])
                                   
            message = [{"role": "system", "content": "You are a helpful assistant." +
                        "Enhance the image description with two short elements corresponding to the " + season + 
                        "season. Keep animal wearing clothing and retain image medium information (like photo or painting). Return new description only, no intro."},
                        {"role": "user", "content": p }]
            messages.append(message)
        return [out[0]['generated_text'][-1]['content'] for out in self.pipe(messages, max_new_tokens=200, batch_size=2)]
    
    def __call__(self, batch):
        batch[self.prompt_column_name] = self.chat(batch[self.prompt_column_name])
        return batch

# %%
# try your code here: updated pipelineto generate seasonal_images Ray dataset
seasonal_images = animals_outfits.map_batches(expand_prompt) \
                    .map_batches(Enhancer, batch_size=4, compute=ray.data.ActorPoolStrategy(size=2), num_gpus=0.6, fn_constructor_args=[enhancer_model, prompt_column]) \
                    .map_batches(ImageGen, batch_size=8, compute=ray.data.ActorPoolStrategy(size=2), num_gpus=0.4)

# %%
examples = seasonal_images.take_batch(4)
# Out:
# 2025-12-09 23:27:15,741	INFO logging.py:397 -- Registered dataset logger for dataset dataset_66_0
# 2025-12-09 23:27:15,744	INFO limit_pushdown.py:140 -- Skipping push down of limit 4 through map MapBatches[MapBatches(ImageGen)] because it requires 8 rows to produce stable outputs
# 2025-12-09 23:27:15,752	INFO streaming_executor.py:174 -- Starting execution of Dataset dataset_66_0. Full logs are in /tmp/ray/session_2025-12-09_20-33-19_425846_2349/logs/ray-data
# 2025-12-09 23:27:15,752	INFO streaming_executor.py:175 -- Execution plan of Dataset dataset_66_0: InputDataBuffer[Input] -> TaskPoolMapOperator[ListFiles] -> TaskPoolMapOperator[ReadFiles], InputDataBuffer[Input] -> TaskPoolMapOperator[ListFiles] -> TaskPoolMapOperator[ReadFiles] -> JoinOperatorWithPolars[Join(num_partitions=1)] -> AllToAllOperator[Repartition] -> TaskPoolMapOperator[MapBatches(expand_prompt)] -> ActorPoolMapOperator[MapBatches(Enhancer)] -> ActorPoolMapOperator[MapBatches(ImageGen)] -> LimitOperator[limit=4]
# Running 0: 0.00 row [00:00, ? row/s]
# - ListFiles 1: 0.00 row [00:00, ? row/s]
# - ReadFiles 2: 0.00 row [00:00, ? row/s]
# - ListFiles 3: 0.00 row [00:00, ? row/s]
# - ReadFiles 4: 0.00 row [00:00, ? row/s]
# - Join(num_partitions=1) 5: 0.00 row [00:00, ? row/s]
# Shuffle 6:   0%|          | 0.00/1.00 [00:00<?, ? row/s]
# Join 7:   0%|          | 0.00/1.00 [00:00<?, ? row/s]
# - Repartition 8: 0.00 row [00:00, ? row/s]
# Split Repartition 9:   0%|          | 0.00/1.00 [00:00<?, ? row/s]
# - MapBatches(expand_prompt) 10: 0.00 row [00:00, ? row/s]
# - MapBatches(Enhancer) 11: 0.00 row [00:00, ? row/s]
# - MapBatches(ImageGen) 12: 0.00 row [00:00, ? row/s]
# - limit=4 13: 0.00 row [00:00, ? row/s]
# (autoscaler +1m31s) Tip: use `ray status` to view detailed cluster status. To disable these messages, set RAY_SCHEDULER_EVENTS=0.
# (MapWorker(MapBatches(ImageGen)) pid=21174, ip=10.0.180.82) Failed to convert column 'image' into pyarrow array due to: Error converting data to Arrow: [<PIL.Image.Image image mode=RGB size=512x512 at 0x71570976E720>, <PIL.Image.Image image mode=RGB size=512x512 at 0x71570866E8A0>, <PIL.Image.Image image mode=RGB size=512x512 at 0x71570866F230>, <PIL...; falling back to serialize as pickled python objects
# (MapWorker(MapBatches(ImageGen)) pid=21174, ip=10.0.180.82) Traceback (most recent call last):
# (MapWorker(MapBatches(ImageGen)) pid=21174, ip=10.0.180.82)   File "/home/ray/anaconda3/lib/python3.12/site-packages/ray/air/util/tensor_extensions/arrow.py", line 318, in _convert_to_pyarrow_native_array
# (MapWorker(MapBatches(ImageGen)) pid=21174, ip=10.0.180.82)     pa_type = _infer_pyarrow_type(column_values)
# (MapWorker(MapBatches(ImageGen)) pid=21174, ip=10.0.180.82)               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (MapWorker(MapBatches(ImageGen)) pid=21174, ip=10.0.180.82)   File "/home/ray/anaconda3/lib/python3.12/site-packages/ray/air/util/tensor_extensions/arrow.py", line 431, in _infer_pyarrow_type
# (MapWorker(MapBatches(ImageGen)) pid=21174, ip=10.0.180.82)     inferred_pa_dtype = pa.infer_type(column_values)
# (MapWorker(MapBatches(ImageGen)) pid=21174, ip=10.0.180.82)                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (MapWorker(MapBatches(ImageGen)) pid=21174, ip=10.0.180.82)   File "pyarrow/array.pxi", line 568, in pyarrow.lib.infer_type
# (MapWorker(MapBatches(ImageGen)) pid=21174, ip=10.0.180.82)   File "pyarrow/error.pxi", line 155, in pyarrow.lib.pyarrow_internal_check_status
# (MapWorker(MapBatches(ImageGen)) pid=21174, ip=10.0.180.82)   File "pyarrow/error.pxi", line 92, in pyarrow.lib.check_status
# (MapWorker(MapBatches(ImageGen)) pid=21174, ip=10.0.180.82) pyarrow.lib.ArrowInvalid: Could not convert <PIL.Image.Image image mode=RGB size=512x512 at 0x71570976E720> with type Image: did not recognize Python value type when inferring an Arrow data type
# (MapWorker(MapBatches(ImageGen)) pid=21174, ip=10.0.180.82)
# (MapWorker(MapBatches(ImageGen)) pid=21174, ip=10.0.180.82) The above exception was the direct cause of the following exception:
# (MapWorker(MapBatches(ImageGen)) pid=21174, ip=10.0.180.82)
# (MapWorker(MapBatches(ImageGen)) pid=21174, ip=10.0.180.82) Traceback (most recent call last):
# (MapWorker(MapBatches(ImageGen)) pid=21174, ip=10.0.180.82)   File "/home/ray/anaconda3/lib/python3.12/site-packages/ray/air/util/tensor_extensions/arrow.py", line 235, in convert_to_pyarrow_array
# (MapWorker(MapBatches(ImageGen)) pid=21174, ip=10.0.180.82)     return _convert_to_pyarrow_native_array(column_values, column_name)
# (MapWorker(MapBatches(ImageGen)) pid=21174, ip=10.0.180.82)            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (MapWorker(MapBatches(ImageGen)) pid=21174, ip=10.0.180.82)   File "/home/ray/anaconda3/lib/python3.12/site-packages/ray/air/util/tensor_extensions/arrow.py", line 345, in _convert_to_pyarrow_native_array
# (MapWorker(MapBatches(ImageGen)) pid=21174, ip=10.0.180.82)     raise ArrowConversionError(str(column_values)) from e
# (MapWorker(MapBatches(ImageGen)) pid=21174, ip=10.0.180.82) ray.air.util.tensor_extensions.arrow.ArrowConversionError: Error converting data to Arrow: [<PIL.Image.Image image mode=RGB size=512x512 at 0x71570976E720>, <PIL.Image.Image image mode=RGB size=512x512 at 0x71570866E8A0>, <PIL.Image.Image image mode=RGB size=512x512 at 0x71570866F230>, <PIL...
# (MapWorker(MapBatches(ImageGen)) pid=21174, ip=10.0.180.82) The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['<|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|>', 'of colors that reflect the fleeting beauty of the season. this image is reminiscent of a traditional chinese painting technique, where the vivid colors and intricate details capture the essence of the moment, capturing the essence of the springtime experience through the eyes of the panda.', '<|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|>', "seahorse's back, making it appear almost translucent. <|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|>"]
# (MapWorker(MapBatches(ImageGen)) pid=21174, ip=10.0.180.82) The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!', 'of colors that reflect the fleeting beauty of the season. this image is reminiscent of a traditional chinese painting technique, where the vivid colors and intricate details capture the essence of the moment, capturing the essence of the springtime experience through the eyes of the panda.', '!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!', "seahorse's back, making it appear almost translucent. <|endoftext|>!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!"]
#   0%|          | 0/1 [00:00<?, ?it/s] pid=21174, ip=10.0.180.82)
# 100%|██████████| 1/1 [00:00<00:00,  4.07it/s]74, ip=10.0.180.82)
# (MapWorker(MapBatches(Enhancer)) pid=21401, ip=10.0.180.82) A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Loading pipeline components...:   0%|          | 0/7 [00:00<?, ?it/s]
# Loading pipeline components...:  29%|██▊       | 2/7 [00:00<00:00, 18.30it/s]
# Loading pipeline components...:  57%|█████▋    | 4/7 [00:00<00:00,  5.37it/s]
# Loading pipeline components...: 100%|██████████| 7/7 [00:00<00:00,  8.43it/s]
# (MapWorker(MapBatches(Enhancer)) pid=20426, ip=10.0.142.30) A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer. [repeated 4x across cluster]
# Loading pipeline components...: 100%|██████████| 7/7 [00:00<00:00,  8.02it/s]
# Loading pipeline components...:   0%|          | 0/7 [00:00<?, ?it/s]
# Loading pipeline components...:  71%|███████▏  | 5/7 [00:00<00:00,  7.66it/s] [repeated 2x across cluster]
# (MapWorker(MapBatches(Enhancer)) pid=21401, ip=10.0.180.82) A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer. [repeated 3x across cluster]
# (MapWorker(MapBatches(Enhancer)) pid=21401, ip=10.0.180.82) A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer. [repeated 4x across cluster]
# (MapWorker(MapBatches(Enhancer)) pid=20426, ip=10.0.142.30) You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
# (MapWorker(MapBatches(Enhancer)) pid=21681, ip=10.0.180.82) Sliding Window Attention is enabled but not implemented for `sdpa`; unexpected results may be encountered.
# (MapWorker(MapBatches(Enhancer)) pid=21401, ip=10.0.180.82) A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer. [repeated 3x across cluster]
# (MapWorker(MapBatches(Enhancer)) pid=21681, ip=10.0.180.82) Device set to use cuda
# (MapWorker(MapBatches(Enhancer)) pid=20749, ip=10.0.142.30) Sliding Window Attention is enabled but not implemented for `sdpa`; unexpected results may be encountered.
# (MapWorker(MapBatches(Enhancer)) pid=20749, ip=10.0.142.30) A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer. [repeated 2x across cluster]
# (MapWorker(MapBatches(Enhancer)) pid=20749, ip=10.0.142.30) Device set to use cuda
# (MapWorker(MapBatches(Enhancer)) pid=20749, ip=10.0.142.30) A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer. [repeated 4x across cluster]
# (MapWorker(MapBatches(ImageGen)) pid=21588, ip=10.0.180.82) Token indices sequence length is longer than the specified maximum sequence length for this model (112 > 77). Running this sequence through the model will result in indexing errors
# (MapWorker(MapBatches(ImageGen)) pid=21588, ip=10.0.180.82) The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: [". this image showcases the warmth of nature's embrace as the sea otter adjusts to the changing seasons, embodying the essence of tranquility and renewal found in the natural world. <|endoftext|>", 'colors while evoking the spirit of nature. <|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|>', '<|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|>', '<|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|>', "and vibrancy. the scene is captured in a vibrant, high - quality image medium, likely a photograph taken during the spring season when nature's colors are most vivid and vibrant.", '<|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|>', '<|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|>', '<|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|>']
# (MapWorker(MapBatches(ImageGen)) pid=21588, ip=10.0.180.82) Token indices sequence length is longer than the specified maximum sequence length for this model (112 > 77). Running this sequence through the model will result in indexing errors
# (MapWorker(MapBatches(ImageGen)) pid=21588, ip=10.0.180.82) The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: [". this image showcases the warmth of nature's embrace as the sea otter adjusts to the changing seasons, embodying the essence of tranquility and renewal found in the natural world. <|endoftext|>", 'colors while evoking the spirit of nature. <|endoftext|>!!!!!!!!!!!!!!!!!!!!!!!!!!', '!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!', '!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!', "and vibrancy. the scene is captured in a vibrant, high - quality image medium, likely a photograph taken during the spring season when nature's colors are most vivid and vibrant.", '!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!', '!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!', '!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!']
#   0%|          | 0/1 [00:00<?, ?it/s] pid=21588, ip=10.0.180.82)
# 100%|██████████| 1/1 [00:00<00:00,  1.38it/s]88, ip=10.0.180.82)
# (MapWorker(MapBatches(ImageGen)) pid=20595, ip=10.0.142.30) The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ["the vast expanse of white snow below, its tail wagging in the gentle breeze. the background features a cluster of pine trees against a backdrop of rolling hills, creating a harmonious balance between the natural beauty and the cozy warmth of the cat's coat.", '<|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|>', 'summer. <|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|>', "of the owl. the scene captures the essence of a traditional winter landscape, where nature's cycles come alive in this serene moment. <|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|>", 'of autumn, with leaves crunching underfoot and the sound of falling leaves creating a haunting melody through the brushwork. <|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|>', 'the essence of this transformative time of year. <|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|>', '<|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|>', '<|endoftext|><|endoftext|><|endoftext|><|endoftex ...
# (MapWorker(MapBatches(ImageGen)) pid=20595, ip=10.0.142.30) The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ["the vast expanse of white snow below, its tail wagging in the gentle breeze. the background features a cluster of pine trees against a backdrop of rolling hills, creating a harmonious balance between the natural beauty and the cozy warmth of the cat's coat.", '!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!', 'summer. <|endoftext|>!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!', "of the owl. the scene captures the essence of a traditional winter landscape, where nature's cycles come alive in this serene moment. <|endoftext|>!!!!!!!!!!!!!!!!!!!!!!!!", 'of autumn, with leaves crunching underfoot and the sound of falling leaves creating a haunting melody through the brushwork. <|endoftext|>!!!!!!!!!!!!!!!!!!!!!!!!!!', 'the essence of this transformative time of year. <|endoftext|>!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!', '!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!', '!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!']
# (MapWorker(MapBatches(Enhancer)) pid=21681, ip=10.0.180.82) A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer. [repeated 3x across cluster]
# 100%|██████████| 1/1 [00:00<00:00,  1.41it/s]95, ip=10.0.142.30)
# (MapWorker(MapBatches(ImageGen)) pid=21588, ip=10.0.180.82) Failed to convert column 'image' into pyarrow array due to: Error converting data to Arrow: [<PIL.Image.Image image mode=RGB size=512x512 at 0x7ABC26E2D6A0>, <PIL.Image.Image image mode=RGB size=512x512 at 0x7ABC26E2E1B0>, <PIL.Image.Image image mode=RGB size=512x512 at 0x7ABC26E2DA60>, <PIL...; falling back to serialize as pickled python objects
# (MapWorker(MapBatches(ImageGen)) pid=21588, ip=10.0.180.82) Traceback (most recent call last):
# (MapWorker(MapBatches(ImageGen)) pid=21588, ip=10.0.180.82)   File "/home/ray/anaconda3/lib/python3.12/site-packages/ray/air/util/tensor_extensions/arrow.py", line 318, in _convert_to_pyarrow_native_array
# (MapWorker(MapBatches(ImageGen)) pid=21588, ip=10.0.180.82)     pa_type = _infer_pyarrow_type(column_values)
# (MapWorker(MapBatches(ImageGen)) pid=21588, ip=10.0.180.82)               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (MapWorker(MapBatches(ImageGen)) pid=21588, ip=10.0.180.82)   File "/home/ray/anaconda3/lib/python3.12/site-packages/ray/air/util/tensor_extensions/arrow.py", line 431, in _infer_pyarrow_type
# (MapWorker(MapBatches(ImageGen)) pid=21588, ip=10.0.180.82)     inferred_pa_dtype = pa.infer_type(column_values)
# (MapWorker(MapBatches(ImageGen)) pid=21588, ip=10.0.180.82)                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (MapWorker(MapBatches(ImageGen)) pid=21588, ip=10.0.180.82)   File "pyarrow/array.pxi", line 568, in pyarrow.lib.infer_type
# (MapWorker(MapBatches(ImageGen)) pid=21588, ip=10.0.180.82)   File "pyarrow/error.pxi", line 155, in pyarrow.lib.pyarrow_internal_check_status
# (MapWorker(MapBatches(ImageGen)) pid=21588, ip=10.0.180.82)   File "pyarrow/error.pxi", line 92, in pyarrow.lib.check_status
# (MapWorker(MapBatches(ImageGen)) pid=21588, ip=10.0.180.82) pyarrow.lib.ArrowInvalid: Could not convert <PIL.Image.Image image mode=RGB size=512x512 at 0x7ABC26E2D6A0> with type Image: did not recognize Python value type when inferring an Arrow data type
# (MapWorker(MapBatches(ImageGen)) pid=21588, ip=10.0.180.82)
# (MapWorker(MapBatches(ImageGen)) pid=21588, ip=10.0.180.82) The above exception was the direct cause of the following exception:
# (MapWorker(MapBatches(ImageGen)) pid=21588, ip=10.0.180.82)
# (MapWorker(MapBatches(ImageGen)) pid=21588, ip=10.0.180.82) Traceback (most recent call last):
# (MapWorker(MapBatches(ImageGen)) pid=21588, ip=10.0.180.82)   File "/home/ray/anaconda3/lib/python3.12/site-packages/ray/air/util/tensor_extensions/arrow.py", line 235, in convert_to_pyarrow_array
# (MapWorker(MapBatches(ImageGen)) pid=21588, ip=10.0.180.82)     return _convert_to_pyarrow_native_array(column_values, column_name)
# (MapWorker(MapBatches(ImageGen)) pid=21588, ip=10.0.180.82)            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (MapWorker(MapBatches(ImageGen)) pid=21588, ip=10.0.180.82)   File "/home/ray/anaconda3/lib/python3.12/site-packages/ray/air/util/tensor_extensions/arrow.py", line 345, in _convert_to_pyarrow_native_array
# (MapWorker(MapBatches(ImageGen)) pid=21588, ip=10.0.180.82)     raise ArrowConversionError(str(column_values)) from e
# (MapWorker(MapBatches(ImageGen)) pid=21588, ip=10.0.180.82) ray.air.util.tensor_extensions.arrow.ArrowConversionError: Error converting data to Arrow: [<PIL.Image.Image image mode=RGB size=512x512 at 0x7ABC26E2D6A0>, <PIL.Image.Image image mode=RGB size=512x512 at 0x7ABC26E2E1B0>, <PIL.Image.Image image mode=RGB size=512x512 at 0x7ABC26E2DA60>, <PIL...
# (MapWorker(MapBatches(ImageGen)) pid=21588, ip=10.0.180.82) The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['<|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|>', '<|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|>', 'des both elegance and authenticity, perfect for a serene summer day. <|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|>', ". the water reflects the seahorse's elegant form, casting long shadows that dance across the canvas, creating a mesmerizing backdrop for this unique and whimsical piece."]
# (MapWorker(MapBatches(ImageGen)) pid=21588, ip=10.0.180.82) The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!', '!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!', 'des both elegance and authenticity, perfect for a serene summer day. <|endoftext|>!!!!!!!!!!!!!!!!!!', ". the water reflects the seahorse's elegant form, casting long shadows that dance across the canvas, creating a mesmerizing backdrop for this unique and whimsical piece."]
# 100%|██████████| 1/1 [00:00<00:00,  4.19it/s]88, ip=10.0.180.82)
# 2025-12-09 23:28:08,119	INFO streaming_executor.py:300 -- ✔️  Dataset dataset_66_0 execution finished in 52.36 seconds

# %%
print(examples['prompt'][0])
examples['image'][0]
# Out:
# In the springtime landscape depicted in this printmaking piece, an elegant sea otter is depicted wearing a cozy, plump sweater adorned with intricate fur tufts. The scene captures the soft glow of dawn breaking over the waters, casting dappled shadows on the rugged coastline. A serene blue sky above, framed by wispy clouds, adds a tranquil backdrop to the serene moment captured on paper. This image showcases the warmth of nature's embrace as the sea otter adjusts to the changing seasons, embodying the essence of tranquility and renewal found in the natural world.
# <PIL.Image.Image image mode=RGB size=512x512>
# (MapWorker(MapBatches(ImageGen)) pid=20595, ip=10.0.142.30) Failed to convert column 'image' into pyarrow array due to: Error converting data to Arrow: [<PIL.Image.Image image mode=RGB size=512x512 at 0x7C01154041D0>, <PIL.Image.Image image mode=RGB size=512x512 at 0x7C0114FD7470>, <PIL.Image.Image image mode=RGB size=512x512 at 0x7C0117E4E720>, <PIL...; falling back to serialize as pickled python objects
# (MapWorker(MapBatches(ImageGen)) pid=20595, ip=10.0.142.30) Traceback (most recent call last):
# (MapWorker(MapBatches(ImageGen)) pid=20595, ip=10.0.142.30)   File "/home/ray/anaconda3/lib/python3.12/site-packages/ray/air/util/tensor_extensions/arrow.py", line 318, in _convert_to_pyarrow_native_array
# (MapWorker(MapBatches(ImageGen)) pid=20595, ip=10.0.142.30)     pa_type = _infer_pyarrow_type(column_values)
# (MapWorker(MapBatches(ImageGen)) pid=20595, ip=10.0.142.30)               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (MapWorker(MapBatches(ImageGen)) pid=20595, ip=10.0.142.30)   File "/home/ray/anaconda3/lib/python3.12/site-packages/ray/air/util/tensor_extensions/arrow.py", line 431, in _infer_pyarrow_type
# (MapWorker(MapBatches(ImageGen)) pid=20595, ip=10.0.142.30)     inferred_pa_dtype = pa.infer_type(column_values)
# (MapWorker(MapBatches(ImageGen)) pid=20595, ip=10.0.142.30)                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (MapWorker(MapBatches(ImageGen)) pid=20595, ip=10.0.142.30)   File "pyarrow/array.pxi", line 568, in pyarrow.lib.infer_type
# (MapWorker(MapBatches(ImageGen)) pid=20595, ip=10.0.142.30)   File "pyarrow/error.pxi", line 155, in pyarrow.lib.pyarrow_internal_check_status
# (MapWorker(MapBatches(ImageGen)) pid=20595, ip=10.0.142.30)   File "pyarrow/error.pxi", line 92, in pyarrow.lib.check_status
# (MapWorker(MapBatches(ImageGen)) pid=20595, ip=10.0.142.30) pyarrow.lib.ArrowInvalid: Could not convert <PIL.Image.Image image mode=RGB size=512x512 at 0x7C01154041D0> with type Image: did not recognize Python value type when inferring an Arrow data type
# (MapWorker(MapBatches(ImageGen)) pid=20595, ip=10.0.142.30)
# (MapWorker(MapBatches(ImageGen)) pid=20595, ip=10.0.142.30) The above exception was the direct cause of the following exception:
# (MapWorker(MapBatches(ImageGen)) pid=20595, ip=10.0.142.30)
# (MapWorker(MapBatches(ImageGen)) pid=20595, ip=10.0.142.30) Traceback (most recent call last):
# (MapWorker(MapBatches(ImageGen)) pid=20595, ip=10.0.142.30)   File "/home/ray/anaconda3/lib/python3.12/site-packages/ray/air/util/tensor_extensions/arrow.py", line 235, in convert_to_pyarrow_array
# (MapWorker(MapBatches(ImageGen)) pid=20595, ip=10.0.142.30)     return _convert_to_pyarrow_native_array(column_values, column_name)
# (MapWorker(MapBatches(ImageGen)) pid=20595, ip=10.0.142.30)            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (MapWorker(MapBatches(ImageGen)) pid=20595, ip=10.0.142.30)   File "/home/ray/anaconda3/lib/python3.12/site-packages/ray/air/util/tensor_extensions/arrow.py", line 345, in _convert_to_pyarrow_native_array
# (MapWorker(MapBatches(ImageGen)) pid=20595, ip=10.0.142.30)     raise ArrowConversionError(str(column_values)) from e
# (MapWorker(MapBatches(ImageGen)) pid=20595, ip=10.0.142.30) ray.air.util.tensor_extensions.arrow.ArrowConversionError: Error converting data to Arrow: [<PIL.Image.Image image mode=RGB size=512x512 at 0x7C01154041D0>, <PIL.Image.Image image mode=RGB size=512x512 at 0x7C0114FD7470>, <PIL.Image.Image image mode=RGB size=512x512 at 0x7C0117E4E720>, <PIL...
# (MapWorker(MapBatches(ImageGen)) pid=20595, ip=10.0.142.30) The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['<|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|>', "the composition. this scene captures the essence of an enchanting spring season, where nature's beauty is at its most vivid and alive.", '<|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|>', "season through the striking colors and delicate textures of the koala's coat. <|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|>"]
# (MapWorker(MapBatches(ImageGen)) pid=20595, ip=10.0.142.30) The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['!!!!!!!!!!!!!!!!!!!!!!!!!!', "the composition. this scene captures the essence of an enchanting spring season, where nature's beauty is at its most vivid and alive.", '!!!!!!!!!!!!!!!!!!!!!!!!!!', "season through the striking colors and delicate textures of the koala's coat. <|endoftext|>!!!!!!!!!!!"]
#   0%|          | 0/1 [00:00<?, ?it/s] pid=20595, ip=10.0.142.30)
# 100%|██████████| 1/1 [00:00<00:00,  4.06it/s]95, ip=10.0.142.30)
# (MapWorker(MapBatches(Enhancer)) pid=21681, ip=10.0.180.82) A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# (MapWorker(MapBatches(Enhancer)) pid=20749, ip=10.0.142.30) A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer. [repeated 4x across cluster]
# (MapWorker(MapBatches(Enhancer)) pid=20749, ip=10.0.142.30) A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer. [repeated 4x across cluster]
# (MapWorker(MapBatches(Enhancer)) pid=21681, ip=10.0.180.82) A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer. [repeated 3x across cluster]
# (MapWorker(MapBatches(Enhancer)) pid=21681, ip=10.0.180.82) A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer. [repeated 4x across cluster]
# (MapWorker(MapBatches(Enhancer)) pid=21681, ip=10.0.180.82) You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset

# %% [markdown]
# <h2 style="color: #0f2027; background: linear-gradient(90deg, #43cea2 0%, #185a9d 100%); padding: 12px 0; border-radius: 8px; text-align:center; font-size: 2rem; letter-spacing: 1px;">
#    <span style="color: #fff;">Thank You!</span>
# </h2>

# %% [markdown]
# <div align="center"><img src="assets/LI.png" alt="Intro to Ray" width="50%"></div>
